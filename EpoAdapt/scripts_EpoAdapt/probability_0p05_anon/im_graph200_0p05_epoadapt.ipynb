# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOAdapt/
# Out:
# /content/drive/MyDrive/ML_Project/EPOAdapt

# %% [markdown]
# ### Probability 0.05
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 100.0 EPOAdapt 4
# 16
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 280490 RR sets for influence estimation...
# RR sets: 100% 280490/280490 [09:47<00:00, 477.82it/s]
# Built 280490 RR sets
#   Node 199: estimated_f=1.00, c=1.00, ratio=0.995
#   Node 194: estimated_f=1.02, c=2.02, ratio=0.506
#   Node 198: estimated_f=1.09, c=2.36, ratio=0.464
#   Node 15: estimated_f=41.99, c=92.01, ratio=0.456
#   Node 189: estimated_f=1.03, c=2.44, ratio=0.421
#   Node 32: estimated_f=39.99, c=98.87, ratio=0.405
#   Node 43: estimated_f=30.59, c=82.64, ratio=0.370
#   Node 49: estimated_f=23.15, c=62.67, ratio=0.369
#   Node 41: estimated_f=25.02, c=71.80, ratio=0.349
#   Node 45: estimated_f=20.26, c=58.15, ratio=0.348
#   Node 31: estimated_f=29.27, c=84.10, ratio=0.348
#   Node 44: estimated_f=31.48, c=92.49, ratio=0.340
#   Node 37: estimated_f=32.90, c=97.20, ratio=0.339
#   Node 191: estimated_f=1.11, c=3.30, ratio=0.337
#   Node 53: estimated_f=30.88, c=94.82, ratio=0.326
#   Node 61: estimated_f=24.52, c=75.81, ratio=0.323
#   Node 38: estimated_f=30.28, c=94.64, ratio=0.320
#   Node 56: estimated_f=20.50, c=67.56, ratio=0.303
#   Node 197: estimated_f=1.08, c=3.57, ratio=0.302
#   Node 52: estimated_f=27.04, c=91.07, ratio=0.297
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 200
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 38: Initialized with 5 seeds (20 singletons + greedy)
# SubPOMC 38:   1% 81/12800 [00:01<03:54, 54.16it/s]SubPOMC 15: Initialized with 7 seeds (20 singletons + greedy)
# SubPOMC 15:  13% 1676/12800 [00:28<03:31, 52.55it/s]SubPOMC 199: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 38:  19% 2416/12800 [00:32<03:12, 54.01it/s]SubPOMC 194: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 12800/12800 [01:54<00:00, 112.24it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 38: 100% 12800/12800 [02:48<00:00, 75.96it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 194: 100% 12800/12800 [02:19<00:00, 91.53it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 15:  67% 8565/12800 [02:53<01:44, 40.62it/s]SubPOMC 189: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 189:  24% 3114/12800 [00:31<01:14, 129.67it/s]SubPOMC 191: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 189:  28% 3580/12800 [00:36<01:29, 102.52it/s]SubPOMC 198: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 12800/12800 [04:33<00:00, 46.85it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 189: 100% 12800/12800 [01:57<00:00, 108.65it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 191:  89% 11367/12800 [01:44<00:12, 111.73it/s]SubPOMC 197: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 198: 100% 12800/12800 [01:49<00:00, 117.12it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 191: 100% 12800/12800 [01:55<00:00, 110.56it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 197: 100% 12800/12800 [01:57<00:00, 108.99it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 1017.8111 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 100.0 EPOAdapt 4
# 16
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 280490 RR sets for influence estimation...
# RR sets: 100% 280490/280490 [09:44<00:00, 480.11it/s]
# Built 280490 RR sets
#   Node 199: estimated_f=0.96, c=1.00, ratio=0.956
#   Node 194: estimated_f=1.07, c=2.02, ratio=0.529
#   Node 15: estimated_f=42.19, c=92.01, ratio=0.459
#   Node 189: estimated_f=1.06, c=2.44, ratio=0.435
#   Node 198: estimated_f=1.03, c=2.36, ratio=0.435
#   Node 32: estimated_f=40.26, c=98.87, ratio=0.407
#   Node 49: estimated_f=23.38, c=62.67, ratio=0.373
#   Node 43: estimated_f=30.79, c=82.64, ratio=0.373
#   Node 41: estimated_f=25.27, c=71.80, ratio=0.352
#   Node 45: estimated_f=20.36, c=58.15, ratio=0.350
#   Node 31: estimated_f=29.28, c=84.10, ratio=0.348
#   Node 191: estimated_f=1.14, c=3.30, ratio=0.346
#   Node 44: estimated_f=31.63, c=92.49, ratio=0.342
#   Node 37: estimated_f=33.01, c=97.20, ratio=0.340
#   Node 53: estimated_f=31.08, c=94.82, ratio=0.328
#   Node 38: estimated_f=30.51, c=94.64, ratio=0.322
#   Node 61: estimated_f=24.39, c=75.81, ratio=0.322
#   Node 197: estimated_f=1.08, c=3.57, ratio=0.304
#   Node 56: estimated_f=20.48, c=67.56, ratio=0.303
#   Node 52: estimated_f=27.08, c=91.07, ratio=0.297
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 200
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 38: Initialized with 5 seeds (20 singletons + greedy)
# SubPOMC 38:   1% 82/12800 [00:01<03:00, 70.47it/s]SubPOMC 15: Initialized with 6 seeds (20 singletons + greedy)
# SubPOMC 15:   8% 1016/12800 [00:28<06:36, 29.69it/s]SubPOMC 199: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 15:  10% 1274/12800 [00:35<04:37, 41.54it/s]SubPOMC 194: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 12800/12800 [01:52<00:00, 113.37it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 194: 100% 12800/12800 [01:53<00:00, 112.84it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 38:  78% 9998/12800 [02:51<00:46, 60.68it/s]SubPOMC 189: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 189:   8% 1038/12800 [00:13<01:57, 100.50it/s]SubPOMC 191: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 38: 100% 12800/12800 [03:39<00:00, 58.43it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 15: 100% 12800/12800 [03:58<00:00, 53.75it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 189:  58% 7366/12800 [01:19<00:55, 97.41it/s] SubPOMC 198: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 191:  78% 10014/12800 [01:29<00:24, 115.46it/s]SubPOMC 197: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 191: 100% 12800/12800 [01:54<00:00, 111.62it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 189: 100% 12800/12800 [02:13<00:00, 95.72it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 198: 100% 12800/12800 [01:54<00:00, 112.01it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 197: 100% 12800/12800 [02:06<00:00, 101.10it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 987.7758 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 100.0 EPOAdapt 4
# 16
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 280490 RR sets for influence estimation...
# RR sets: 100% 280490/280490 [09:46<00:00, 478.14it/s]
# Built 280490 RR sets
#   Node 199: estimated_f=1.00, c=1.00, ratio=1.004
#   Node 194: estimated_f=1.08, c=2.02, ratio=0.531
#   Node 15: estimated_f=42.06, c=92.01, ratio=0.457
#   Node 198: estimated_f=1.07, c=2.36, ratio=0.455
#   Node 189: estimated_f=1.08, c=2.44, ratio=0.442
#   Node 32: estimated_f=40.19, c=98.87, ratio=0.406
#   Node 49: estimated_f=23.40, c=62.67, ratio=0.373
#   Node 43: estimated_f=30.79, c=82.64, ratio=0.373
#   Node 31: estimated_f=29.19, c=84.10, ratio=0.347
#   Node 45: estimated_f=20.18, c=58.15, ratio=0.347
#   Node 41: estimated_f=24.87, c=71.80, ratio=0.346
#   Node 44: estimated_f=31.42, c=92.49, ratio=0.340
#   Node 37: estimated_f=32.72, c=97.20, ratio=0.337
#   Node 191: estimated_f=1.08, c=3.30, ratio=0.328
#   Node 53: estimated_f=30.84, c=94.82, ratio=0.325
#   Node 61: estimated_f=24.35, c=75.81, ratio=0.321
#   Node 38: estimated_f=30.28, c=94.64, ratio=0.320
#   Node 56: estimated_f=20.44, c=67.56, ratio=0.303
#   Node 48: estimated_f=24.80, c=82.91, ratio=0.299
#   Node 52: estimated_f=27.19, c=91.07, ratio=0.299
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 200
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 38: Initialized with 5 seeds (20 singletons + greedy)
# SubPOMC 38:   1% 174/12800 [00:02<03:12, 65.50it/s]SubPOMC 15: Initialized with 14 seeds (20 singletons + greedy)
# SubPOMC 38:  16% 2101/12800 [00:27<01:59, 89.23it/s]SubPOMC 199: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 38:  21% 2654/12800 [00:34<01:55, 87.48it/s]SubPOMC 194: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 12800/12800 [01:48<00:00, 117.95it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 194: 100% 12800/12800 [01:55<00:00, 110.65it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 38: 100% 12800/12800 [02:47<00:00, 76.23it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 15:  73% 9300/12800 [02:45<01:18, 44.57it/s]SubPOMC 189: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 189:   7% 910/12800 [00:12<02:30, 78.85it/s]SubPOMC 191: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 191:  12% 1511/12800 [00:22<02:31, 74.66it/s]SubPOMC 198: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 12800/12800 [03:47<00:00, 56.30it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 189:  57% 7235/12800 [01:18<00:52, 106.94it/s]SubPOMC 31: Initialized with 23 seeds (20 singletons + greedy)
# SubPOMC 189: 100% 12800/12800 [02:11<00:00, 97.45it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 191: 100% 12800/12800 [02:25<00:00, 87.69it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 198: 100% 12800/12800 [02:05<00:00, 102.35it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 31: 100% 12800/12800 [02:49<00:00, 75.60it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 1004.8716 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 57.04',
    'value = 55.7',
    'value = 56.58'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 56.4400 sec, Std Dev: 0.6809 sec, CV: 1.21%

# %% [markdown]
# **------Time Analysis----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 1017.8111',
    'Elapsed time: 987.7758',
    'Elapsed time: 1004.8716'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 1003.4862 sec, Std Dev: 15.0655 sec, CV: 1.50%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 200
# ---

# %% [markdown]
# **--------Run 1----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:21<00:00, 483.46it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=0.99, c=1.00, ratio=0.993
#   Node 0: estimated_f=63.44, c=103.13, ratio=0.615
#   Node 6: estimated_f=52.53, c=102.60, ratio=0.512
#   Node 4: estimated_f=58.00, c=113.62, ratio=0.510
#   Node 194: estimated_f=1.03, c=2.02, ratio=0.507
#   Node 10: estimated_f=53.89, c=106.33, ratio=0.507
#   Node 8: estimated_f=51.25, c=105.24, ratio=0.487
#   Node 18: estimated_f=51.87, c=107.45, ratio=0.483
#   Node 1: estimated_f=63.99, c=137.54, ratio=0.465
#   Node 2: estimated_f=64.69, c=139.41, ratio=0.464
#   Node 15: estimated_f=42.06, c=92.01, ratio=0.457
#   Node 27: estimated_f=44.29, c=100.81, ratio=0.439
#   Node 198: estimated_f=1.03, c=2.36, ratio=0.436
#   Node 11: estimated_f=53.69, c=123.55, ratio=0.435
#   Node 189: estimated_f=1.05, c=2.44, ratio=0.428
#   Node 7: estimated_f=54.88, c=129.09, ratio=0.425
#   Node 22: estimated_f=48.64, c=115.01, ratio=0.423
#   Node 14: estimated_f=50.60, c=119.86, ratio=0.422
#   Node 17: estimated_f=44.05, c=104.85, ratio=0.420
#   Node 12: estimated_f=51.71, c=127.06, ratio=0.407
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 4800, n = 200
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 2: Initialized with 24 seeds (20 singletons + greedy)
# SubPOMC 2:  23% 4394/19200 [02:54<08:45, 28.17it/s]SubPOMC 0: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 2:  58% 11132/19200 [07:29<04:46, 28.19it/s]SubPOMC 199: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 2:  79% 15094/19200 [10:04<02:02, 33.44it/s]SubPOMC 198: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 2: 100% 19200/19200 [12:54<00:00, 24.80it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 199: 100% 19200/19200 [05:58<00:00, 53.58it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 198: 100% 19200/19200 [05:00<00:00, 63.85it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 0: 100% 19200/19200 [13:54<00:00, 23.01it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 15: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 15:   1% 118/19200 [00:05<15:59, 19.89it/s]SubPOMC 14: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 14:  62% 11837/19200 [06:30<04:08, 29.65it/s]SubPOMC 194: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 15:  50% 9694/19200 [06:52<06:23, 24.78it/s]SubPOMC 189: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 19200/19200 [10:13<00:00, 31.27it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 194: 100% 19200/19200 [05:44<00:00, 55.75it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 15:  94% 18116/19200 [12:50<00:40, 26.68it/s]SubPOMC 6: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 189: 100% 19200/19200 [06:04<00:00, 52.62it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 15: 100% 19200/19200 [13:36<00:00, 23.52it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 6:  11% 2065/19200 [01:20<09:16, 30.81it/s]SubPOMC 17: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 17:  10% 1942/19200 [01:08<09:58, 28.82it/s]SubPOMC 27: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 6:  22% 4300/19200 [02:44<09:08, 27.15it/s]SubPOMC 10: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 19200/19200 [10:55<00:00, 29.30it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 6: 100% 19200/19200 [12:23<00:00, 25.83it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 27: 100% 19200/19200 [10:56<00:00, 29.25it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 10: 100% 19200/19200 [12:31<00:00, 25.56it/s]
#
# >>> Subproblem 11/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 3582.0001 seconds

# %% [markdown]
# **---------Run 2 Version--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:20<00:00, 484.23it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=0.99, c=1.00, ratio=0.990
#   Node 0: estimated_f=63.02, c=103.13, ratio=0.611
#   Node 194: estimated_f=1.11, c=2.02, ratio=0.546
#   Node 6: estimated_f=52.64, c=102.60, ratio=0.513
#   Node 4: estimated_f=57.75, c=113.62, ratio=0.508
#   Node 10: estimated_f=54.01, c=106.33, ratio=0.508
#   Node 8: estimated_f=51.12, c=105.24, ratio=0.486
#   Node 18: estimated_f=51.88, c=107.45, ratio=0.483
#   Node 2: estimated_f=64.84, c=139.41, ratio=0.465
#   Node 1: estimated_f=63.87, c=137.54, ratio=0.464
#   Node 15: estimated_f=42.08, c=92.01, ratio=0.457
#   Node 27: estimated_f=44.09, c=100.81, ratio=0.437
#   Node 11: estimated_f=53.84, c=123.55, ratio=0.436
#   Node 198: estimated_f=1.02, c=2.36, ratio=0.432
#   Node 189: estimated_f=1.04, c=2.44, ratio=0.425
#   Node 14: estimated_f=50.87, c=119.86, ratio=0.424
#   Node 7: estimated_f=54.71, c=129.09, ratio=0.424
#   Node 22: estimated_f=48.45, c=115.01, ratio=0.421
#   Node 17: estimated_f=44.07, c=104.85, ratio=0.420
#   Node 12: estimated_f=52.13, c=127.06, ratio=0.410
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 4800, n = 200
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 2: Initialized with 22 seeds (20 singletons + greedy)
# SubPOMC 2:   1% 192/19200 [00:08<13:20, 23.74it/s]SubPOMC 0: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 0:  43% 8314/19200 [06:24<12:24, 14.61it/s]SubPOMC 198: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 0:  47% 9084/19200 [07:00<08:14, 20.44it/s]SubPOMC 199: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 198: 100% 19200/19200 [05:21<00:00, 59.79it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 2: 100% 19200/19200 [12:02<00:00, 26.57it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 199: 100% 19200/19200 [05:55<00:00, 53.97it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 0: 100% 19200/19200 [14:56<00:00, 21.42it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 14: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 14:  12% 2305/19200 [01:19<09:11, 30.62it/s]SubPOMC 15: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 15:  36% 6970/19200 [05:05<10:03, 20.25it/s]SubPOMC 189: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 15:  48% 9258/19200 [06:41<05:57, 27.85it/s]SubPOMC 194: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 19200/19200 [10:56<00:00, 29.24it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 189: 100% 19200/19200 [05:03<00:00, 63.28it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 194: 100% 19200/19200 [04:26<00:00, 72.07it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 15:  91% 17475/19200 [12:38<01:38, 17.57it/s]SubPOMC 17: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 15:  97% 18659/19200 [13:29<00:20, 25.82it/s]SubPOMC 10: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 17:   9% 1678/19200 [00:59<08:09, 35.82it/s]SubPOMC 6: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 19200/19200 [13:55<00:00, 22.99it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 10:  20% 3770/19200 [02:30<10:40, 24.08it/s]SubPOMC 27: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 19200/19200 [11:18<00:00, 28.28it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 6: 100% 19200/19200 [12:57<00:00, 24.68it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 10: 100% 19200/19200 [13:28<00:00, 23.75it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 27: 100% 19200/19200 [12:08<00:00, 26.37it/s]
#
# >>> Subproblem 12/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 3624.4440 seconds

# %% [markdown]
# **----------Run 3-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:53<00:00, 462.25it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=1.00, c=1.00, ratio=0.996
#   Node 0: estimated_f=63.29, c=103.13, ratio=0.614
#   Node 194: estimated_f=1.06, c=2.02, ratio=0.525
#   Node 6: estimated_f=52.55, c=102.60, ratio=0.512
#   Node 4: estimated_f=57.71, c=113.62, ratio=0.508
#   Node 10: estimated_f=53.69, c=106.33, ratio=0.505
#   Node 8: estimated_f=51.04, c=105.24, ratio=0.485
#   Node 18: estimated_f=51.59, c=107.45, ratio=0.480
#   Node 1: estimated_f=63.93, c=137.54, ratio=0.465
#   Node 2: estimated_f=64.71, c=139.41, ratio=0.464
#   Node 15: estimated_f=42.24, c=92.01, ratio=0.459
#   Node 198: estimated_f=1.04, c=2.36, ratio=0.442
#   Node 27: estimated_f=44.18, c=100.81, ratio=0.438
#   Node 11: estimated_f=53.60, c=123.55, ratio=0.434
#   Node 189: estimated_f=1.04, c=2.44, ratio=0.427
#   Node 7: estimated_f=54.71, c=129.09, ratio=0.424
#   Node 14: estimated_f=50.71, c=119.86, ratio=0.423
#   Node 22: estimated_f=48.61, c=115.01, ratio=0.423
#   Node 17: estimated_f=43.88, c=104.85, ratio=0.418
#   Node 12: estimated_f=51.90, c=127.06, ratio=0.408
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 4800, n = 200
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 2: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 2:   7% 1414/19200 [00:56<11:14, 26.37it/s]SubPOMC 0: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 2:  53% 10178/19200 [06:15<07:05, 21.23it/s]SubPOMC 198: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 2:  70% 13410/19200 [08:19<04:42, 20.50it/s]SubPOMC 199: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 2: 100% 19200/19200 [12:06<00:00, 26.44it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 198: 100% 19200/19200 [06:10<00:00, 51.81it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 199: 100% 19200/19200 [04:48<00:00, 66.64it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 0: 100% 19200/19200 [13:29<00:00, 23.71it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 15: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 15:   2% 298/19200 [00:13<15:13, 20.69it/s]SubPOMC 14: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 14:  58% 11166/19200 [06:24<04:33, 29.35it/s]SubPOMC 194: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 194:  13% 2591/19200 [00:48<04:21, 63.47it/s]SubPOMC 189: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 19200/19200 [10:49<00:00, 29.56it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 194: 100% 19200/19200 [04:53<00:00, 65.32it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 15: 100% 19200/19200 [12:43<00:00, 25.16it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 189:  96% 18505/19200 [05:19<00:09, 70.04it/s]SubPOMC 17: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 189: 100% 19200/19200 [05:30<00:00, 58.17it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 17:  15% 2941/19200 [01:41<10:16, 26.39it/s]SubPOMC 6: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 17:  16% 3138/19200 [01:47<09:13, 29.00it/s]SubPOMC 27: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 6:   6% 1139/19200 [00:42<11:54, 25.29it/s]SubPOMC 10: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 19200/19200 [10:47<00:00, 29.65it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 27: 100% 19200/19200 [10:56<00:00, 29.24it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 6: 100% 19200/19200 [12:09<00:00, 26.31it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 10: 100% 19200/19200 [11:48<00:00, 27.10it/s]
#
# >>> Subproblem 11/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 3501.8270 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 200 Results--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 93.34',
    'value = 94.34',
    'value = 93.12'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 93.6000 sec, Std Dev: 0.6502 sec, CV: 0.69%

# %% [markdown]
# **----------Time Analysis-----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 3582.0001',
    'Elapsed time: 3624.4440',
    'Elapsed time: 3501.8270'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 3569.4237 sec, Std Dev: 62.2684 sec, CV: 1.74%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 300
# ---

# %% [markdown]
# **--------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:19<00:00, 485.06it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=1.04, c=1.00, ratio=1.043
#   Node 0: estimated_f=63.39, c=103.13, ratio=0.615
#   Node 6: estimated_f=52.28, c=102.60, ratio=0.510
#   Node 4: estimated_f=57.67, c=113.62, ratio=0.508
#   Node 194: estimated_f=1.03, c=2.02, ratio=0.507
#   Node 10: estimated_f=53.84, c=106.33, ratio=0.506
#   Node 8: estimated_f=51.14, c=105.24, ratio=0.486
#   Node 18: estimated_f=51.76, c=107.45, ratio=0.482
#   Node 2: estimated_f=64.87, c=139.41, ratio=0.465
#   Node 1: estimated_f=63.89, c=137.54, ratio=0.465
#   Node 198: estimated_f=1.08, c=2.36, ratio=0.460
#   Node 15: estimated_f=42.18, c=92.01, ratio=0.458
#   Node 189: estimated_f=1.08, c=2.44, ratio=0.442
#   Node 27: estimated_f=44.27, c=100.81, ratio=0.439
#   Node 11: estimated_f=53.92, c=123.55, ratio=0.436
#   Node 7: estimated_f=54.65, c=129.09, ratio=0.423
#   Node 14: estimated_f=50.46, c=119.86, ratio=0.421
#   Node 22: estimated_f=48.37, c=115.01, ratio=0.421
#   Node 17: estimated_f=43.83, c=104.85, ratio=0.418
#   Node 12: estimated_f=52.00, c=127.06, ratio=0.409
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 5800, n = 200
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 2: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 2:  50% 11502/23200 [10:31<12:20, 15.80it/s]SubPOMC 0: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 2: 100% 23200/23200 [21:31<00:00, 17.97it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 0:  50% 11688/23200 [11:33<13:53, 13.80it/s]SubPOMC 199: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 199:  21% 4909/23200 [02:21<06:17, 48.45it/s]SubPOMC 198: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 23200/23200 [08:17<00:00, 46.65it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 198: 100% 23200/23200 [08:47<00:00, 43.99it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 0: 100% 23200/23200 [22:47<00:00, 16.97it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 14: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 14:  24% 5667/23200 [04:25<13:19, 21.93it/s]SubPOMC 15: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 14:  54% 12542/23200 [10:03<08:19, 21.32it/s]SubPOMC 189: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  67% 15461/23200 [12:29<07:56, 16.24it/s]SubPOMC 194: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 23200/23200 [18:57<00:00, 20.39it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 189: 100% 23200/23200 [10:16<00:00, 37.61it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 194: 100% 23200/23200 [09:49<00:00, 39.33it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 15: 100% 23200/23200 [19:08<00:00, 20.20it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 17: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 17:   2% 352/23200 [00:16<18:02, 21.10it/s]SubPOMC 6: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 17:  13% 3107/23200 [02:26<16:07, 20.77it/s]SubPOMC 10: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 6:  18% 4146/23200 [03:32<22:37, 14.04it/s]SubPOMC 27: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 23200/23200 [18:20<00:00, 21.08it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 6: 100% 23200/23200 [20:54<00:00, 18.49it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 27: 100% 23200/23200 [17:43<00:00, 21.81it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 10: 100% 23200/23200 [20:11<00:00, 19.15it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 11: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 11:  10% 2435/23200 [02:03<18:38, 18.56it/s]SubPOMC 7: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 11: 100% 23200/23200 [18:58<00:00, 20.38it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 7: 100% 23200/23200 [18:46<00:00, 20.60it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 9126.7399 seconds

# %% [markdown]
# **----------Run 2 -----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:25<00:00, 480.68it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=1.01, c=1.00, ratio=1.006
#   Node 0: estimated_f=63.26, c=103.13, ratio=0.613
#   Node 194: estimated_f=1.12, c=2.02, ratio=0.551
#   Node 6: estimated_f=52.72, c=102.60, ratio=0.514
#   Node 4: estimated_f=58.16, c=113.62, ratio=0.512
#   Node 10: estimated_f=53.94, c=106.33, ratio=0.507
#   Node 8: estimated_f=51.23, c=105.24, ratio=0.487
#   Node 18: estimated_f=51.72, c=107.45, ratio=0.481
#   Node 2: estimated_f=64.87, c=139.41, ratio=0.465
#   Node 1: estimated_f=63.98, c=137.54, ratio=0.465
#   Node 15: estimated_f=42.39, c=92.01, ratio=0.461
#   Node 198: estimated_f=1.07, c=2.36, ratio=0.455
#   Node 27: estimated_f=44.35, c=100.81, ratio=0.440
#   Node 11: estimated_f=53.87, c=123.55, ratio=0.436
#   Node 189: estimated_f=1.05, c=2.44, ratio=0.429
#   Node 7: estimated_f=54.83, c=129.09, ratio=0.425
#   Node 22: estimated_f=48.81, c=115.01, ratio=0.424
#   Node 14: estimated_f=50.64, c=119.86, ratio=0.422
#   Node 17: estimated_f=44.15, c=104.85, ratio=0.421
#   Node 12: estimated_f=51.88, c=127.06, ratio=0.408
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 5800, n = 200
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 2: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 2:  38% 8779/23200 [07:24<11:07, 21.61it/s]SubPOMC 0: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 2: 100% 23200/23200 [19:40<00:00, 19.65it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 0:  63% 14646/23200 [13:12<06:30, 21.88it/s]SubPOMC 198: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 23200/23200 [20:47<00:00, 18.59it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 198:  91% 21134/23200 [08:11<00:48, 43.02it/s]SubPOMC 199: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 198: 100% 23200/23200 [08:54<00:00, 43.38it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 199: 100% 23200/23200 [08:59<00:00, 42.99it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 14: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 14:  37% 8616/23200 [06:51<10:53, 22.33it/s]SubPOMC 194: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 194:  90% 20961/23200 [08:04<00:47, 46.74it/s]SubPOMC 15: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 194: 100% 23200/23200 [08:52<00:00, 43.56it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 14: 100% 23200/23200 [17:30<00:00, 22.08it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 15:  24% 5548/23200 [04:28<16:55, 17.39it/s]SubPOMC 189: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 189:  99% 23042/23200 [12:30<00:04, 39.36it/s]SubPOMC 17: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 189: 100% 23200/23200 [12:35<00:00, 30.72it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 17:   7% 1662/23200 [01:25<18:57, 18.94it/s]SubPOMC 6: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 23200/23200 [19:47<00:00, 19.54it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 17:  87% 20204/23200 [17:40<02:48, 17.76it/s]SubPOMC 10: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 10:   7% 1683/23200 [01:33<21:27, 16.72it/s]SubPOMC 27: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 23200/23200 [20:09<00:00, 19.18it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 6: 100% 23200/23200 [19:38<00:00, 19.68it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 10:  72% 16649/23200 [14:42<05:08, 21.26it/s]SubPOMC 7: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 10:  77% 17883/23200 [15:45<04:18, 20.55it/s]SubPOMC 11: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 10: 100% 23200/23200 [20:24<00:00, 18.95it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 27: 100% 23200/23200 [19:47<00:00, 19.54it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 7: 100% 23200/23200 [17:43<00:00, 21.82it/s]
#
# >>> Subproblem 14/14 completed <<<
# SubPOMC 11: 100% 23200/23200 [18:17<00:00, 21.14it/s]
#
# >>> Subproblem 13/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 8750.5166 seconds

# %% [markdown]
# **----------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:49<00:00, 464.63it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=1.01, c=1.00, ratio=1.010
#   Node 0: estimated_f=63.46, c=103.13, ratio=0.615
#   Node 194: estimated_f=1.04, c=2.02, ratio=0.513
#   Node 6: estimated_f=52.46, c=102.60, ratio=0.511
#   Node 4: estimated_f=57.99, c=113.62, ratio=0.510
#   Node 10: estimated_f=53.93, c=106.33, ratio=0.507
#   Node 8: estimated_f=51.15, c=105.24, ratio=0.486
#   Node 18: estimated_f=51.95, c=107.45, ratio=0.483
#   Node 2: estimated_f=64.88, c=139.41, ratio=0.465
#   Node 1: estimated_f=64.00, c=137.54, ratio=0.465
#   Node 15: estimated_f=42.20, c=92.01, ratio=0.459
#   Node 189: estimated_f=1.08, c=2.44, ratio=0.443
#   Node 27: estimated_f=44.43, c=100.81, ratio=0.441
#   Node 198: estimated_f=1.03, c=2.36, ratio=0.437
#   Node 11: estimated_f=53.87, c=123.55, ratio=0.436
#   Node 7: estimated_f=54.91, c=129.09, ratio=0.425
#   Node 14: estimated_f=50.86, c=119.86, ratio=0.424
#   Node 22: estimated_f=48.67, c=115.01, ratio=0.423
#   Node 17: estimated_f=44.11, c=104.85, ratio=0.421
#   Node 12: estimated_f=51.99, c=127.06, ratio=0.409
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 5800, n = 200
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 2: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 2:  40% 9330/23200 [09:07<12:12, 18.95it/s]SubPOMC 0: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 0:  44% 10192/23200 [10:12<12:41, 17.07it/s]SubPOMC 198: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 2:  95% 21990/23200 [21:38<01:22, 14.73it/s]SubPOMC 199: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 2: 100% 23200/23200 [22:53<00:00, 16.89it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 198: 100% 23200/23200 [07:31<00:00, 51.44it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 199: 100% 23200/23200 [08:07<00:00, 47.58it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 0: 100% 23200/23200 [22:43<00:00, 17.02it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 14: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 14:  47% 10799/23200 [08:24<10:48, 19.11it/s]SubPOMC 15: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 14:  79% 18230/23200 [14:19<04:57, 16.69it/s]SubPOMC 189: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 23200/23200 [18:19<00:00, 21.11it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 15:  59% 13698/23200 [11:42<07:39, 20.66it/s]SubPOMC 194: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 189: 100% 23200/23200 [09:32<00:00, 40.55it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 15: 100% 23200/23200 [19:36<00:00, 19.72it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 194: 100% 23200/23200 [07:56<00:00, 48.70it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 6: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 6:  16% 3690/23200 [03:03<16:20, 19.89it/s]SubPOMC 17: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 6:  34% 7881/23200 [06:31<14:52, 17.17it/s]SubPOMC 10: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 17:  35% 8124/23200 [06:22<11:15, 22.32it/s]SubPOMC 27: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 23200/23200 [19:25<00:00, 19.90it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 17: 100% 23200/23200 [18:24<00:00, 21.00it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 10: 100% 23200/23200 [18:17<00:00, 21.13it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 27:  89% 20659/23200 [18:05<02:14, 18.84it/s]SubPOMC 7: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 27: 100% 23200/23200 [20:18<00:00, 19.03it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 7:  31% 7283/23200 [06:03<12:06, 21.91it/s]SubPOMC 4: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 7: 100% 23200/23200 [19:13<00:00, 20.12it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 4: 100% 23200/23200 [18:45<00:00, 20.60it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 9051.5513 seconds

# %% [markdown]
# ---

# %% [markdown]
# **----------Budget 300 Results-----------**

# %%
# The result strings
results = [
    'value = 108.46',
    'value = 107.48',
    'value = 107.6'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 107.8467 sec, Std Dev: 0.5345 sec, CV: 0.50%

# %% [markdown]
# **------------Time Analysis--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 9126.7399',
    'Elapsed time: 8750.5166',
    'Elapsed time: 9051.5513'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 8976.2693 sec, Std Dev: 199.0893 sec, CV: 2.22%

# %% [markdown]
# #### Budget 400
# ---

# %% [markdown]
# **-----------Run 1-----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 400.0 EPOAdapt 4
# 34
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:16<00:00, 487.13it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=1.01, c=1.00, ratio=1.013
#   Node 0: estimated_f=63.24, c=103.13, ratio=0.613
#   Node 194: estimated_f=1.08, c=2.02, ratio=0.533
#   Node 6: estimated_f=52.36, c=102.60, ratio=0.510
#   Node 4: estimated_f=57.89, c=113.62, ratio=0.509
#   Node 10: estimated_f=53.90, c=106.33, ratio=0.507
#   Node 8: estimated_f=51.13, c=105.24, ratio=0.486
#   Node 18: estimated_f=51.66, c=107.45, ratio=0.481
#   Node 1: estimated_f=63.84, c=137.54, ratio=0.464
#   Node 2: estimated_f=64.66, c=139.41, ratio=0.464
#   Node 15: estimated_f=42.15, c=92.01, ratio=0.458
#   Node 189: estimated_f=1.09, c=2.44, ratio=0.447
#   Node 27: estimated_f=44.27, c=100.81, ratio=0.439
#   Node 198: estimated_f=1.02, c=2.36, ratio=0.434
#   Node 11: estimated_f=53.60, c=123.55, ratio=0.434
#   Node 7: estimated_f=54.53, c=129.09, ratio=0.422
#   Node 22: estimated_f=48.58, c=115.01, ratio=0.422
#   Node 14: estimated_f=50.55, c=119.86, ratio=0.422
#   Node 17: estimated_f=43.92, c=104.85, ratio=0.419
#   Node 12: estimated_f=52.16, c=127.06, ratio=0.411
# Selected 20 candidates via RR sets
# → adaptive K_B = 17 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 6800, n = 200
# → K_B = 17; launching 17 diverse subRuns
#
# SubPOMC 2: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 2:  39% 10647/27200 [11:24<19:08, 14.41it/s]SubPOMC 0: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 0:  14% 3779/27200 [04:05<24:08, 16.17it/s]SubPOMC 199: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 199:  10% 2625/27200 [01:37<08:44, 46.81it/s]SubPOMC 198: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 27200/27200 [10:25<00:00, 43.49it/s]
#
# >>> Subproblem 4/17 completed <<<
# SubPOMC 2: 100% 27200/27200 [28:01<00:00, 16.18it/s]
#
# >>> Subproblem 1/17 completed <<<
# SubPOMC 198: 100% 27200/27200 [10:58<00:00, 41.32it/s]
#
# >>> Subproblem 3/17 completed <<<
# SubPOMC 0: 100% 27200/27200 [30:15<00:00, 14.99it/s]
#
# >>> Subproblem 2/17 completed <<<
# SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  54% 14652/27200 [13:53<11:23, 18.36it/s]SubPOMC 189: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  89% 24219/27200 [23:05<02:57, 16.78it/s]SubPOMC 15: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 27200/27200 [26:00<00:00, 17.43it/s]
#
# >>> Subproblem 7/17 completed <<<
# SubPOMC 15:  12% 3373/27200 [03:34<23:25, 16.96it/s]SubPOMC 194: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 189: 100% 27200/27200 [13:14<00:00, 34.23it/s]
#
# >>> Subproblem 5/17 completed <<<
# SubPOMC 194: 100% 27200/27200 [10:21<00:00, 43.76it/s]
#
# >>> Subproblem 6/17 completed <<<
# SubPOMC 15: 100% 27200/27200 [26:51<00:00, 16.88it/s]
#
# >>> Subproblem 8/17 completed <<<
# SubPOMC 17: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 17:  23% 6241/27200 [06:15<22:19, 15.65it/s]SubPOMC 6: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 17:  90% 24558/27200 [24:08<02:55, 15.04it/s]SubPOMC 10: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 27200/27200 [26:42<00:00, 16.97it/s]
#
# >>> Subproblem 10/17 completed <<<
# SubPOMC 10:  13% 3580/27200 [04:03<26:33, 14.82it/s]SubPOMC 27: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 27200/27200 [26:49<00:00, 16.89it/s]
#
# >>> Subproblem 9/17 completed <<<
# SubPOMC 27: 100% 27200/27200 [25:25<00:00, 17.83it/s]
#
# >>> Subproblem 12/17 completed <<<
# SubPOMC 10: 100% 27200/27200 [30:39<00:00, 14.78it/s]
#
# >>> Subproblem 11/17 completed <<<
# SubPOMC 11: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 11:  11% 2875/27200 [02:53<29:57, 13.53it/s]SubPOMC 7: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 11: 100% 27200/27200 [28:18<00:00, 16.02it/s]
#
# >>> Subproblem 13/17 completed <<<
# SubPOMC 7:  99% 26845/27200 [28:34<00:25, 13.96it/s]SubPOMC 18: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 7: 100% 27200/27200 [28:56<00:00, 15.66it/s]
#
# >>> Subproblem 14/17 completed <<<
# SubPOMC 18:  13% 3546/27200 [03:24<19:22, 20.35it/s]SubPOMC 4: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 18: 100% 27200/27200 [26:40<00:00, 17.00it/s]
#
# >>> Subproblem 16/17 completed <<<
# SubPOMC 4: 100% 27200/27200 [26:55<00:00, 16.83it/s]
#
# >>> Subproblem 15/17 completed <<<
# SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 27200/27200 [27:35<00:00, 16.43it/s]
#
# >>> Subproblem 17/17 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 20433.9485 seconds

# %% [markdown]
# **----------Run 2 ------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 400.0 EPOAdapt 4
# 34
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:49<00:00, 464.32it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=0.99, c=1.00, ratio=0.989
#   Node 0: estimated_f=63.07, c=103.13, ratio=0.612
#   Node 194: estimated_f=1.05, c=2.02, ratio=0.517
#   Node 6: estimated_f=52.68, c=102.60, ratio=0.513
#   Node 4: estimated_f=57.82, c=113.62, ratio=0.509
#   Node 10: estimated_f=53.77, c=106.33, ratio=0.506
#   Node 8: estimated_f=51.15, c=105.24, ratio=0.486
#   Node 18: estimated_f=51.55, c=107.45, ratio=0.480
#   Node 198: estimated_f=1.10, c=2.36, ratio=0.466
#   Node 2: estimated_f=64.71, c=139.41, ratio=0.464
#   Node 1: estimated_f=63.84, c=137.54, ratio=0.464
#   Node 15: estimated_f=42.19, c=92.01, ratio=0.458
#   Node 27: estimated_f=44.29, c=100.81, ratio=0.439
#   Node 11: estimated_f=53.41, c=123.55, ratio=0.432
#   Node 189: estimated_f=1.05, c=2.44, ratio=0.430
#   Node 7: estimated_f=55.01, c=129.09, ratio=0.426
#   Node 22: estimated_f=48.67, c=115.01, ratio=0.423
#   Node 14: estimated_f=50.57, c=119.86, ratio=0.422
#   Node 17: estimated_f=44.02, c=104.85, ratio=0.420
#   Node 12: estimated_f=51.84, c=127.06, ratio=0.408
# Selected 20 candidates via RR sets
# → adaptive K_B = 17 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 6800, n = 200
# → K_B = 17; launching 17 diverse subRuns
#
# SubPOMC 2: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 2:  27% 7250/27200 [07:50<25:18, 13.14it/s]SubPOMC 198: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 198:  27% 7383/27200 [04:32<12:03, 27.39it/s]SubPOMC 199: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 2:  48% 12937/27200 [13:59<16:36, 14.32it/s]SubPOMC 0: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 198: 100% 27200/27200 [14:54<00:00, 30.40it/s]
#
# >>> Subproblem 3/17 completed <<<
# SubPOMC 199: 100% 27200/27200 [11:32<00:00, 39.27it/s]
#
# >>> Subproblem 4/17 completed <<<
# SubPOMC 2: 100% 27200/27200 [29:36<00:00, 15.31it/s]
#
# >>> Subproblem 1/17 completed <<<
# SubPOMC 0: 100% 27200/27200 [31:03<00:00, 14.59it/s]
#
# >>> Subproblem 2/17 completed <<<
# SubPOMC 14: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 14:  15% 3985/27200 [04:09<22:29, 17.20it/s]SubPOMC 189: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 189:   5% 1473/27200 [01:21<26:09, 16.39it/s]SubPOMC 194: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 194:  98% 26615/27200 [13:06<00:17, 33.69it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 194: 100% 27200/27200 [13:20<00:00, 33.98it/s]
#
# >>> Subproblem 6/17 completed <<<
# SubPOMC 189: 100% 27200/27200 [20:30<00:00, 22.11it/s]
#
# >>> Subproblem 5/17 completed <<<
# SubPOMC 14: 100% 27200/27200 [27:15<00:00, 16.63it/s]
#
# >>> Subproblem 7/17 completed <<<
# SubPOMC 15: 100% 27200/27200 [26:25<00:00, 17.16it/s]
#
# >>> Subproblem 8/17 completed <<<
# SubPOMC 17: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 17:   2% 556/27200 [00:31<26:07, 16.99it/s]SubPOMC 6: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 6:  10% 2773/27200 [02:43<25:36, 15.90it/s]SubPOMC 10: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 27200/27200 [23:54<00:00, 18.96it/s]
#
# >>> Subproblem 10/17 completed <<<
# SubPOMC 6: 100% 27200/27200 [27:01<00:00, 16.78it/s]
#
# >>> Subproblem 9/17 completed <<<
# SubPOMC 10:  94% 25550/27200 [26:10<01:51, 14.75it/s]SubPOMC 27: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 10: 100% 27200/27200 [27:57<00:00, 16.21it/s]
#
# >>> Subproblem 11/17 completed <<<
# SubPOMC 27: 100% 27200/27200 [25:01<00:00, 18.11it/s]
#
# >>> Subproblem 12/17 completed <<<
# SubPOMC 7: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 7:  26% 7143/27200 [07:36<24:10, 13.83it/s]SubPOMC 4: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 4:  28% 7698/27200 [08:37<24:04, 13.50it/s]SubPOMC 11: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 7: 100% 27200/27200 [27:12<00:00, 16.66it/s]
#
# >>> Subproblem 13/17 completed <<<
# SubPOMC 11:  54% 14645/27200 [15:31<10:05, 20.73it/s]SubPOMC 18: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 4: 100% 27200/27200 [29:39<00:00, 15.28it/s]
# SubPOMC 18:  19% 5193/27200 [05:30<25:01, 14.66it/s]
# >>> Subproblem 14/17 completed <<<
# SubPOMC 11: 100% 27200/27200 [28:06<00:00, 16.12it/s]
#
# >>> Subproblem 15/17 completed <<<
# SubPOMC 18: 100% 27200/27200 [27:40<00:00, 16.38it/s]
#
# >>> Subproblem 16/17 completed <<<
# SubPOMC 8: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 27200/27200 [25:33<00:00, 17.74it/s]
#
# >>> Subproblem 17/17 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 21361.0252 seconds

# %% [markdown]
# **-------------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 400.0 EPOAdapt 4
# 34
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [12:07<00:00, 453.15it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=1.03, c=1.00, ratio=1.033
#   Node 0: estimated_f=63.29, c=103.13, ratio=0.614
#   Node 194: estimated_f=1.07, c=2.02, ratio=0.529
#   Node 6: estimated_f=52.77, c=102.60, ratio=0.514
#   Node 4: estimated_f=58.03, c=113.62, ratio=0.511
#   Node 10: estimated_f=53.91, c=106.33, ratio=0.507
#   Node 8: estimated_f=51.18, c=105.24, ratio=0.486
#   Node 18: estimated_f=51.71, c=107.45, ratio=0.481
#   Node 2: estimated_f=64.72, c=139.41, ratio=0.464
#   Node 1: estimated_f=63.80, c=137.54, ratio=0.464
#   Node 15: estimated_f=42.15, c=92.01, ratio=0.458
#   Node 198: estimated_f=1.05, c=2.36, ratio=0.446
#   Node 27: estimated_f=44.51, c=100.81, ratio=0.442
#   Node 11: estimated_f=53.76, c=123.55, ratio=0.435
#   Node 189: estimated_f=1.05, c=2.44, ratio=0.430
#   Node 22: estimated_f=48.86, c=115.01, ratio=0.425
#   Node 7: estimated_f=54.80, c=129.09, ratio=0.424
#   Node 14: estimated_f=50.76, c=119.86, ratio=0.424
#   Node 17: estimated_f=44.14, c=104.85, ratio=0.421
#   Node 12: estimated_f=52.01, c=127.06, ratio=0.409
# Selected 20 candidates via RR sets
# → adaptive K_B = 17 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 6800, n = 200
# → K_B = 17; launching 17 diverse subRuns
#
# SubPOMC 2: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 2:  18% 4873/27200 [05:42<26:15, 14.17it/s]SubPOMC 0: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 2:  48% 13025/27200 [15:11<16:02, 14.73it/s]SubPOMC 199: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0:  32% 8765/27200 [09:52<23:56, 12.83it/s]SubPOMC 198: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 198: 100% 27200/27200 [13:58<00:00, 32.45it/s]
#
# >>> Subproblem 3/17 completed <<<
# SubPOMC 2: 100% 27200/27200 [31:08<00:00, 14.56it/s]
#
# >>> Subproblem 1/17 completed <<<
# SubPOMC 199: 100% 27200/27200 [20:12<00:00, 22.43it/s]
#
# >>> Subproblem 4/17 completed <<<
# SubPOMC 0: 100% 27200/27200 [30:36<00:00, 14.81it/s]
#
# >>> Subproblem 2/17 completed <<<
# SubPOMC 14: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 14:  19% 5284/27200 [05:37<23:28, 15.56it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:  14% 3770/27200 [03:16<22:35, 17.28it/s]SubPOMC 194: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 194:  13% 3457/27200 [02:15<09:20, 42.35it/s]SubPOMC 189: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 194: 100% 27200/27200 [11:26<00:00, 39.60it/s]
#
# >>> Subproblem 5/17 completed <<<
# SubPOMC 189: 100% 27200/27200 [12:14<00:00, 37.01it/s]
#
# >>> Subproblem 6/17 completed <<<
# SubPOMC 14: 100% 27200/27200 [28:15<00:00, 16.04it/s]
#
# >>> Subproblem 7/17 completed <<<
# SubPOMC 15: 100% 27200/27200 [24:35<00:00, 18.44it/s]
#
# >>> Subproblem 8/17 completed <<<
# SubPOMC 6: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 6:  22% 5862/27200 [05:59<25:33, 13.91it/s]SubPOMC 17: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 17:  24% 6525/27200 [06:27<20:51, 16.52it/s]SubPOMC 10: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 10:  22% 5910/27200 [06:15<20:56, 16.94it/s]SubPOMC 27: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 27200/27200 [28:34<00:00, 15.87it/s]
#
# >>> Subproblem 9/17 completed <<<
# SubPOMC 17: 100% 27200/27200 [26:51<00:00, 16.88it/s]
#
# >>> Subproblem 10/17 completed <<<
# SubPOMC 10: 100% 27200/27200 [29:06<00:00, 15.58it/s]
#
# >>> Subproblem 11/17 completed <<<
# SubPOMC 27: 100% 27200/27200 [27:12<00:00, 16.66it/s]
#
# >>> Subproblem 12/17 completed <<<
# SubPOMC 7: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 7:  30% 8231/27200 [08:38<19:30, 16.21it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 4:   8% 2215/27200 [02:22<32:01, 13.01it/s]SubPOMC 11: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 7: 100% 27200/27200 [28:37<00:00, 15.84it/s]
#
# >>> Subproblem 13/17 completed <<<
# SubPOMC 4:  83% 22450/27200 [22:26<04:36, 17.17it/s]SubPOMC 18: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 11: 100% 27200/27200 [24:37<00:00, 18.41it/s]
#
# >>> Subproblem 15/17 completed <<<
# SubPOMC 4: 100% 27200/27200 [27:15<00:00, 16.63it/s]
#
# >>> Subproblem 14/17 completed <<<
# SubPOMC 18: 100% 27200/27200 [25:27<00:00, 17.81it/s]
#
# >>> Subproblem 16/17 completed <<<
# SubPOMC 8: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 27200/27200 [26:33<00:00, 17.07it/s]
#
# >>> Subproblem 17/17 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 21427.1799 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 400 Results-----------**

# %%
# The result strings
results = [
    'value = 116.78',
    'value = 117.48',
    'value = 118.34'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 117.5333 sec, Std Dev: 0.7814 sec, CV: 0.66%

# %% [markdown]
# **-----------Time Analysis---------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 20433.9485',
    'Elapsed time: 21361.0252',
    'Elapsed time: 21427.1799'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 21074.0512 sec, Std Dev: 555.3312 sec, CV: 2.64%

# %% [markdown]
# #### Budget 500
# ---

# %% [markdown]
# **------------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 500.0 EPOAdapt 4
# 38
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:45<00:00, 467.43it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=1.02, c=1.00, ratio=1.019
#   Node 0: estimated_f=63.22, c=103.13, ratio=0.613
#   Node 194: estimated_f=1.07, c=2.02, ratio=0.530
#   Node 6: estimated_f=52.55, c=102.60, ratio=0.512
#   Node 4: estimated_f=57.75, c=113.62, ratio=0.508
#   Node 10: estimated_f=53.87, c=106.33, ratio=0.507
#   Node 8: estimated_f=51.16, c=105.24, ratio=0.486
#   Node 18: estimated_f=51.81, c=107.45, ratio=0.482
#   Node 1: estimated_f=64.15, c=137.54, ratio=0.466
#   Node 2: estimated_f=64.79, c=139.41, ratio=0.465
#   Node 15: estimated_f=42.41, c=92.01, ratio=0.461
#   Node 198: estimated_f=1.05, c=2.36, ratio=0.447
#   Node 27: estimated_f=44.40, c=100.81, ratio=0.440
#   Node 11: estimated_f=54.19, c=123.55, ratio=0.439
#   Node 189: estimated_f=1.07, c=2.44, ratio=0.437
#   Node 22: estimated_f=48.93, c=115.01, ratio=0.425
#   Node 7: estimated_f=54.88, c=129.09, ratio=0.425
#   Node 14: estimated_f=50.79, c=119.86, ratio=0.424
#   Node 17: estimated_f=43.99, c=104.85, ratio=0.420
#   Node 12: estimated_f=52.03, c=127.06, ratio=0.410
# Selected 20 candidates via RR sets
# → adaptive K_B = 19 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 7600, n = 200
# → K_B = 19; launching 19 diverse subRuns
#
# SubPOMC 2: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 2:   9% 2601/30400 [03:09<40:41, 11.38it/s]SubPOMC 198: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 198:  24% 7375/30400 [06:18<18:50, 20.38it/s]SubPOMC 0: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 198:  35% 10505/30400 [08:39<13:28, 24.61it/s]SubPOMC 199: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 198: 100% 30400/30400 [22:58<00:00, 22.06it/s]
# SubPOMC 199:  62% 18869/30400 [14:18<09:40, 19.86it/s]
# >>> Subproblem 3/19 completed <<<
# SubPOMC 199: 100% 30400/30400 [22:45<00:00, 22.27it/s]
#
# >>> Subproblem 4/19 completed <<<
# SubPOMC 2: 100% 30400/30400 [35:51<00:00, 14.13it/s]
#
# >>> Subproblem 1/19 completed <<<
# SubPOMC 0: 100% 30400/30400 [33:05<00:00, 15.31it/s]
#
# >>> Subproblem 2/19 completed <<<
# SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:   2% 512/30400 [00:34<27:20, 18.22it/s]SubPOMC 194: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 194:  32% 9672/30400 [07:35<15:44, 21.94it/s]SubPOMC 189: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 189:  24% 7420/30400 [05:54<14:59, 25.56it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 194: 100% 30400/30400 [22:13<00:00, 22.80it/s]
#
# >>> Subproblem 5/19 completed <<<
# SubPOMC 189: 100% 30400/30400 [23:08<00:00, 21.89it/s]
#
# >>> Subproblem 6/19 completed <<<
# SubPOMC 14: 100% 30400/30400 [31:33<00:00, 16.05it/s]
#
# >>> Subproblem 7/19 completed <<<
# SubPOMC 15: 100% 30400/30400 [29:57<00:00, 16.91it/s]
#
# >>> Subproblem 8/19 completed <<<
# SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:   2% 705/30400 [00:48<35:20, 14.00it/s]SubPOMC 17: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  53% 16185/30400 [18:16<17:46, 13.33it/s]SubPOMC 10: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  62% 18970/30400 [21:24<16:54, 11.27it/s]SubPOMC 27: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 17: 100% 30400/30400 [29:39<00:00, 17.09it/s]
#
# >>> Subproblem 10/19 completed <<<
# SubPOMC 6: 100% 30400/30400 [34:11<00:00, 14.82it/s]
#
# >>> Subproblem 9/19 completed <<<
# SubPOMC 10: 100% 30400/30400 [33:19<00:00, 15.20it/s]
#
# >>> Subproblem 11/19 completed <<<
# SubPOMC 27: 100% 30400/30400 [31:21<00:00, 16.15it/s]
#
# >>> Subproblem 12/19 completed <<<
# SubPOMC 7: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 7:  13% 3812/30400 [04:11<31:22, 14.12it/s]SubPOMC 11: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 7:  85% 25830/30400 [27:36<04:54, 15.53it/s]SubPOMC 18: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 7: 100% 30400/30400 [32:26<00:00, 15.62it/s]
#
# >>> Subproblem 14/19 completed <<<
# SubPOMC 11:  92% 27911/30400 [30:13<02:42, 15.35it/s]SubPOMC 4: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 11: 100% 30400/30400 [32:54<00:00, 15.40it/s]
#
# >>> Subproblem 13/19 completed <<<
# SubPOMC 18: 100% 30400/30400 [30:51<00:00, 16.42it/s]
#
# >>> Subproblem 16/19 completed <<<
# SubPOMC 4: 100% 30400/30400 [35:07<00:00, 14.42it/s]
#
# >>> Subproblem 15/19 completed <<<
# SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8:  11% 3346/30400 [03:32<22:28, 20.06it/s]SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 12:  83% 25314/30400 [26:29<06:08, 13.79it/s]SubPOMC 1: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 30400/30400 [31:20<00:00, 16.17it/s]
#
# >>> Subproblem 17/19 completed <<<
# SubPOMC 12: 100% 30400/30400 [31:35<00:00, 16.04it/s]
#
# >>> Subproblem 18/19 completed <<<
# SubPOMC 1: 100% 30400/30400 [32:55<00:00, 15.39it/s]
#
# >>> Subproblem 19/19 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 32407.3814 seconds

# %% [markdown]
# **------------Run 2 --------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 1

# %% [markdown]
# **-------------Run 3--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 500.0 EPOAdapt 4
# 38
# Building fast coverage sets...
# Coverage sets built: avg size = 50.8
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [11:40<00:00, 470.20it/s]
# Built 329587 RR sets
#   Node 199: estimated_f=0.98, c=1.00, ratio=0.984
#   Node 0: estimated_f=63.28, c=103.13, ratio=0.614
#   Node 194: estimated_f=1.06, c=2.02, ratio=0.522
#   Node 6: estimated_f=52.58, c=102.60, ratio=0.513
#   Node 4: estimated_f=57.66, c=113.62, ratio=0.507
#   Node 10: estimated_f=53.74, c=106.33, ratio=0.505
#   Node 8: estimated_f=51.02, c=105.24, ratio=0.485
#   Node 18: estimated_f=51.57, c=107.45, ratio=0.480
#   Node 2: estimated_f=64.68, c=139.41, ratio=0.464
#   Node 1: estimated_f=63.77, c=137.54, ratio=0.464
#   Node 198: estimated_f=1.08, c=2.36, ratio=0.459
#   Node 15: estimated_f=42.14, c=92.01, ratio=0.458
#   Node 27: estimated_f=44.48, c=100.81, ratio=0.441
#   Node 189: estimated_f=1.07, c=2.44, ratio=0.436
#   Node 11: estimated_f=53.59, c=123.55, ratio=0.434
#   Node 7: estimated_f=54.69, c=129.09, ratio=0.424
#   Node 14: estimated_f=50.54, c=119.86, ratio=0.422
#   Node 22: estimated_f=48.42, c=115.01, ratio=0.421
#   Node 17: estimated_f=43.96, c=104.85, ratio=0.419
#   Node 12: estimated_f=51.87, c=127.06, ratio=0.408
# Selected 20 candidates via RR sets
# → adaptive K_B = 19 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 7600, n = 200
# → K_B = 19; launching 19 diverse subRuns
#
# SubPOMC 2: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 2:  24% 7340/30400 [09:11<26:01, 14.77it/s]SubPOMC 198: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 198:  20% 6141/30400 [05:18<17:50, 22.66it/s]SubPOMC 199: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 198:  21% 6245/30400 [05:23<20:07, 20.00it/s]SubPOMC 0: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 198: 100% 30400/30400 [23:55<00:00, 21.18it/s]
#
# >>> Subproblem 3/19 completed <<<
# SubPOMC 2: 100% 30400/30400 [35:48<00:00, 14.15it/s]
#
# >>> Subproblem 1/19 completed <<<
# SubPOMC 199: 100% 30400/30400 [25:27<00:00, 19.90it/s]
#
# >>> Subproblem 4/19 completed <<<
# SubPOMC 0: 100% 30400/30400 [35:26<00:00, 14.30it/s]
#
# >>> Subproblem 2/19 completed <<<
# SubPOMC 189: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 189:  16% 4879/30400 [04:21<19:40, 21.62it/s]SubPOMC 194: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 194:  16% 4805/30400 [04:21<21:54, 19.47it/s]SubPOMC 14: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 189:  57% 17251/30400 [13:44<09:56, 22.06it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 189: 100% 30400/30400 [24:10<00:00, 20.95it/s]
#
# >>> Subproblem 5/19 completed <<<
# SubPOMC 194: 100% 30400/30400 [24:52<00:00, 20.36it/s]
#
# >>> Subproblem 6/19 completed <<<
# SubPOMC 14: 100% 30400/30400 [37:02<00:00, 13.68it/s]
#
# >>> Subproblem 7/19 completed <<<
# SubPOMC 15: 100% 30400/30400 [34:43<00:00, 14.59it/s]
#
# >>> Subproblem 8/19 completed <<<
# SubPOMC 6: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 6:   8% 2464/30400 [02:52<23:22, 19.92it/s]SubPOMC 17: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 17:  51% 15372/30400 [18:45<15:50, 15.82it/s]SubPOMC 27: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  96% 29240/30400 [34:12<01:26, 13.48it/s]SubPOMC 10: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 30400/30400 [35:35<00:00, 14.23it/s]
#
# >>> Subproblem 9/19 completed <<<
# SubPOMC 17: 100% 30400/30400 [36:51<00:00, 13.75it/s]
#
# >>> Subproblem 10/19 completed <<<
# SubPOMC 27: 100% 30400/30400 [34:08<00:00, 14.84it/s]
#
# >>> Subproblem 12/19 completed <<<
# SubPOMC 10: 100% 30400/30400 [34:58<00:00, 14.48it/s]
#
# >>> Subproblem 11/19 completed <<<
# SubPOMC 7: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 7:  12% 3611/30400 [03:58<27:15, 16.38it/s]SubPOMC 4: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 7:  45% 13754/30400 [15:15<18:28, 15.02it/s]SubPOMC 11: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 7: 100% 30400/30400 [32:47<00:00, 15.45it/s]
#
# >>> Subproblem 13/19 completed <<<
# SubPOMC 4:  98% 29817/30400 [34:26<00:41, 14.13it/s]SubPOMC 18: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 4: 100% 30400/30400 [35:08<00:00, 14.42it/s]
#
# >>> Subproblem 14/19 completed <<<
# SubPOMC 11: 100% 30400/30400 [34:33<00:00, 14.66it/s]
#
# >>> Subproblem 15/19 completed <<<
# SubPOMC 18: 100% 30400/30400 [35:44<00:00, 14.18it/s]
#
# >>> Subproblem 16/19 completed <<<
# SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8:   1% 353/30400 [00:24<36:35, 13.69it/s]SubPOMC 12: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 12:  44% 13322/30400 [15:11<19:13, 14.80it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 30400/30400 [31:51<00:00, 15.90it/s]
#
# >>> Subproblem 17/19 completed <<<
# SubPOMC 12: 100% 30400/30400 [34:23<00:00, 14.73it/s]
#
# >>> Subproblem 18/19 completed <<<
# SubPOMC 1: 100% 30400/30400 [36:06<00:00, 14.03it/s]
#
# >>> Subproblem 19/19 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 33264.8124 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 500 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 125.64',
    'value = 125.42',
    'value = 124.36',
    'value = 126.58',
    'value = 124.62',
    'value = 125.56',
    'value = 125.04'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 125.3171 sec, Std Dev: 0.7357 sec, CV: 0.59%

# %% [markdown]
# ---
