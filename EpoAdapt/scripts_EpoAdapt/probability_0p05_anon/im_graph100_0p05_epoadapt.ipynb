# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOAdapt/
# Out:
# /content/drive/MyDrive/ML_Project/EPOAdapt

# %% [markdown]
# ### Probability 0.05
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 100.0 EPOAdapt 4
# 14
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2203.96it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.97, c=1.00, ratio=0.969
#   Node 98: estimated_f=1.06, c=2.26, ratio=0.469
#   Node 96: estimated_f=1.13, c=4.06, ratio=0.278
#   Node 92: estimated_f=1.13, c=4.23, ratio=0.267
#   Node 97: estimated_f=1.09, c=4.16, ratio=0.261
#   Node 7: estimated_f=15.17, c=60.51, ratio=0.251
#   Node 6: estimated_f=20.69, c=82.83, ratio=0.250
#   Node 94: estimated_f=1.19, c=4.82, ratio=0.248
#   Node 90: estimated_f=1.15, c=4.71, ratio=0.244
#   Node 15: estimated_f=11.82, c=48.60, ratio=0.243
#   Node 1: estimated_f=21.68, c=89.25, ratio=0.243
#   Node 11: estimated_f=17.86, c=79.69, ratio=0.224
#   Node 95: estimated_f=1.23, c=5.50, ratio=0.223
#   Node 9: estimated_f=18.26, c=82.73, ratio=0.221
#   Node 4: estimated_f=15.53, c=70.48, ratio=0.220
#   Node 5: estimated_f=21.14, c=98.22, ratio=0.215
#   Node 12: estimated_f=12.38, c=58.67, ratio=0.211
#   Node 8: estimated_f=18.16, c=88.01, ratio=0.206
#   Node 93: estimated_f=1.28, c=6.33, ratio=0.201
#   Node 19: estimated_f=9.98, c=50.06, ratio=0.199
# Selected 20 candidates via RR sets
# → adaptive K_B = 7 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 1400, n = 100
# → K_B = 7; launching 7 diverse subRuns
#
# SubPOMC 1: Initialized with 9 seeds (20 singletons + greedy)
# SubPOMC 1:  49% 2729/5600 [00:21<00:23, 121.39it/s]SubPOMC 96: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 1:  50% 2825/5600 [00:22<00:24, 112.56it/s]SubPOMC 90: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 1:  51% 2873/5600 [00:22<00:21, 128.06it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 5600/5600 [00:42<00:00, 131.38it/s]
# SubPOMC 96:  49% 2762/5600 [00:21<00:17, 160.54it/s]
# >>> Subproblem 1/7 completed <<<
# SubPOMC 99: 100% 5600/5600 [00:39<00:00, 143.58it/s]
# SubPOMC 90:  90% 5056/5600 [00:39<00:03, 161.55it/s]
# >>> Subproblem 2/7 completed <<<
# SubPOMC 96: 100% 5600/5600 [00:41<00:00, 135.82it/s]
#
# >>> Subproblem 3/7 completed <<<
# SubPOMC 90:  99% 5531/5600 [00:42<00:00, 155.24it/s]SubPOMC 98: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 90: 100% 5600/5600 [00:43<00:00, 129.76it/s]
#
# >>> Subproblem 4/7 completed <<<
# SubPOMC 98:  60% 3347/5600 [00:20<00:12, 178.29it/s]SubPOMC 97: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 98:  69% 3853/5600 [00:23<00:10, 170.52it/s]SubPOMC 94: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 5600/5600 [00:32<00:00, 170.72it/s]
#
# >>> Subproblem 5/7 completed <<<
# SubPOMC 97: 100% 5600/5600 [00:38<00:00, 145.40it/s]
#
# >>> Subproblem 7/7 completed <<<
# SubPOMC 94: 100% 5600/5600 [00:39<00:00, 141.12it/s]
#
# >>> Subproblem 6/7 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 167.9928 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 100.0 EPOAdapt 4
# 14
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:37<00:00, 2231.95it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.00, c=1.00, ratio=1.002
#   Node 98: estimated_f=1.05, c=2.26, ratio=0.463
#   Node 92: estimated_f=1.17, c=4.23, ratio=0.276
#   Node 97: estimated_f=1.13, c=4.16, ratio=0.272
#   Node 96: estimated_f=1.09, c=4.06, ratio=0.269
#   Node 94: estimated_f=1.21, c=4.82, ratio=0.252
#   Node 7: estimated_f=15.15, c=60.51, ratio=0.250
#   Node 6: estimated_f=20.49, c=82.83, ratio=0.247
#   Node 90: estimated_f=1.16, c=4.71, ratio=0.245
#   Node 1: estimated_f=21.64, c=89.25, ratio=0.242
#   Node 15: estimated_f=11.70, c=48.60, ratio=0.241
#   Node 11: estimated_f=17.96, c=79.69, ratio=0.225
#   Node 4: estimated_f=15.73, c=70.48, ratio=0.223
#   Node 95: estimated_f=1.21, c=5.50, ratio=0.221
#   Node 9: estimated_f=18.25, c=82.73, ratio=0.221
#   Node 5: estimated_f=21.10, c=98.22, ratio=0.215
#   Node 12: estimated_f=12.45, c=58.67, ratio=0.212
#   Node 8: estimated_f=18.48, c=88.01, ratio=0.210
#   Node 93: estimated_f=1.30, c=6.33, ratio=0.206
#   Node 33: estimated_f=7.39, c=36.83, ratio=0.201
# Selected 20 candidates via RR sets
# → adaptive K_B = 7 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 1400, n = 100
# → K_B = 7; launching 7 diverse subRuns
#
# SubPOMC 1: Initialized with 16 seeds (20 singletons + greedy)
# SubPOMC 1:  26% 1464/5600 [00:16<00:50, 81.47it/s]SubPOMC 96: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 1:  33% 1846/5600 [00:20<00:35, 106.49it/s]SubPOMC 99: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 96:  18% 996/5600 [00:07<00:33, 139.15it/s]SubPOMC 90: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 5600/5600 [00:57<00:00, 97.81it/s]
#
# >>> Subproblem 1/7 completed <<<
# SubPOMC 99: 100% 5600/5600 [00:36<00:00, 154.24it/s]
#
# >>> Subproblem 2/7 completed <<<
# SubPOMC 96: 100% 5600/5600 [00:40<00:00, 136.73it/s]
#
# >>> Subproblem 3/7 completed <<<
# SubPOMC 90: 100% 5600/5600 [00:36<00:00, 153.08it/s]
#
# >>> Subproblem 4/7 completed <<<
# SubPOMC 97: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 97:   2% 121/5600 [00:01<00:50, 107.99it/s]SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 97:  14% 797/5600 [00:06<00:37, 129.12it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 5600/5600 [00:38<00:00, 143.62it/s]
#
# >>> Subproblem 5/7 completed <<<
# SubPOMC 97: 100% 5600/5600 [00:41<00:00, 135.96it/s]
#
# >>> Subproblem 7/7 completed <<<
# SubPOMC 94: 100% 5600/5600 [00:44<00:00, 125.69it/s]
#
# >>> Subproblem 6/7 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 168.9584 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 100.0 EPOAdapt 4
# 14
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2214.57it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.02, c=1.00, ratio=1.020
#   Node 98: estimated_f=1.04, c=2.26, ratio=0.460
#   Node 96: estimated_f=1.13, c=4.06, ratio=0.277
#   Node 97: estimated_f=1.13, c=4.16, ratio=0.272
#   Node 92: estimated_f=1.12, c=4.23, ratio=0.265
#   Node 6: estimated_f=20.65, c=82.83, ratio=0.249
#   Node 7: estimated_f=15.04, c=60.51, ratio=0.249
#   Node 90: estimated_f=1.17, c=4.71, ratio=0.248
#   Node 1: estimated_f=21.74, c=89.25, ratio=0.244
#   Node 94: estimated_f=1.17, c=4.82, ratio=0.243
#   Node 15: estimated_f=11.79, c=48.60, ratio=0.243
#   Node 11: estimated_f=17.95, c=79.69, ratio=0.225
#   Node 4: estimated_f=15.74, c=70.48, ratio=0.223
#   Node 9: estimated_f=18.33, c=82.73, ratio=0.222
#   Node 95: estimated_f=1.20, c=5.50, ratio=0.218
#   Node 5: estimated_f=21.39, c=98.22, ratio=0.218
#   Node 12: estimated_f=12.58, c=58.67, ratio=0.214
#   Node 8: estimated_f=18.58, c=88.01, ratio=0.211
#   Node 19: estimated_f=10.22, c=50.06, ratio=0.204
#   Node 93: estimated_f=1.27, c=6.33, ratio=0.201
# Selected 20 candidates via RR sets
# → adaptive K_B = 7 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 1400, n = 100
# → K_B = 7; launching 7 diverse subRuns
#
# SubPOMC 1: Initialized with 12 seeds (20 singletons + greedy)
# SubPOMC 1:  44% 2463/5600 [00:18<00:23, 134.61it/s]SubPOMC 99: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 99:   3% 169/5600 [00:01<00:42, 127.92it/s]SubPOMC 96: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 1:  51% 2863/5600 [00:21<00:19, 141.56it/s]SubPOMC 90: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 5600/5600 [00:42<00:00, 130.90it/s]
#
# >>> Subproblem 1/7 completed <<<
# SubPOMC 99: 100% 5600/5600 [00:38<00:00, 146.37it/s]
#
# >>> Subproblem 2/7 completed <<<
# SubPOMC 96: 100% 5600/5600 [00:39<00:00, 142.16it/s]
#
# >>> Subproblem 3/7 completed <<<
# SubPOMC 90: 100% 5600/5600 [00:39<00:00, 141.00it/s]
#
# >>> Subproblem 4/7 completed <<<
# SubPOMC 98: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 98:  37% 2068/5600 [00:15<00:20, 171.17it/s]SubPOMC 94: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 98:  38% 2135/5600 [00:15<00:23, 149.54it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 5600/5600 [00:37<00:00, 150.76it/s]
#
# >>> Subproblem 5/7 completed <<<
# SubPOMC 97: 100% 5600/5600 [00:35<00:00, 159.58it/s]
#
# >>> Subproblem 7/7 completed <<<
# SubPOMC 94: 100% 5600/5600 [00:42<00:00, 131.56it/s]
#
# >>> Subproblem 6/7 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 163.3065 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 29.6',
    'value = 29.46',
    'value = 29.32'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 29.4600 sec, Std Dev: 0.1400 sec, CV: 0.48%

# %% [markdown]
# ---

# %% [markdown]
# **--------Time Analysis----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 167.9928',
    'Elapsed time: 168.9584',
    'Elapsed time: 163.3065'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 166.7526 sec, Std Dev: 3.0232 sec, CV: 1.81%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 200
# ---

# %% [markdown]
# **--------Run 1----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 200.0 EPOAdapt 4
# 20
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:39<00:00, 2157.30it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.02, c=1.00, ratio=1.019
#   Node 98: estimated_f=1.04, c=2.26, ratio=0.460
#   Node 92: estimated_f=1.17, c=4.23, ratio=0.276
#   Node 96: estimated_f=1.11, c=4.06, ratio=0.273
#   Node 97: estimated_f=1.11, c=4.16, ratio=0.267
#   Node 7: estimated_f=15.06, c=60.51, ratio=0.249
#   Node 6: estimated_f=20.53, c=82.83, ratio=0.248
#   Node 94: estimated_f=1.19, c=4.82, ratio=0.246
#   Node 1: estimated_f=21.45, c=89.25, ratio=0.240
#   Node 15: estimated_f=11.68, c=48.60, ratio=0.240
#   Node 90: estimated_f=1.13, c=4.71, ratio=0.240
#   Node 11: estimated_f=18.00, c=79.69, ratio=0.226
#   Node 4: estimated_f=15.76, c=70.48, ratio=0.224
#   Node 5: estimated_f=21.36, c=98.22, ratio=0.217
#   Node 9: estimated_f=17.95, c=82.73, ratio=0.217
#   Node 95: estimated_f=1.17, c=5.50, ratio=0.213
#   Node 12: estimated_f=12.42, c=58.67, ratio=0.212
#   Node 8: estimated_f=18.25, c=88.01, ratio=0.207
#   Node 93: estimated_f=1.29, c=6.33, ratio=0.204
#   Node 19: estimated_f=10.01, c=50.06, ratio=0.200
# Selected 20 candidates via RR sets
# → adaptive K_B = 10 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 2000, n = 100
# → K_B = 10; launching 10 diverse subRuns
#
# SubPOMC 1: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 1:  67% 5398/8000 [01:43<00:48, 54.17it/s]SubPOMC 96: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 1:  82% 6592/8000 [02:06<00:27, 51.76it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 8000/8000 [02:31<00:00, 52.74it/s]
#
# >>> Subproblem 1/10 completed <<<
# SubPOMC 96:  51% 4048/8000 [00:51<00:47, 82.36it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96: 100% 8000/8000 [01:34<00:00, 85.01it/s]
#
# >>> Subproblem 3/10 completed <<<
# SubPOMC 99: 100% 8000/8000 [01:19<00:00, 100.20it/s]
#
# >>> Subproblem 2/10 completed <<<
# SubPOMC 90: 100% 8000/8000 [01:31<00:00, 87.15it/s]
#
# >>> Subproblem 4/10 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  57% 4581/8000 [00:56<00:32, 104.84it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  72% 5771/8000 [01:09<00:25, 88.53it/s]SubPOMC 97: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 94:  32% 2564/8000 [00:35<01:06, 81.64it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 8000/8000 [01:33<00:00, 85.60it/s]
#
# >>> Subproblem 5/10 completed <<<
# SubPOMC 94: 100% 8000/8000 [01:34<00:00, 84.74it/s]
#
# >>> Subproblem 6/10 completed <<<
# SubPOMC 97: 100% 8000/8000 [01:35<00:00, 84.09it/s]
#
# >>> Subproblem 7/10 completed <<<
# SubPOMC 92: 100% 8000/8000 [01:23<00:00, 95.68it/s]
#
# >>> Subproblem 8/10 completed <<<
# SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  40% 3201/8000 [00:39<00:50, 95.38it/s]SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93: 100% 8000/8000 [01:30<00:00, 88.68it/s]
#
# >>> Subproblem 9/10 completed <<<
# SubPOMC 95: 100% 8000/8000 [01:35<00:00, 83.91it/s]
#
# >>> Subproblem 10/10 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 934.1160 seconds

# %% [markdown]
# **---------Run 2 Version--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 200.0 EPOAdapt 4
# 20
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2186.20it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.96, c=1.00, ratio=0.960
#   Node 98: estimated_f=1.11, c=2.26, ratio=0.489
#   Node 92: estimated_f=1.17, c=4.23, ratio=0.276
#   Node 96: estimated_f=1.05, c=4.06, ratio=0.259
#   Node 90: estimated_f=1.18, c=4.71, ratio=0.251
#   Node 6: estimated_f=20.52, c=82.83, ratio=0.248
#   Node 97: estimated_f=1.02, c=4.16, ratio=0.244
#   Node 7: estimated_f=14.77, c=60.51, ratio=0.244
#   Node 94: estimated_f=1.16, c=4.82, ratio=0.242
#   Node 15: estimated_f=11.67, c=48.60, ratio=0.240
#   Node 1: estimated_f=21.27, c=89.25, ratio=0.238
#   Node 11: estimated_f=17.74, c=79.69, ratio=0.223
#   Node 4: estimated_f=15.63, c=70.48, ratio=0.222
#   Node 9: estimated_f=17.97, c=82.73, ratio=0.217
#   Node 5: estimated_f=21.00, c=98.22, ratio=0.214
#   Node 95: estimated_f=1.17, c=5.50, ratio=0.213
#   Node 12: estimated_f=12.42, c=58.67, ratio=0.212
#   Node 8: estimated_f=18.33, c=88.01, ratio=0.208
#   Node 19: estimated_f=9.94, c=50.06, ratio=0.199
#   Node 17: estimated_f=11.44, c=58.90, ratio=0.194
# Selected 20 candidates via RR sets
# → adaptive K_B = 10 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 2000, n = 100
# → K_B = 10; launching 10 diverse subRuns
#
# SubPOMC 1: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 1:  76% 6054/8000 [01:55<00:35, 55.18it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  79% 6332/8000 [02:00<00:30, 53.88it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  95% 7576/8000 [02:24<00:08, 49.12it/s]SubPOMC 90: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 8000/8000 [02:32<00:00, 52.63it/s]
#
# >>> Subproblem 1/10 completed <<<
# SubPOMC 96: 100% 8000/8000 [01:27<00:00, 91.95it/s]
#
# >>> Subproblem 3/10 completed <<<
# SubPOMC 99: 100% 8000/8000 [01:36<00:00, 82.55it/s]
#
# >>> Subproblem 2/10 completed <<<
# SubPOMC 90: 100% 8000/8000 [01:17<00:00, 103.24it/s]
#
# >>> Subproblem 4/10 completed <<<
# SubPOMC 98: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 98:  53% 4256/8000 [00:47<00:36, 102.24it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:  10% 785/8000 [00:11<01:33, 77.46it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:  21% 1705/8000 [00:23<01:20, 77.98it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 8000/8000 [01:21<00:00, 98.58it/s]
#
# >>> Subproblem 5/10 completed <<<
# SubPOMC 94: 100% 8000/8000 [01:30<00:00, 87.96it/s]
#
# >>> Subproblem 8/10 completed <<<
# SubPOMC 97: 100% 8000/8000 [01:31<00:00, 87.14it/s]
#
# >>> Subproblem 7/10 completed <<<
# SubPOMC 92: 100% 8000/8000 [01:46<00:00, 75.08it/s]
#
# >>> Subproblem 6/10 completed <<<
# SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 4:  31% 2474/8000 [00:40<01:32, 59.67it/s]SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 8000/8000 [01:19<00:00, 101.23it/s]
#
# >>> Subproblem 9/10 completed <<<
# SubPOMC 4: 100% 8000/8000 [02:12<00:00, 60.49it/s]
#
# >>> Subproblem 10/10 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 881.5720 seconds

# %% [markdown]
# **----------Run 3-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 200.0 EPOAdapt 4
# 20
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2166.03it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.95, c=1.00, ratio=0.950
#   Node 98: estimated_f=1.07, c=2.26, ratio=0.472
#   Node 97: estimated_f=1.14, c=4.16, ratio=0.274
#   Node 92: estimated_f=1.15, c=4.23, ratio=0.271
#   Node 96: estimated_f=1.07, c=4.06, ratio=0.264
#   Node 90: estimated_f=1.17, c=4.71, ratio=0.248
#   Node 6: estimated_f=20.38, c=82.83, ratio=0.246
#   Node 7: estimated_f=14.85, c=60.51, ratio=0.245
#   Node 1: estimated_f=21.79, c=89.25, ratio=0.244
#   Node 94: estimated_f=1.16, c=4.82, ratio=0.241
#   Node 15: estimated_f=11.64, c=48.60, ratio=0.239
#   Node 11: estimated_f=17.87, c=79.69, ratio=0.224
#   Node 4: estimated_f=15.50, c=70.48, ratio=0.220
#   Node 9: estimated_f=18.09, c=82.73, ratio=0.219
#   Node 95: estimated_f=1.19, c=5.50, ratio=0.216
#   Node 5: estimated_f=21.07, c=98.22, ratio=0.215
#   Node 12: estimated_f=12.28, c=58.67, ratio=0.209
#   Node 8: estimated_f=18.20, c=88.01, ratio=0.207
#   Node 19: estimated_f=10.10, c=50.06, ratio=0.202
#   Node 17: estimated_f=11.61, c=58.90, ratio=0.197
# Selected 20 candidates via RR sets
# → adaptive K_B = 10 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 2000, n = 100
# → K_B = 10; launching 10 diverse subRuns
#
# SubPOMC 1: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 1:  70% 5633/8000 [01:45<00:46, 51.02it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:  25% 1982/8000 [00:26<01:15, 79.98it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  92% 7399/8000 [02:19<00:13, 45.34it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 8000/8000 [02:30<00:00, 53.08it/s]
#
# >>> Subproblem 1/10 completed <<<
# SubPOMC 96: 100% 8000/8000 [01:31<00:00, 87.35it/s]
#
# >>> Subproblem 3/10 completed <<<
# SubPOMC 90: 100% 8000/8000 [01:29<00:00, 89.18it/s]
#
# >>> Subproblem 4/10 completed <<<
# SubPOMC 99: 100% 8000/8000 [01:39<00:00, 80.24it/s]
#
# >>> Subproblem 2/10 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  69% 5503/8000 [01:12<00:36, 67.72it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:  12% 945/8000 [00:14<01:33, 75.72it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:  19% 1518/8000 [00:22<01:41, 64.16it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 8000/8000 [01:41<00:00, 78.85it/s]
#
# >>> Subproblem 5/10 completed <<<
# SubPOMC 94: 100% 8000/8000 [01:37<00:00, 82.04it/s]
#
# >>> Subproblem 6/10 completed <<<
# SubPOMC 92: 100% 8000/8000 [01:33<00:00, 85.86it/s]
#
# >>> Subproblem 8/10 completed <<<
# SubPOMC 97: 100% 8000/8000 [01:31<00:00, 87.77it/s]
#
# >>> Subproblem 7/10 completed <<<
# SubPOMC 4: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 4:  35% 2814/8000 [00:46<01:34, 55.14it/s]SubPOMC 95: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 4: 100% 8000/8000 [02:16<00:00, 58.79it/s]
#
# >>> Subproblem 10/10 completed <<<
# SubPOMC 95: 100% 8000/8000 [01:30<00:00, 88.38it/s]
#
# >>> Subproblem 9/10 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 896.9400 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 200 Results--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 41.84',
    'value = 41.22',
    'value = 41.04'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 41.3667 sec, Std Dev: 0.4197 sec, CV: 1.01%

# %% [markdown]
# ---

# %% [markdown]
# **--------Time Analysis----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 934.1160',
    'Elapsed time: 881.5720',
    'Elapsed time: 896.9400'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 904.2093 sec, Std Dev: 27.0157 sec, CV: 2.99%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 300
# ---

# %% [markdown]
# **--------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 300.0 EPOAdapt 4
# 25
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2162.76it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.05, c=1.00, ratio=1.051
#   Node 98: estimated_f=1.09, c=2.26, ratio=0.480
#   Node 96: estimated_f=1.18, c=4.06, ratio=0.290
#   Node 97: estimated_f=1.14, c=4.16, ratio=0.274
#   Node 92: estimated_f=1.16, c=4.23, ratio=0.273
#   Node 7: estimated_f=15.19, c=60.51, ratio=0.251
#   Node 6: estimated_f=20.59, c=82.83, ratio=0.249
#   Node 94: estimated_f=1.18, c=4.82, ratio=0.245
#   Node 90: estimated_f=1.15, c=4.71, ratio=0.243
#   Node 1: estimated_f=21.63, c=89.25, ratio=0.242
#   Node 15: estimated_f=11.66, c=48.60, ratio=0.240
#   Node 11: estimated_f=17.96, c=79.69, ratio=0.225
#   Node 9: estimated_f=18.26, c=82.73, ratio=0.221
#   Node 4: estimated_f=15.42, c=70.48, ratio=0.219
#   Node 5: estimated_f=21.30, c=98.22, ratio=0.217
#   Node 95: estimated_f=1.19, c=5.50, ratio=0.216
#   Node 12: estimated_f=12.55, c=58.67, ratio=0.214
#   Node 93: estimated_f=1.35, c=6.33, ratio=0.213
#   Node 8: estimated_f=18.46, c=88.01, ratio=0.210
#   Node 19: estimated_f=10.27, c=50.06, ratio=0.205
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.08
# → GreedyEvaluate = 2500, n = 100
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  34% 3354/10000 [01:25<02:51, 38.76it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:   6% 596/10000 [00:10<02:32, 61.47it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:  17% 1656/10000 [00:27<02:00, 69.49it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96: 100% 10000/10000 [02:30<00:00, 66.42it/s]
# SubPOMC 1:  91% 9120/10000 [03:55<00:27, 32.37it/s]
# >>> Subproblem 3/12 completed <<<
# SubPOMC 1: 100% 10000/10000 [04:18<00:00, 38.70it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 99: 100% 10000/10000 [02:44<00:00, 60.68it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 90: 100% 10000/10000 [02:44<00:00, 60.95it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:  12% 1189/10000 [00:25<02:50, 51.59it/s]SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:  15% 1477/10000 [00:30<02:35, 54.76it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 97:  13% 1251/10000 [00:24<02:49, 51.75it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94: 100% 10000/10000 [02:46<00:00, 60.00it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 97: 100% 10000/10000 [02:34<00:00, 64.93it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 98: 100% 10000/10000 [02:42<00:00, 61.49it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 92: 100% 10000/10000 [02:50<00:00, 58.55it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:   3% 312/10000 [00:06<03:11, 50.68it/s]SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  18% 1797/10000 [00:33<02:12, 62.09it/s]SubPOMC 15: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 15:   5% 497/10000 [00:11<03:39, 43.39it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 10000/10000 [02:23<00:00, 69.48it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 93: 100% 10000/10000 [02:41<00:00, 61.87it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 15: 100% 10000/10000 [03:46<00:00, 44.20it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 4: 100% 10000/10000 [03:42<00:00, 44.90it/s]
#
# >>> Subproblem 11/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2076.7314 seconds

# %% [markdown]
# **----------Run 2 -----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 300.0 EPOAdapt 4
# 25
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2183.92it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.93, c=1.00, ratio=0.933
#   Node 98: estimated_f=0.99, c=2.26, ratio=0.439
#   Node 92: estimated_f=1.25, c=4.23, ratio=0.295
#   Node 96: estimated_f=1.13, c=4.06, ratio=0.278
#   Node 97: estimated_f=1.10, c=4.16, ratio=0.265
#   Node 6: estimated_f=20.59, c=82.83, ratio=0.249
#   Node 7: estimated_f=14.75, c=60.51, ratio=0.244
#   Node 90: estimated_f=1.15, c=4.71, ratio=0.244
#   Node 1: estimated_f=21.39, c=89.25, ratio=0.240
#   Node 94: estimated_f=1.14, c=4.82, ratio=0.237
#   Node 15: estimated_f=11.51, c=48.60, ratio=0.237
#   Node 11: estimated_f=17.89, c=79.69, ratio=0.225
#   Node 9: estimated_f=18.35, c=82.73, ratio=0.222
#   Node 4: estimated_f=15.38, c=70.48, ratio=0.218
#   Node 5: estimated_f=21.02, c=98.22, ratio=0.214
#   Node 12: estimated_f=12.31, c=58.67, ratio=0.210
#   Node 95: estimated_f=1.15, c=5.50, ratio=0.209
#   Node 8: estimated_f=18.26, c=88.01, ratio=0.207
#   Node 19: estimated_f=10.25, c=50.06, ratio=0.205
#   Node 17: estimated_f=11.48, c=58.90, ratio=0.195
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.08
# → GreedyEvaluate = 2500, n = 100
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  20% 2002/10000 [00:50<03:11, 41.86it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  32% 3231/10000 [01:20<03:03, 36.94it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:  25% 2464/10000 [00:49<02:11, 57.45it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96: 100% 10000/10000 [02:36<00:00, 63.76it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 99: 100% 10000/10000 [03:11<00:00, 52.14it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 1: 100% 10000/10000 [04:04<00:00, 40.86it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 90: 100% 10000/10000 [03:00<00:00, 55.29it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 92:   6% 612/10000 [00:13<02:40, 58.46it/s]SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  19% 1910/10000 [00:33<02:11, 61.58it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 97:   3% 253/10000 [00:04<02:58, 54.49it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 92: 100% 10000/10000 [02:42<00:00, 61.67it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 98: 100% 10000/10000 [02:36<00:00, 63.84it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 97: 100% 10000/10000 [02:38<00:00, 63.09it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 94: 100% 10000/10000 [02:38<00:00, 63.04it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:   1% 146/10000 [00:03<03:32, 46.43it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:   9% 926/10000 [00:22<03:49, 39.45it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:  21% 2085/10000 [00:48<03:08, 42.05it/s]SubPOMC 19: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 10000/10000 [02:41<00:00, 61.93it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 15: 100% 10000/10000 [03:39<00:00, 45.66it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 4: 100% 10000/10000 [03:45<00:00, 44.26it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 19: 100% 10000/10000 [03:23<00:00, 49.23it/s]
#
# >>> Subproblem 12/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2074.7441 seconds

# %% [markdown]
# **----------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 300.0 EPOAdapt 4
# 25
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:39<00:00, 2145.97it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.02, c=1.00, ratio=1.022
#   Node 98: estimated_f=0.97, c=2.26, ratio=0.428
#   Node 92: estimated_f=1.19, c=4.23, ratio=0.281
#   Node 96: estimated_f=1.10, c=4.06, ratio=0.271
#   Node 97: estimated_f=1.12, c=4.16, ratio=0.268
#   Node 7: estimated_f=15.18, c=60.51, ratio=0.251
#   Node 6: estimated_f=20.47, c=82.83, ratio=0.247
#   Node 94: estimated_f=1.19, c=4.82, ratio=0.247
#   Node 90: estimated_f=1.14, c=4.71, ratio=0.243
#   Node 1: estimated_f=21.56, c=89.25, ratio=0.242
#   Node 15: estimated_f=11.63, c=48.60, ratio=0.239
#   Node 95: estimated_f=1.30, c=5.50, ratio=0.237
#   Node 11: estimated_f=18.18, c=79.69, ratio=0.228
#   Node 9: estimated_f=18.19, c=82.73, ratio=0.220
#   Node 4: estimated_f=15.44, c=70.48, ratio=0.219
#   Node 5: estimated_f=21.25, c=98.22, ratio=0.216
#   Node 12: estimated_f=12.53, c=58.67, ratio=0.214
#   Node 8: estimated_f=18.41, c=88.01, ratio=0.209
#   Node 93: estimated_f=1.30, c=6.33, ratio=0.205
#   Node 19: estimated_f=10.22, c=50.06, ratio=0.204
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.08
# → GreedyEvaluate = 2500, n = 100
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  24% 2414/10000 [01:00<03:21, 37.64it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  31% 3121/10000 [01:18<03:05, 36.99it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:   1% 98/10000 [00:02<03:09, 52.22it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99: 100% 10000/10000 [02:35<00:00, 64.24it/s]
# SubPOMC 1:  90% 9011/10000 [03:54<00:25, 38.36it/s]
# >>> Subproblem 2/12 completed <<<
# SubPOMC 90: 100% 10000/10000 [02:57<00:00, 56.46it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 96: 100% 10000/10000 [02:39<00:00, 62.59it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 1: 100% 10000/10000 [04:20<00:00, 38.35it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:   8% 841/10000 [00:16<02:30, 60.73it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  32% 3188/10000 [00:56<01:58, 57.43it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:   2% 203/10000 [00:04<03:36, 45.24it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 10000/10000 [02:41<00:00, 61.89it/s]
#
# SubPOMC 92:  95% 9530/10000 [02:24<00:06, 76.95it/s]
# SubPOMC 92: 100% 10000/10000 [02:31<00:00, 66.18it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 97: 100% 10000/10000 [02:47<00:00, 59.55it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 94: 100% 10000/10000 [02:53<00:00, 57.53it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:   4% 358/10000 [00:07<02:46, 57.90it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 4:  13% 1257/10000 [00:30<03:28, 41.97it/s]SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  52% 5215/10000 [01:17<01:02, 76.39it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93: 100% 10000/10000 [02:25<00:00, 68.64it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 95: 100% 10000/10000 [02:20<00:00, 70.95it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 4: 100% 10000/10000 [03:53<00:00, 42.84it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 15: 100% 10000/10000 [03:28<00:00, 48.08it/s]
#
# >>> Subproblem 12/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2162.6462 seconds

# %% [markdown]
# ---

# %% [markdown]
# **----------Budget 300 Results-----------**

# %%
# The result strings
results = [
    'value = 49.24',
    'value = 49.16',
    'value = 48.76'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 49.0533 sec, Std Dev: 0.2572 sec, CV: 0.52%

# %% [markdown]
# ---

# %% [markdown]
# **-------Time Analysis------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 2076.7314',
    'Elapsed time: 2074.7441',
    'Elapsed time: 2162.6462'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 2104.7072 sec, Std Dev: 50.1865 sec, CV: 2.38%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 400
# ---

# %% [markdown]
# **-----------Run 1-----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 400.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:39<00:00, 2133.49it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.01, c=1.00, ratio=1.008
#   Node 98: estimated_f=1.09, c=2.26, ratio=0.480
#   Node 96: estimated_f=1.13, c=4.06, ratio=0.279
#   Node 92: estimated_f=1.15, c=4.23, ratio=0.272
#   Node 97: estimated_f=1.13, c=4.16, ratio=0.272
#   Node 94: estimated_f=1.25, c=4.82, ratio=0.258
#   Node 90: estimated_f=1.22, c=4.71, ratio=0.258
#   Node 7: estimated_f=15.01, c=60.51, ratio=0.248
#   Node 6: estimated_f=20.50, c=82.83, ratio=0.247
#   Node 15: estimated_f=11.90, c=48.60, ratio=0.245
#   Node 1: estimated_f=21.71, c=89.25, ratio=0.243
#   Node 11: estimated_f=18.17, c=79.69, ratio=0.228
#   Node 4: estimated_f=15.78, c=70.48, ratio=0.224
#   Node 9: estimated_f=18.28, c=82.73, ratio=0.221
#   Node 95: estimated_f=1.21, c=5.50, ratio=0.220
#   Node 5: estimated_f=21.09, c=98.22, ratio=0.215
#   Node 12: estimated_f=12.59, c=58.67, ratio=0.215
#   Node 8: estimated_f=18.46, c=88.01, ratio=0.210
#   Node 19: estimated_f=10.01, c=50.06, ratio=0.200
#   Node 93: estimated_f=1.26, c=6.33, ratio=0.200
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 2900, n = 100
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:  12% 1392/11600 [00:35<04:25, 38.39it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:  12% 1441/11600 [00:36<03:59, 42.49it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:  13% 1504/11600 [00:38<04:51, 34.65it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96: 100% 11600/11600 [04:27<00:00, 43.34it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 99: 100% 11600/11600 [04:24<00:00, 43.80it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 90: 100% 11600/11600 [04:26<00:00, 43.49it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 1: 100% 11600/11600 [05:42<00:00, 33.87it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:   7% 803/11600 [00:20<04:30, 39.98it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:   8% 955/11600 [00:23<04:16, 41.54it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 97:  34% 3919/11600 [01:33<02:48, 45.66it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 11600/11600 [04:41<00:00, 41.27it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 94: 100% 11600/11600 [04:43<00:00, 40.97it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 97: 100% 11600/11600 [04:29<00:00, 43.01it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 92: 100% 11600/11600 [04:41<00:00, 41.15it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  25% 2954/11600 [01:08<03:07, 45.99it/s]SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  23% 2688/11600 [01:04<03:53, 38.22it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  88% 10189/11600 [03:47<00:31, 44.40it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 11600/11600 [04:19<00:00, 44.75it/s]
#
# SubPOMC 15:  10% 1177/11600 [00:31<04:20, 40.08it/s]
# SubPOMC 93: 100% 11600/11600 [04:29<00:00, 43.05it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 4: 100% 11600/11600 [05:20<00:00, 36.20it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 15: 100% 11600/11600 [05:07<00:00, 37.67it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 19: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19:  36% 4141/11600 [01:45<02:53, 42.97it/s]SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19: 100% 11600/11600 [04:53<00:00, 39.59it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 12: 100% 11600/11600 [04:55<00:00, 39.20it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 4091.3149 seconds

# %% [markdown]
# **----------Run 2 ------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 400.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:40<00:00, 2086.70it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.01, c=1.00, ratio=1.015
#   Node 98: estimated_f=1.06, c=2.26, ratio=0.470
#   Node 96: estimated_f=1.12, c=4.06, ratio=0.276
#   Node 92: estimated_f=1.14, c=4.23, ratio=0.269
#   Node 97: estimated_f=1.11, c=4.16, ratio=0.266
#   Node 90: estimated_f=1.20, c=4.71, ratio=0.254
#   Node 7: estimated_f=15.12, c=60.51, ratio=0.250
#   Node 6: estimated_f=20.65, c=82.83, ratio=0.249
#   Node 1: estimated_f=21.73, c=89.25, ratio=0.243
#   Node 15: estimated_f=11.82, c=48.60, ratio=0.243
#   Node 95: estimated_f=1.26, c=5.50, ratio=0.230
#   Node 94: estimated_f=1.11, c=4.82, ratio=0.229
#   Node 11: estimated_f=17.99, c=79.69, ratio=0.226
#   Node 4: estimated_f=15.64, c=70.48, ratio=0.222
#   Node 9: estimated_f=18.20, c=82.73, ratio=0.220
#   Node 5: estimated_f=21.22, c=98.22, ratio=0.216
#   Node 12: estimated_f=12.41, c=58.67, ratio=0.212
#   Node 8: estimated_f=18.23, c=88.01, ratio=0.207
#   Node 93: estimated_f=1.30, c=6.33, ratio=0.206
#   Node 19: estimated_f=10.14, c=50.06, ratio=0.203
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 2900, n = 100
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 90:   7% 804/11600 [00:20<04:12, 42.71it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:   4% 427/11600 [00:10<04:24, 42.29it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:  21% 2397/11600 [00:56<03:47, 40.49it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99: 100% 11600/11600 [04:16<00:00, 45.20it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 90: 100% 11600/11600 [04:45<00:00, 40.64it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 96: 100% 11600/11600 [04:16<00:00, 45.16it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 1: 100% 11600/11600 [05:47<00:00, 33.34it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  10% 1204/11600 [00:28<04:16, 40.48it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  29% 3326/11600 [01:16<03:03, 45.06it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 97:  44% 5086/11600 [02:02<02:56, 36.99it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 11600/11600 [04:20<00:00, 44.59it/s]
# SubPOMC 92:  83% 9613/11600 [03:51<00:47, 41.59it/s]
# >>> Subproblem 5/14 completed <<<
# SubPOMC 92: 100% 11600/11600 [04:34<00:00, 42.19it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 97: 100% 11600/11600 [04:33<00:00, 42.37it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 94: 100% 11600/11600 [04:46<00:00, 40.56it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:   3% 393/11600 [00:10<04:17, 43.49it/s]SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  52% 6028/11600 [02:23<01:50, 50.35it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  85% 9887/11600 [03:53<00:32, 51.95it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 11600/11600 [04:29<00:00, 43.04it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 93: 100% 11600/11600 [04:31<00:00, 42.80it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 4: 100% 11600/11600 [05:17<00:00, 36.49it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 15: 100% 11600/11600 [05:15<00:00, 36.75it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 19: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19:  13% 1523/11600 [00:38<03:43, 45.02it/s]SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19: 100% 11600/11600 [04:40<00:00, 41.33it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 12: 100% 11600/11600 [05:07<00:00, 37.69it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 4082.8304 seconds

# %% [markdown]
# **-------------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 400.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2177.85it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.99, c=1.00, ratio=0.988
#   Node 98: estimated_f=1.10, c=2.26, ratio=0.485
#   Node 92: estimated_f=1.19, c=4.23, ratio=0.281
#   Node 96: estimated_f=1.10, c=4.06, ratio=0.272
#   Node 97: estimated_f=1.12, c=4.16, ratio=0.268
#   Node 7: estimated_f=15.04, c=60.51, ratio=0.249
#   Node 6: estimated_f=20.49, c=82.83, ratio=0.247
#   Node 94: estimated_f=1.17, c=4.82, ratio=0.244
#   Node 90: estimated_f=1.15, c=4.71, ratio=0.243
#   Node 1: estimated_f=21.50, c=89.25, ratio=0.241
#   Node 15: estimated_f=11.69, c=48.60, ratio=0.241
#   Node 95: estimated_f=1.26, c=5.50, ratio=0.230
#   Node 11: estimated_f=17.82, c=79.69, ratio=0.224
#   Node 9: estimated_f=18.10, c=82.73, ratio=0.219
#   Node 4: estimated_f=15.41, c=70.48, ratio=0.219
#   Node 5: estimated_f=21.30, c=98.22, ratio=0.217
#   Node 12: estimated_f=12.49, c=58.67, ratio=0.213
#   Node 8: estimated_f=18.44, c=88.01, ratio=0.209
#   Node 19: estimated_f=10.17, c=50.06, ratio=0.203
#   Node 93: estimated_f=1.27, c=6.33, ratio=0.200
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 2900, n = 100
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:  11% 1230/11600 [00:30<04:05, 42.28it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:  11% 1284/11600 [00:31<04:27, 38.52it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:  12% 1364/11600 [00:33<03:58, 42.87it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99: 100% 11600/11600 [04:28<00:00, 43.23it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 96: 100% 11600/11600 [04:26<00:00, 43.56it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 90: 100% 11600/11600 [04:25<00:00, 43.70it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 1: 100% 11600/11600 [05:28<00:00, 35.36it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  19% 2160/11600 [00:48<03:25, 45.94it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  25% 2856/11600 [01:04<02:42, 53.77it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  65% 7571/11600 [02:51<01:53, 35.55it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 11600/11600 [04:21<00:00, 44.29it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 97: 100% 11600/11600 [04:25<00:00, 43.70it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 92: 100% 11600/11600 [04:17<00:00, 44.99it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 94: 100% 11600/11600 [04:27<00:00, 43.43it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  19% 2257/11600 [00:52<03:20, 46.56it/s]SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  21% 2456/11600 [01:00<04:03, 37.57it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93: 100% 11600/11600 [04:22<00:00, 44.17it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 4:  52% 6057/11600 [02:47<02:34, 35.78it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 11600/11600 [04:29<00:00, 43.04it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 4: 100% 11600/11600 [05:24<00:00, 35.76it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 15: 100% 11600/11600 [04:58<00:00, 38.89it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 19: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19:  39% 4517/11600 [01:48<02:55, 40.25it/s]SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19: 100% 11600/11600 [04:35<00:00, 42.14it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 12: 100% 11600/11600 [04:51<00:00, 39.84it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 4110.0075 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 400 Results-----------**

# %%
# The result strings
results = [
    'value = 54.24',
    'value = 54.14',
    'value = 54.8'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 54.3933 sec, Std Dev: 0.3557 sec, CV: 0.65%

# %% [markdown]
# ---

# %% [markdown]
# **------Time Analysis----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 4091.3149',
    'Elapsed time: 4082.8304',
    'Elapsed time: 4110.0075'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 4094.7176 sec, Std Dev: 13.9044 sec, CV: 0.34%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 500
# ---

# %% [markdown]
# **------------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 500.0 EPOAdapt 4
# 32
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2173.13it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.07, c=1.00, ratio=1.068
#   Node 98: estimated_f=1.05, c=2.26, ratio=0.463
#   Node 92: estimated_f=1.15, c=4.23, ratio=0.271
#   Node 96: estimated_f=1.07, c=4.06, ratio=0.264
#   Node 97: estimated_f=1.07, c=4.16, ratio=0.257
#   Node 6: estimated_f=20.81, c=82.83, ratio=0.251
#   Node 90: estimated_f=1.18, c=4.71, ratio=0.249
#   Node 7: estimated_f=15.07, c=60.51, ratio=0.249
#   Node 15: estimated_f=11.82, c=48.60, ratio=0.243
#   Node 94: estimated_f=1.17, c=4.82, ratio=0.242
#   Node 1: estimated_f=21.49, c=89.25, ratio=0.241
#   Node 11: estimated_f=17.79, c=79.69, ratio=0.223
#   Node 4: estimated_f=15.55, c=70.48, ratio=0.221
#   Node 9: estimated_f=18.19, c=82.73, ratio=0.220
#   Node 5: estimated_f=21.25, c=98.22, ratio=0.216
#   Node 12: estimated_f=12.44, c=58.67, ratio=0.212
#   Node 8: estimated_f=18.39, c=88.01, ratio=0.209
#   Node 95: estimated_f=1.14, c=5.50, ratio=0.207
#   Node 19: estimated_f=10.11, c=50.06, ratio=0.202
#   Node 93: estimated_f=1.27, c=6.33, ratio=0.200
# Selected 20 candidates via RR sets
# → adaptive K_B = 16 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 100
# → K_B = 16; launching 16 diverse subRuns
#
# SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:   7% 866/12800 [00:24<05:16, 37.69it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 90:  10% 1285/12800 [00:35<04:30, 42.49it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:  27% 3517/12800 [01:37<03:55, 39.37it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96: 100% 12800/12800 [05:47<00:00, 36.87it/s]
#
# >>> Subproblem 3/16 completed <<<
# SubPOMC 90: 100% 12800/12800 [05:41<00:00, 37.44it/s]
#
# >>> Subproblem 4/16 completed <<<
# SubPOMC 99: 100% 12800/12800 [05:42<00:00, 37.33it/s]
#
# >>> Subproblem 2/16 completed <<<
# SubPOMC 1: 100% 12800/12800 [06:51<00:00, 31.11it/s]
#
# >>> Subproblem 1/16 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:   3% 389/12800 [00:10<06:33, 31.53it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 97:   2% 258/12800 [00:07<07:42, 27.13it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 94:  62% 7890/12800 [03:26<02:08, 38.25it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 12800/12800 [05:38<00:00, 37.80it/s]
#
# >>> Subproblem 5/16 completed <<<
# SubPOMC 94: 100% 12800/12800 [05:33<00:00, 38.35it/s]
#
# >>> Subproblem 6/16 completed <<<
# SubPOMC 97: 100% 12800/12800 [06:02<00:00, 35.29it/s]
#
# >>> Subproblem 7/16 completed <<<
# SubPOMC 92: 100% 12800/12800 [05:44<00:00, 37.14it/s]
#
# >>> Subproblem 8/16 completed <<<
# SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:   5% 599/12800 [00:16<04:52, 41.67it/s]SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  36% 4669/12800 [02:08<03:45, 36.10it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  70% 8964/12800 [04:01<01:40, 38.28it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93: 100% 12800/12800 [05:40<00:00, 37.54it/s]
#
# >>> Subproblem 9/16 completed <<<
# SubPOMC 95: 100% 12800/12800 [05:40<00:00, 37.63it/s]
#
# >>> Subproblem 10/16 completed <<<
# SubPOMC 4: 100% 12800/12800 [06:50<00:00, 31.21it/s]
#
# >>> Subproblem 11/16 completed <<<
# SubPOMC 15: 100% 12800/12800 [06:20<00:00, 33.62it/s]
#
# >>> Subproblem 12/16 completed <<<
# SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 12:   2% 270/12800 [00:08<05:29, 37.98it/s]SubPOMC 19: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19:  57% 7309/12800 [03:37<02:33, 35.73it/s]SubPOMC 7: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 7:  20% 2535/12800 [01:18<05:29, 31.15it/s]SubPOMC 5: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19: 100% 12800/12800 [06:17<00:00, 33.90it/s]
#
# >>> Subproblem 13/16 completed <<<
# SubPOMC 12: 100% 12800/12800 [06:40<00:00, 31.98it/s]
#
# >>> Subproblem 14/16 completed <<<
# SubPOMC 7: 100% 12800/12800 [06:42<00:00, 31.81it/s]
#
# >>> Subproblem 15/16 completed <<<
# SubPOMC 5: 100% 12800/12800 [06:38<00:00, 32.09it/s]
#
# >>> Subproblem 16/16 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 5679.6528 seconds

# %% [markdown]
# **------------Run 2 --------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 500.0 EPOAdapt 4
# 32
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2160.15it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.99, c=1.00, ratio=0.992
#   Node 98: estimated_f=1.04, c=2.26, ratio=0.460
#   Node 92: estimated_f=1.19, c=4.23, ratio=0.282
#   Node 96: estimated_f=1.07, c=4.06, ratio=0.263
#   Node 97: estimated_f=1.05, c=4.16, ratio=0.253
#   Node 90: estimated_f=1.18, c=4.71, ratio=0.251
#   Node 7: estimated_f=15.02, c=60.51, ratio=0.248
#   Node 6: estimated_f=20.39, c=82.83, ratio=0.246
#   Node 1: estimated_f=21.64, c=89.25, ratio=0.242
#   Node 15: estimated_f=11.64, c=48.60, ratio=0.240
#   Node 94: estimated_f=1.13, c=4.82, ratio=0.236
#   Node 11: estimated_f=17.85, c=79.69, ratio=0.224
#   Node 4: estimated_f=15.48, c=70.48, ratio=0.220
#   Node 9: estimated_f=18.13, c=82.73, ratio=0.219
#   Node 5: estimated_f=20.98, c=98.22, ratio=0.214
#   Node 12: estimated_f=12.45, c=58.67, ratio=0.212
#   Node 95: estimated_f=1.14, c=5.50, ratio=0.208
#   Node 8: estimated_f=18.05, c=88.01, ratio=0.205
#   Node 19: estimated_f=10.06, c=50.06, ratio=0.201
#   Node 93: estimated_f=1.26, c=6.33, ratio=0.198
# Selected 20 candidates via RR sets
# → adaptive K_B = 16 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 100
# → K_B = 16; launching 16 diverse subRuns
#
# SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:   8% 976/12800 [00:29<05:09, 38.25it/s]SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96:  12% 1494/12800 [00:44<05:55, 31.81it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 90:  29% 3689/12800 [01:51<04:17, 35.36it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 96: 100% 12800/12800 [06:10<00:00, 34.59it/s]
#
# >>> Subproblem 3/16 completed <<<
# SubPOMC 90: 100% 12800/12800 [06:11<00:00, 34.46it/s]
#
# >>> Subproblem 4/16 completed <<<
# SubPOMC 99: 100% 12800/12800 [06:26<00:00, 33.15it/s]
#
# >>> Subproblem 2/16 completed <<<
# SubPOMC 1: 100% 12800/12800 [07:18<00:00, 29.20it/s]
#
# >>> Subproblem 1/16 completed <<<
# SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 92:   2% 268/12800 [00:07<04:57, 42.18it/s]SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:   9% 1100/12800 [00:30<05:47, 33.71it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 92:  59% 7614/12800 [03:36<02:17, 37.67it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 12800/12800 [05:47<00:00, 36.84it/s]
#
# >>> Subproblem 5/16 completed <<<
# SubPOMC 92: 100% 12800/12800 [05:58<00:00, 35.75it/s]
#
# >>> Subproblem 6/16 completed <<<
# SubPOMC 97: 100% 12800/12800 [05:45<00:00, 37.10it/s]
#
# >>> Subproblem 7/16 completed <<<
# SubPOMC 94: 100% 12800/12800 [05:57<00:00, 35.80it/s]
#
# >>> Subproblem 8/16 completed <<<
# SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  20% 2555/12800 [01:17<06:12, 27.53it/s]SubPOMC 93: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  24% 3057/12800 [01:31<04:37, 35.08it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 93:  77% 9817/12800 [04:45<01:29, 33.47it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 12800/12800 [06:13<00:00, 34.25it/s]
#
# >>> Subproblem 10/16 completed <<<
# SubPOMC 93: 100% 12800/12800 [06:08<00:00, 34.71it/s]
#
# >>> Subproblem 9/16 completed <<<
# SubPOMC 4: 100% 12800/12800 [07:04<00:00, 30.16it/s]
#
# >>> Subproblem 11/16 completed <<<
# SubPOMC 15: 100% 12800/12800 [07:04<00:00, 30.15it/s]
#
# >>> Subproblem 12/16 completed <<<
# SubPOMC 19: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19:  29% 3772/12800 [01:56<04:32, 33.17it/s]SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19:  76% 9743/12800 [04:57<01:34, 32.23it/s]SubPOMC 7: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19: 100% 12800/12800 [06:28<00:00, 32.97it/s]
#
# >>> Subproblem 13/16 completed <<<
# SubPOMC 12: 100% 12800/12800 [06:24<00:00, 33.26it/s]
#
# >>> Subproblem 14/16 completed <<<
# SubPOMC 7:  55% 6997/12800 [03:39<02:53, 33.45it/s]SubPOMC 5: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 7: 100% 12800/12800 [06:40<00:00, 31.95it/s]
#
# >>> Subproblem 15/16 completed <<<
# SubPOMC 5: 100% 12800/12800 [06:51<00:00, 31.10it/s]
#
# >>> Subproblem 16/16 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 6094.6987 seconds

# %% [markdown]
# **-------------Run 3--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 500.0 EPOAdapt 4
# 32
# Building fast coverage sets...
# Coverage sets built: avg size = 35.6
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [00:38<00:00, 2164.38it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.97, c=1.00, ratio=0.970
#   Node 98: estimated_f=1.03, c=2.26, ratio=0.455
#   Node 96: estimated_f=1.15, c=4.06, ratio=0.283
#   Node 92: estimated_f=1.15, c=4.23, ratio=0.272
#   Node 97: estimated_f=1.07, c=4.16, ratio=0.256
#   Node 6: estimated_f=20.67, c=82.83, ratio=0.250
#   Node 7: estimated_f=15.03, c=60.51, ratio=0.248
#   Node 90: estimated_f=1.17, c=4.71, ratio=0.248
#   Node 94: estimated_f=1.19, c=4.82, ratio=0.246
#   Node 1: estimated_f=21.54, c=89.25, ratio=0.241
#   Node 15: estimated_f=11.68, c=48.60, ratio=0.240
#   Node 11: estimated_f=18.09, c=79.69, ratio=0.227
#   Node 9: estimated_f=18.21, c=82.73, ratio=0.220
#   Node 4: estimated_f=15.39, c=70.48, ratio=0.218
#   Node 5: estimated_f=21.07, c=98.22, ratio=0.215
#   Node 12: estimated_f=12.49, c=58.67, ratio=0.213
#   Node 95: estimated_f=1.17, c=5.50, ratio=0.213
#   Node 8: estimated_f=18.55, c=88.01, ratio=0.211
#   Node 19: estimated_f=9.99, c=50.06, ratio=0.199
#   Node 33: estimated_f=7.31, c=36.83, ratio=0.198
# Selected 20 candidates via RR sets
# → adaptive K_B = 16 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 100
# → K_B = 16; launching 16 diverse subRuns
#
# SubPOMC 90: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 90:   2% 196/12800 [00:05<05:20, 39.38it/s]SubPOMC 99: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 99:  12% 1546/12800 [00:44<05:31, 33.92it/s]SubPOMC 96: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 90:  23% 2971/12800 [01:19<04:36, 35.54it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 90: 100% 12800/12800 [05:42<00:00, 37.36it/s]
#
# >>> Subproblem 4/16 completed <<<
# SubPOMC 99: 100% 12800/12800 [05:53<00:00, 36.22it/s]
#
# >>> Subproblem 2/16 completed <<<
# SubPOMC 96: 100% 12800/12800 [05:42<00:00, 37.38it/s]
#
# >>> Subproblem 3/16 completed <<<
# SubPOMC 1: 100% 12800/12800 [07:03<00:00, 30.25it/s]
#
# >>> Subproblem 1/16 completed <<<
# SubPOMC 98: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  14% 1733/12800 [00:46<04:51, 37.96it/s]SubPOMC 94: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  15% 1958/12800 [00:53<04:08, 43.71it/s]SubPOMC 97: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98:  40% 5066/12800 [02:15<03:02, 42.42it/s]SubPOMC 92: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 98: 100% 12800/12800 [05:33<00:00, 38.33it/s]
#
# >>> Subproblem 5/16 completed <<<
# SubPOMC 97: 100% 12800/12800 [05:46<00:00, 36.93it/s]
#
# SubPOMC 92:  72% 9157/12800 [04:24<01:30, 40.24it/s]
# SubPOMC 94: 100% 12800/12800 [05:56<00:00, 35.89it/s]
#
# >>> Subproblem 6/16 completed <<<
# SubPOMC 92: 100% 12800/12800 [06:07<00:00, 34.85it/s]
#
# >>> Subproblem 8/16 completed <<<
# SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  15% 1947/12800 [00:55<05:20, 33.84it/s]SubPOMC 33: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 33:   2% 317/12800 [00:09<05:32, 37.50it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95:  56% 7228/12800 [03:21<02:11, 42.26it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 12800/12800 [05:45<00:00, 37.04it/s]
# SubPOMC 33:  76% 9779/12800 [04:49<01:20, 37.35it/s]
# >>> Subproblem 9/16 completed <<<
# SubPOMC 33: 100% 12800/12800 [06:21<00:00, 33.53it/s]
#
# >>> Subproblem 11/16 completed <<<
# SubPOMC 4: 100% 12800/12800 [06:47<00:00, 31.44it/s]
#
# >>> Subproblem 10/16 completed <<<
# SubPOMC 15: 100% 12800/12800 [06:14<00:00, 34.19it/s]
#
# >>> Subproblem 12/16 completed <<<
# SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 12:  19% 2484/12800 [01:15<05:17, 32.54it/s]SubPOMC 19: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 19:  22% 2819/12800 [01:21<04:46, 34.89it/s]SubPOMC 7: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 7:  25% 3141/12800 [01:37<05:19, 30.24it/s]SubPOMC 5: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 12: 100% 12800/12800 [06:38<00:00, 32.12it/s]
#
# >>> Subproblem 13/16 completed <<<
# SubPOMC 19: 100% 12800/12800 [06:03<00:00, 35.17it/s]
#
# >>> Subproblem 14/16 completed <<<
# SubPOMC 7: 100% 12800/12800 [06:37<00:00, 32.19it/s]
#
# >>> Subproblem 15/16 completed <<<
# SubPOMC 5: 100% 12800/12800 [07:02<00:00, 30.29it/s]
#
# >>> Subproblem 16/16 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 5705.3717 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 500 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 58.9',
    'value = 59.96',
    'value = 59.12'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 59.3267 sec, Std Dev: 0.5594 sec, CV: 0.94%

# %% [markdown]
# ---

# %% [markdown]
# **--------Time Analysis----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 5679.6528',
    'Elapsed time: 6094.6987',
    'Elapsed time: 5705.3717'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 5826.5744 sec, Std Dev: 232.5583 sec, CV: 3.99%
