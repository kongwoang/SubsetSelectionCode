# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOAdapt/
# Out:
# /content/drive/MyDrive/ML_Project/EPOAdapt

# %% [markdown]
# ### Probability 0.05
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [03:20<00:00, 896.73it/s]
# Built 179468 RR sets
#   Node 87: estimated_f=0.98, c=1.00, ratio=0.982
#   Node 129: estimated_f=1.01, c=2.01, ratio=0.501
#   Node 142: estimated_f=36.79, c=89.39, ratio=0.412
#   Node 4: estimated_f=33.49, c=83.43, ratio=0.401
#   Node 128: estimated_f=1.12, c=3.04, ratio=0.370
#   Node 14: estimated_f=25.85, c=74.92, ratio=0.345
#   Node 6: estimated_f=23.57, c=70.88, ratio=0.333
#   Node 22: estimated_f=19.69, c=61.64, ratio=0.319
#   Node 143: estimated_f=22.65, c=73.35, ratio=0.309
#   Node 21: estimated_f=28.59, c=92.75, ratio=0.308
#   Node 26: estimated_f=22.10, c=75.58, ratio=0.292
#   Node 112: estimated_f=1.10, c=3.79, ratio=0.290
#   Node 65: estimated_f=20.81, c=75.02, ratio=0.277
#   Node 25: estimated_f=24.40, c=88.37, ratio=0.276
#   Node 28: estimated_f=24.54, c=90.84, ratio=0.270
#   Node 95: estimated_f=11.60, c=43.66, ratio=0.266
#   Node 30: estimated_f=18.73, c=72.56, ratio=0.258
#   Node 117: estimated_f=1.17, c=4.55, ratio=0.257
#   Node 131: estimated_f=8.43, c=32.79, ratio=0.257
#   Node 32: estimated_f=21.43, c=85.70, ratio=0.250
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 142: Initialized with 17 seeds (20 singletons + greedy)
# SubPOMC 142:  13% 1369/10336 [00:19<01:38, 90.69it/s]SubPOMC 131: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 131:   5% 546/10336 [00:06<01:52, 86.66it/s]SubPOMC 117: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 117:   0% 36/10336 [00:00<03:43, 46.02it/s]SubPOMC 112: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 117: 100% 10336/10336 [01:38<00:00, 105.23it/s]
# SubPOMC 131:  89% 9158/10336 [01:44<00:12, 96.29it/s]
# >>> Subproblem 4/8 completed <<<
# SubPOMC 112: 100% 10336/10336 [01:44<00:00, 98.46it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 131: 100% 10336/10336 [01:58<00:00, 87.49it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 142: 100% 10336/10336 [02:24<00:00, 71.73it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 87: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 87:  12% 1242/10336 [00:11<01:10, 128.51it/s]SubPOMC 129: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 129:   2% 168/10336 [00:02<02:11, 77.16it/s]SubPOMC 128: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 129:  11% 1138/10336 [00:12<01:32, 99.02it/s] SubPOMC 6: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 10336/10336 [01:26<00:00, 120.01it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 129: 100% 10336/10336 [01:29<00:00, 115.96it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 128: 100% 10336/10336 [01:32<00:00, 111.98it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 6: 100% 10336/10336 [02:15<00:00, 76.46it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 519.6429 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [03:20<00:00, 895.66it/s]
# Built 179468 RR sets
#   Node 87: estimated_f=1.04, c=1.00, ratio=1.038
#   Node 129: estimated_f=1.07, c=2.01, ratio=0.532
#   Node 142: estimated_f=37.04, c=89.39, ratio=0.414
#   Node 4: estimated_f=34.29, c=83.43, ratio=0.411
#   Node 128: estimated_f=1.09, c=3.04, ratio=0.360
#   Node 14: estimated_f=26.25, c=74.92, ratio=0.350
#   Node 6: estimated_f=24.19, c=70.88, ratio=0.341
#   Node 22: estimated_f=20.27, c=61.64, ratio=0.329
#   Node 21: estimated_f=28.97, c=92.75, ratio=0.312
#   Node 143: estimated_f=22.90, c=73.35, ratio=0.312
#   Node 112: estimated_f=1.13, c=3.79, ratio=0.298
#   Node 26: estimated_f=22.12, c=75.58, ratio=0.293
#   Node 25: estimated_f=24.67, c=88.37, ratio=0.279
#   Node 65: estimated_f=20.85, c=75.02, ratio=0.278
#   Node 28: estimated_f=24.79, c=90.84, ratio=0.273
#   Node 95: estimated_f=11.80, c=43.66, ratio=0.270
#   Node 117: estimated_f=1.21, c=4.55, ratio=0.266
#   Node 131: estimated_f=8.64, c=32.79, ratio=0.264
#   Node 30: estimated_f=19.12, c=72.56, ratio=0.264
#   Node 32: estimated_f=21.56, c=85.70, ratio=0.252
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 142: Initialized with 18 seeds (20 singletons + greedy)
# SubPOMC 142:   5% 533/10336 [00:10<03:04, 53.08it/s]SubPOMC 131: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 142:  12% 1248/10336 [00:22<01:47, 84.80it/s]SubPOMC 117: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 117:   1% 52/10336 [00:00<03:14, 52.84it/s]SubPOMC 112: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 131: 100% 10336/10336 [01:43<00:00, 100.04it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 117: 100% 10336/10336 [01:35<00:00, 107.69it/s]
#
# SubPOMC 112: 100% 10336/10336 [01:34<00:00, 108.85it/s]
#
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 142: 100% 10336/10336 [02:26<00:00, 70.50it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 87: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 87:   0% 27/10336 [00:00<03:11, 53.95it/s]SubPOMC 129: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 87:   2% 219/10336 [00:02<01:38, 102.60it/s]SubPOMC 128: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 87:  24% 2515/10336 [00:25<01:09, 113.19it/s]SubPOMC 6: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 129: 100% 10336/10336 [01:26<00:00, 120.01it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 87: 100% 10336/10336 [01:28<00:00, 116.30it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 128: 100% 10336/10336 [01:33<00:00, 110.86it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 6: 100% 10336/10336 [02:25<00:00, 70.82it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 527.7200 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [03:20<00:00, 897.17it/s]
# Built 179468 RR sets
#   Node 87: estimated_f=0.97, c=1.00, ratio=0.971
#   Node 129: estimated_f=1.08, c=2.01, ratio=0.537
#   Node 142: estimated_f=36.98, c=89.39, ratio=0.414
#   Node 4: estimated_f=33.72, c=83.43, ratio=0.404
#   Node 128: estimated_f=1.11, c=3.04, ratio=0.367
#   Node 14: estimated_f=26.07, c=74.92, ratio=0.348
#   Node 6: estimated_f=23.78, c=70.88, ratio=0.336
#   Node 22: estimated_f=19.91, c=61.64, ratio=0.323
#   Node 143: estimated_f=22.63, c=73.35, ratio=0.309
#   Node 21: estimated_f=28.61, c=92.75, ratio=0.308
#   Node 112: estimated_f=1.12, c=3.79, ratio=0.296
#   Node 26: estimated_f=22.08, c=75.58, ratio=0.292
#   Node 65: estimated_f=20.97, c=75.02, ratio=0.279
#   Node 25: estimated_f=24.42, c=88.37, ratio=0.276
#   Node 28: estimated_f=24.71, c=90.84, ratio=0.272
#   Node 95: estimated_f=11.59, c=43.66, ratio=0.265
#   Node 30: estimated_f=19.19, c=72.56, ratio=0.265
#   Node 117: estimated_f=1.20, c=4.55, ratio=0.264
#   Node 131: estimated_f=8.54, c=32.79, ratio=0.260
#   Node 32: estimated_f=21.58, c=85.70, ratio=0.252
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 142: Initialized with 14 seeds (20 singletons + greedy)
# SubPOMC 142:  16% 1668/10336 [00:22<02:25, 59.73it/s]SubPOMC 117: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 117:   2% 191/10336 [00:03<02:14, 75.57it/s]SubPOMC 131: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 131:   1% 116/10336 [00:01<01:55, 88.21it/s]SubPOMC 112: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 117: 100% 10336/10336 [01:28<00:00, 116.28it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 112: 100% 10336/10336 [01:27<00:00, 117.46it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 131: 100% 10336/10336 [01:48<00:00, 95.46it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 142: 100% 10336/10336 [02:20<00:00, 73.80it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 87: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 87:   3% 317/10336 [00:04<01:43, 96.86it/s]SubPOMC 129: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 129:  16% 1688/10336 [00:15<01:08, 126.16it/s]SubPOMC 6: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 6:   1% 110/10336 [00:01<02:36, 65.16it/s]SubPOMC 128: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 10336/10336 [01:34<00:00, 109.03it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 129: 100% 10336/10336 [01:34<00:00, 109.34it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 128: 100% 10336/10336 [01:30<00:00, 113.99it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 6: 100% 10336/10336 [02:14<00:00, 77.13it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 503.2113 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 49.2',
    'value = 48.66',
    'value = 48.86'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 48.9067 sec, Std Dev: 0.2730 sec, CV: 0.56%

# %% [markdown]
# **----------Time Analysis 100------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 519.6429',
    'Elapsed time: 527.7200',
    'Elapsed time: 503.2113'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 516.8581 sec, Std Dev: 12.4894 sec, CV: 2.42%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 200
# ---

# %% [markdown]
# **--------Run 1----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:33<00:00, 899.10it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=1.00, c=1.00, ratio=1.003
#   Node 129: estimated_f=1.10, c=2.01, ratio=0.546
#   Node 142: estimated_f=36.84, c=89.39, ratio=0.412
#   Node 4: estimated_f=33.88, c=83.43, ratio=0.406
#   Node 0: estimated_f=43.77, c=117.26, ratio=0.373
#   Node 128: estimated_f=1.07, c=3.04, ratio=0.352
#   Node 14: estimated_f=25.95, c=74.92, ratio=0.346
#   Node 15: estimated_f=35.18, c=101.64, ratio=0.346
#   Node 6: estimated_f=23.83, c=70.88, ratio=0.336
#   Node 1: estimated_f=37.12, c=110.55, ratio=0.336
#   Node 8: estimated_f=33.70, c=102.68, ratio=0.328
#   Node 22: estimated_f=19.93, c=61.64, ratio=0.323
#   Node 20: estimated_f=32.21, c=102.05, ratio=0.316
#   Node 66: estimated_f=33.30, c=106.37, ratio=0.313
#   Node 143: estimated_f=22.91, c=73.35, ratio=0.312
#   Node 21: estimated_f=28.94, c=92.75, ratio=0.312
#   Node 3: estimated_f=43.17, c=143.03, ratio=0.302
#   Node 13: estimated_f=31.19, c=104.62, ratio=0.298
#   Node 112: estimated_f=1.13, c=3.79, ratio=0.297
#   Node 12: estimated_f=35.32, c=121.36, ratio=0.291
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3648, n = 152
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 0: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 0:  73% 10679/14592 [05:18<01:57, 33.33it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 87:  28% 4015/14592 [01:13<02:47, 63.06it/s]SubPOMC 129: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 129:   0% 33/14592 [00:00<06:53, 35.17it/s]SubPOMC 112: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 14592/14592 [07:13<00:00, 33.64it/s]
# SubPOMC 129:  13% 1938/14592 [00:42<04:24, 47.79it/s]
# >>> Subproblem 1/12 completed <<<
# SubPOMC 87: 100% 14592/14592 [03:44<00:00, 65.01it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 112: 100% 14592/14592 [03:20<00:00, 72.81it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 129: 100% 14592/14592 [04:22<00:00, 55.59it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 1: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 1:  12% 1776/14592 [00:54<06:52, 31.08it/s]SubPOMC 6: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 6:  21% 3101/14592 [01:29<04:41, 40.86it/s]SubPOMC 143: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 6:  54% 7843/14592 [03:47<02:34, 43.62it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 14592/14592 [07:11<00:00, 33.78it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 6: 100% 14592/14592 [06:59<00:00, 34.83it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 128: 100% 14592/14592 [03:18<00:00, 73.67it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 143: 100% 14592/14592 [06:40<00:00, 36.45it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 4: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 4:   0% 66/14592 [00:02<08:35, 28.17it/s]SubPOMC 14: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 14:   1% 203/14592 [00:06<07:23, 32.44it/s]SubPOMC 66: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 66:  12% 1800/14592 [00:52<06:51, 31.05it/s]SubPOMC 22: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 22: 100% 14592/14592 [05:45<00:00, 42.21it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 66: 100% 14592/14592 [06:48<00:00, 35.72it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 4: 100% 14592/14592 [07:12<00:00, 33.76it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 14: 100% 14592/14592 [07:23<00:00, 32.88it/s]
#
# >>> Subproblem 10/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2083.9359 seconds

# %% [markdown]
# **---------Run 2 Version--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:32<00:00, 901.66it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=1.04, c=1.00, ratio=1.044
#   Node 129: estimated_f=1.10, c=2.01, ratio=0.546
#   Node 142: estimated_f=36.96, c=89.39, ratio=0.413
#   Node 4: estimated_f=33.76, c=83.43, ratio=0.405
#   Node 0: estimated_f=43.62, c=117.26, ratio=0.372
#   Node 128: estimated_f=1.10, c=3.04, ratio=0.361
#   Node 15: estimated_f=35.32, c=101.64, ratio=0.347
#   Node 14: estimated_f=25.81, c=74.92, ratio=0.345
#   Node 1: estimated_f=37.02, c=110.55, ratio=0.335
#   Node 6: estimated_f=23.58, c=70.88, ratio=0.333
#   Node 8: estimated_f=33.70, c=102.68, ratio=0.328
#   Node 22: estimated_f=20.02, c=61.64, ratio=0.325
#   Node 20: estimated_f=32.40, c=102.05, ratio=0.317
#   Node 21: estimated_f=29.03, c=92.75, ratio=0.313
#   Node 66: estimated_f=32.94, c=106.37, ratio=0.310
#   Node 112: estimated_f=1.17, c=3.79, ratio=0.309
#   Node 143: estimated_f=22.66, c=73.35, ratio=0.309
#   Node 3: estimated_f=43.50, c=143.03, ratio=0.304
#   Node 13: estimated_f=31.15, c=104.62, ratio=0.298
#   Node 12: estimated_f=35.63, c=121.36, ratio=0.294
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3648, n = 152
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 0: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 0:  45% 6595/14592 [03:14<04:04, 32.73it/s]SubPOMC 87: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 87:  25% 3621/14592 [00:59<03:01, 60.39it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0:  61% 8884/14592 [04:22<03:00, 31.69it/s]SubPOMC 112: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 14592/14592 [03:18<00:00, 73.59it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 0: 100% 14592/14592 [07:20<00:00, 33.09it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 112: 100% 14592/14592 [03:09<00:00, 77.11it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 129: 100% 14592/14592 [03:37<00:00, 66.95it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 1: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 1:   0% 29/14592 [00:00<07:22, 32.88it/s]SubPOMC 143: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 143:   5% 679/14592 [00:18<04:52, 47.53it/s]SubPOMC 6: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 6:  69% 10077/14592 [04:30<01:55, 38.97it/s]SubPOMC 128: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 14592/14592 [06:26<00:00, 37.71it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 143: 100% 14592/14592 [06:47<00:00, 35.83it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 1: 100% 14592/14592 [07:05<00:00, 34.31it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 128: 100% 14592/14592 [03:38<00:00, 66.76it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 4: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 4:   1% 216/14592 [00:08<09:21, 25.61it/s]SubPOMC 14: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 14:  10% 1444/14592 [00:38<06:00, 36.45it/s]SubPOMC 21: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 4:  13% 1828/14592 [00:56<05:49, 36.54it/s]SubPOMC 22: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 14592/14592 [05:57<00:00, 40.82it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 4: 100% 14592/14592 [06:57<00:00, 34.97it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 21: 100% 14592/14592 [06:12<00:00, 39.17it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 22: 100% 14592/14592 [06:07<00:00, 39.67it/s]
#
# >>> Subproblem 9/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2040.5011 seconds

# %% [markdown]
# **----------Run 3-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:35<00:00, 888.62it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=1.02, c=1.00, ratio=1.015
#   Node 129: estimated_f=1.04, c=2.01, ratio=0.519
#   Node 142: estimated_f=36.85, c=89.39, ratio=0.412
#   Node 4: estimated_f=33.79, c=83.43, ratio=0.405
#   Node 0: estimated_f=43.91, c=117.26, ratio=0.375
#   Node 128: estimated_f=1.07, c=3.04, ratio=0.354
#   Node 14: estimated_f=25.98, c=74.92, ratio=0.347
#   Node 15: estimated_f=35.06, c=101.64, ratio=0.345
#   Node 1: estimated_f=37.01, c=110.55, ratio=0.335
#   Node 6: estimated_f=23.70, c=70.88, ratio=0.334
#   Node 8: estimated_f=33.89, c=102.68, ratio=0.330
#   Node 22: estimated_f=20.14, c=61.64, ratio=0.327
#   Node 20: estimated_f=32.21, c=102.05, ratio=0.316
#   Node 66: estimated_f=33.24, c=106.37, ratio=0.312
#   Node 143: estimated_f=22.86, c=73.35, ratio=0.312
#   Node 21: estimated_f=28.87, c=92.75, ratio=0.311
#   Node 3: estimated_f=43.38, c=143.03, ratio=0.303
#   Node 112: estimated_f=1.14, c=3.79, ratio=0.301
#   Node 13: estimated_f=31.00, c=104.62, ratio=0.296
#   Node 12: estimated_f=35.65, c=121.36, ratio=0.294
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3648, n = 152
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 0: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 0:  71% 10293/14592 [05:14<02:16, 31.43it/s]SubPOMC 87: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 0:  83% 12051/14592 [06:09<01:18, 32.46it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 87:  20% 2927/14592 [00:59<03:22, 57.47it/s]SubPOMC 112: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 14592/14592 [07:30<00:00, 32.41it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 87: 100% 14592/14592 [03:41<00:00, 65.76it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 129: 100% 14592/14592 [03:14<00:00, 75.08it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 112: 100% 14592/14592 [04:09<00:00, 58.56it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 6: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 6:   9% 1340/14592 [00:40<07:55, 27.86it/s]SubPOMC 143: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 6:  18% 2638/14592 [01:19<06:37, 30.10it/s]SubPOMC 22: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 6:  51% 7437/14592 [03:40<03:23, 35.09it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 143: 100% 14592/14592 [05:36<00:00, 43.31it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 128: 100% 14592/14592 [03:12<00:00, 75.77it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 22: 100% 14592/14592 [05:54<00:00, 41.21it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 6: 100% 14592/14592 [07:14<00:00, 33.62it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 1: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 1:  12% 1816/14592 [00:49<05:48, 36.66it/s]SubPOMC 4: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 4:   2% 352/14592 [00:11<07:40, 30.95it/s]SubPOMC 66: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 1:  18% 2625/14592 [01:12<05:16, 37.83it/s]SubPOMC 14: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 14592/14592 [06:46<00:00, 35.90it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 66: 100% 14592/14592 [06:28<00:00, 37.57it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 4: 100% 14592/14592 [06:51<00:00, 35.42it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 14: 100% 14592/14592 [06:42<00:00, 36.22it/s]
#
# >>> Subproblem 10/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2040.4542 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 200 Results--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 65.88',
    'value = 65.24',
    'value = 66.62'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 65.9133 sec, Std Dev: 0.6906 sec, CV: 1.05%

# %% [markdown]
# **--------Time Analysis 200----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 2083.9359',
    'Elapsed time: 2040.5011',
    'Elapsed time: 2040.4542'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 2054.9637 sec, Std Dev: 25.0906 sec, CV: 1.22%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 300
# ---

# %% [markdown]
# **--------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:36<00:00, 886.18it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=1.00, c=1.00, ratio=1.005
#   Node 129: estimated_f=1.02, c=2.01, ratio=0.508
#   Node 142: estimated_f=36.98, c=89.39, ratio=0.414
#   Node 4: estimated_f=34.10, c=83.43, ratio=0.409
#   Node 128: estimated_f=1.14, c=3.04, ratio=0.375
#   Node 0: estimated_f=43.75, c=117.26, ratio=0.373
#   Node 15: estimated_f=35.53, c=101.64, ratio=0.350
#   Node 14: estimated_f=25.94, c=74.92, ratio=0.346
#   Node 6: estimated_f=24.09, c=70.88, ratio=0.340
#   Node 1: estimated_f=37.19, c=110.55, ratio=0.336
#   Node 8: estimated_f=33.68, c=102.68, ratio=0.328
#   Node 22: estimated_f=20.08, c=61.64, ratio=0.326
#   Node 20: estimated_f=32.38, c=102.05, ratio=0.317
#   Node 66: estimated_f=33.19, c=106.37, ratio=0.312
#   Node 21: estimated_f=28.94, c=92.75, ratio=0.312
#   Node 143: estimated_f=22.81, c=73.35, ratio=0.311
#   Node 3: estimated_f=43.38, c=143.03, ratio=0.303
#   Node 13: estimated_f=31.36, c=104.62, ratio=0.300
#   Node 112: estimated_f=1.13, c=3.79, ratio=0.297
#   Node 12: estimated_f=35.77, c=121.36, ratio=0.295
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 4408, n = 152
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 0: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 0:  56% 9862/17632 [07:23<05:58, 21.70it/s]SubPOMC 112: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0:  61% 10810/17632 [08:04<04:07, 27.54it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 112:  26% 4530/17632 [01:48<05:23, 40.50it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 17632/17632 [13:06<00:00, 22.43it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 87: 100% 17632/17632 [04:58<00:00, 59.00it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 112: 100% 17632/17632 [06:55<00:00, 42.47it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 129: 100% 17632/17632 [07:03<00:00, 41.60it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 1: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 1:  48% 8417/17632 [05:07<06:17, 24.43it/s]SubPOMC 143: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 143:   2% 286/17632 [00:09<10:15, 28.19it/s]SubPOMC 6: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 1:  60% 10610/17632 [06:26<04:01, 29.06it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 17632/17632 [10:56<00:00, 26.86it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 128: 100% 17632/17632 [06:33<00:00, 44.84it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 143: 100% 17632/17632 [10:05<00:00, 29.14it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 6: 100% 17632/17632 [10:04<00:00, 29.15it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 14: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 14:  32% 5717/17632 [02:58<04:59, 39.78it/s]SubPOMC 66: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 14:  39% 6964/17632 [03:38<06:18, 28.22it/s]SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 22:  40% 7117/17632 [04:05<06:01, 29.05it/s]SubPOMC 4: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 17632/17632 [09:16<00:00, 31.70it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 66: 100% 17632/17632 [10:12<00:00, 28.81it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 22: 100% 17632/17632 [09:46<00:00, 30.08it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 4: 100% 17632/17632 [11:50<00:00, 24.81it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 21: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 21:  19% 3268/17632 [01:52<09:14, 25.92it/s]SubPOMC 8: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 21: 100% 17632/17632 [09:53<00:00, 29.71it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 8: 100% 17632/17632 [10:02<00:00, 29.25it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 6333.8498 seconds

# %% [markdown]
# **----------Run 2 -----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:33<00:00, 897.50it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=0.97, c=1.00, ratio=0.965
#   Node 129: estimated_f=1.05, c=2.01, ratio=0.522
#   Node 142: estimated_f=36.80, c=89.39, ratio=0.412
#   Node 4: estimated_f=33.94, c=83.43, ratio=0.407
#   Node 128: estimated_f=1.15, c=3.04, ratio=0.377
#   Node 0: estimated_f=43.96, c=117.26, ratio=0.375
#   Node 14: estimated_f=26.23, c=74.92, ratio=0.350
#   Node 15: estimated_f=35.48, c=101.64, ratio=0.349
#   Node 1: estimated_f=37.15, c=110.55, ratio=0.336
#   Node 6: estimated_f=23.72, c=70.88, ratio=0.335
#   Node 8: estimated_f=33.71, c=102.68, ratio=0.328
#   Node 22: estimated_f=19.99, c=61.64, ratio=0.324
#   Node 20: estimated_f=32.22, c=102.05, ratio=0.316
#   Node 21: estimated_f=29.00, c=92.75, ratio=0.313
#   Node 66: estimated_f=33.04, c=106.37, ratio=0.311
#   Node 143: estimated_f=22.69, c=73.35, ratio=0.309
#   Node 3: estimated_f=43.51, c=143.03, ratio=0.304
#   Node 13: estimated_f=31.40, c=104.62, ratio=0.300
#   Node 112: estimated_f=1.12, c=3.79, ratio=0.296
#   Node 12: estimated_f=35.76, c=121.36, ratio=0.295
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 4408, n = 152
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 0: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 0:  65% 11443/17632 [07:55<04:14, 24.34it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:   9% 1505/17632 [00:41<06:15, 42.91it/s]SubPOMC 112: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:  27% 4830/17632 [01:47<03:07, 68.40it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 17632/17632 [11:59<00:00, 24.51it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 129: 100% 17632/17632 [05:13<00:00, 56.29it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 112: 100% 17632/17632 [04:41<00:00, 62.56it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 87: 100% 17632/17632 [05:31<00:00, 53.21it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 1: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 1:  37% 6518/17632 [04:20<06:37, 27.95it/s]SubPOMC 143: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 1:  46% 8108/17632 [05:20<06:27, 24.55it/s]SubPOMC 6: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 6:  26% 4631/17632 [02:37<07:15, 29.85it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 17632/17632 [11:10<00:00, 26.30it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 128: 100% 17632/17632 [05:01<00:00, 58.44it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 143: 100% 17632/17632 [10:01<00:00, 29.29it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 6: 100% 17632/17632 [09:46<00:00, 30.05it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 66: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 66:   9% 1601/17632 [00:59<09:57, 26.84it/s]SubPOMC 14: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 66:  13% 2284/17632 [01:24<09:27, 27.04it/s]SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  56% 9787/17632 [05:31<04:48, 27.21it/s]SubPOMC 4: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 22: 100% 17632/17632 [08:58<00:00, 32.76it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 66: 100% 17632/17632 [10:35<00:00, 27.74it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 14: 100% 17632/17632 [09:45<00:00, 30.12it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 4: 100% 17632/17632 [10:32<00:00, 27.88it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 8: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 8:   8% 1488/17632 [00:51<07:58, 33.74it/s]SubPOMC 21: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 17632/17632 [09:27<00:00, 31.08it/s]
#
# >>> Subproblem 14/14 completed <<<
# SubPOMC 21: 100% 17632/17632 [10:09<00:00, 28.94it/s]
#
# >>> Subproblem 13/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 6225.0916 seconds

# %% [markdown]
# **----------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:30<00:00, 909.45it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=0.99, c=1.00, ratio=0.993
#   Node 129: estimated_f=1.13, c=2.01, ratio=0.562
#   Node 142: estimated_f=37.00, c=89.39, ratio=0.414
#   Node 4: estimated_f=33.74, c=83.43, ratio=0.404
#   Node 0: estimated_f=43.93, c=117.26, ratio=0.375
#   Node 128: estimated_f=1.12, c=3.04, ratio=0.369
#   Node 14: estimated_f=25.99, c=74.92, ratio=0.347
#   Node 15: estimated_f=35.20, c=101.64, ratio=0.346
#   Node 1: estimated_f=37.11, c=110.55, ratio=0.336
#   Node 6: estimated_f=23.66, c=70.88, ratio=0.334
#   Node 8: estimated_f=33.65, c=102.68, ratio=0.328
#   Node 22: estimated_f=19.95, c=61.64, ratio=0.324
#   Node 20: estimated_f=32.36, c=102.05, ratio=0.317
#   Node 21: estimated_f=28.96, c=92.75, ratio=0.312
#   Node 66: estimated_f=33.21, c=106.37, ratio=0.312
#   Node 143: estimated_f=22.69, c=73.35, ratio=0.309
#   Node 3: estimated_f=43.48, c=143.03, ratio=0.304
#   Node 13: estimated_f=31.04, c=104.62, ratio=0.297
#   Node 12: estimated_f=35.51, c=121.36, ratio=0.293
#   Node 26: estimated_f=21.96, c=75.58, ratio=0.291
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 4408, n = 152
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 0: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 0:  69% 12227/17632 [07:48<03:15, 27.60it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128:  16% 2752/17632 [01:29<06:25, 38.59it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0:  84% 14853/17632 [09:35<01:53, 24.52it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 17632/17632 [11:29<00:00, 25.58it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 128: 100% 17632/17632 [06:13<00:00, 47.24it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 87: 100% 17632/17632 [05:31<00:00, 53.26it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 129: 100% 17632/17632 [06:40<00:00, 43.99it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 1: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 1:  20% 3503/17632 [02:19<07:35, 31.02it/s]SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  34% 5990/17632 [03:15<05:22, 36.08it/s]SubPOMC 143: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  50% 8862/17632 [04:49<05:27, 26.77it/s]SubPOMC 22: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 17632/17632 [11:41<00:00, 25.13it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 6: 100% 17632/17632 [09:51<00:00, 29.80it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 143: 100% 17632/17632 [10:00<00:00, 29.37it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 22: 100% 17632/17632 [09:32<00:00, 30.80it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  24% 4316/17632 [02:24<08:07, 27.30it/s]SubPOMC 26: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 14:  26% 4625/17632 [02:34<07:14, 29.91it/s]SubPOMC 66: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 14:  34% 6019/17632 [03:21<06:24, 30.24it/s]SubPOMC 4: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 17632/17632 [10:13<00:00, 28.73it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 26: 100% 17632/17632 [09:49<00:00, 29.89it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 66: 100% 17632/17632 [10:42<00:00, 27.44it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 4: 100% 17632/17632 [11:00<00:00, 26.70it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 21: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 21:  26% 4665/17632 [02:32<06:53, 31.33it/s]SubPOMC 8: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 21: 100% 17632/17632 [09:43<00:00, 30.22it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 8: 100% 17632/17632 [10:28<00:00, 28.07it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 6304.5563 seconds

# %% [markdown]
# ---

# %% [markdown]
# **----------Budget 300 Results-----------**

# %%
# The result strings
results = [
    'value = 79.9',
    'value = 80.2',
    'value = 79.4'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 79.8333 sec, Std Dev: 0.4041 sec, CV: 0.51%

# %% [markdown]
# **---------Time Analysis 300------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 6333.8498',
    'Elapsed time: 6225.0916',
    'Elapsed time: 6304.5563'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 6287.8326 sec, Std Dev: 56.2748 sec, CV: 0.89%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 400
# ---

# %% [markdown]
# **-----------Run 1-----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 400.0 EPOAdapt 4
# 34
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:30<00:00, 909.54it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=0.98, c=1.00, ratio=0.981
#   Node 129: estimated_f=1.05, c=2.01, ratio=0.522
#   Node 142: estimated_f=36.75, c=89.39, ratio=0.411
#   Node 4: estimated_f=33.64, c=83.43, ratio=0.403
#   Node 0: estimated_f=43.78, c=117.26, ratio=0.373
#   Node 128: estimated_f=1.10, c=3.04, ratio=0.364
#   Node 15: estimated_f=35.25, c=101.64, ratio=0.347
#   Node 14: estimated_f=25.86, c=74.92, ratio=0.345
#   Node 6: estimated_f=23.76, c=70.88, ratio=0.335
#   Node 1: estimated_f=36.93, c=110.55, ratio=0.334
#   Node 8: estimated_f=33.57, c=102.68, ratio=0.327
#   Node 22: estimated_f=20.05, c=61.64, ratio=0.325
#   Node 20: estimated_f=32.39, c=102.05, ratio=0.317
#   Node 21: estimated_f=28.76, c=92.75, ratio=0.310
#   Node 66: estimated_f=32.93, c=106.37, ratio=0.310
#   Node 143: estimated_f=22.67, c=73.35, ratio=0.309
#   Node 112: estimated_f=1.16, c=3.79, ratio=0.306
#   Node 3: estimated_f=43.43, c=143.03, ratio=0.304
#   Node 13: estimated_f=31.16, c=104.62, ratio=0.298
#   Node 12: estimated_f=35.59, c=121.36, ratio=0.293
# Selected 20 candidates via RR sets
# → adaptive K_B = 17 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 5168, n = 152
# → K_B = 17; launching 17 diverse subRuns
#
# SubPOMC 0: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0:   0% 77/20672 [00:03<14:05, 24.35it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0:   8% 1665/20672 [01:16<12:26, 25.45it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 0:  10% 2024/20672 [01:33<15:07, 20.54it/s]SubPOMC 112: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129: 100% 20672/20672 [11:23<00:00, 30.24it/s]
#
# >>> Subproblem 4/17 completed <<<
# SubPOMC 87: 100% 20672/20672 [10:38<00:00, 32.36it/s]
#
# >>> Subproblem 3/17 completed <<<
# SubPOMC 112: 100% 20672/20672 [10:48<00:00, 31.86it/s]
#
# >>> Subproblem 2/17 completed <<<
# SubPOMC 0: 100% 20672/20672 [15:44<00:00, 21.89it/s]
#
# >>> Subproblem 1/17 completed <<<
# SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:   5% 1105/20672 [00:46<12:11, 26.75it/s]SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 22:  37% 7624/20672 [04:57<08:41, 25.03it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  52% 10786/20672 [07:02<07:26, 22.12it/s]SubPOMC 143: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 20672/20672 [13:52<00:00, 24.84it/s]
#
# >>> Subproblem 6/17 completed <<<
# SubPOMC 22: 100% 20672/20672 [13:13<00:00, 26.06it/s]
#
# >>> Subproblem 7/17 completed <<<
# SubPOMC 128: 100% 20672/20672 [11:22<00:00, 30.28it/s]
#
# >>> Subproblem 5/17 completed <<<
# SubPOMC 143: 100% 20672/20672 [13:14<00:00, 26.00it/s]
#
# >>> Subproblem 8/17 completed <<<
# SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:   4% 754/20672 [00:31<13:14, 25.07it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  37% 7706/20672 [05:13<09:55, 21.76it/s]SubPOMC 66: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66:   5% 1040/20672 [00:40<11:40, 28.03it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 20672/20672 [13:16<00:00, 25.94it/s]
#
# >>> Subproblem 10/17 completed <<<
# SubPOMC 1: 100% 20672/20672 [14:24<00:00, 23.91it/s]
#
# >>> Subproblem 9/17 completed <<<
# SubPOMC 66: 100% 20672/20672 [14:00<00:00, 24.60it/s]
#
# >>> Subproblem 12/17 completed <<<
# SubPOMC 4: 100% 20672/20672 [15:16<00:00, 22.55it/s]
#
# >>> Subproblem 11/17 completed <<<
# SubPOMC 21: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21:  25% 5271/20672 [03:35<13:43, 18.71it/s]SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21:  58% 12061/20672 [08:30<05:59, 23.94it/s]SubPOMC 13: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21:  97% 20059/20672 [14:21<00:24, 25.17it/s]SubPOMC 142: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21: 100% 20672/20672 [14:48<00:00, 23.26it/s]
#
# >>> Subproblem 13/17 completed <<<
# SubPOMC 8: 100% 20672/20672 [14:46<00:00, 23.31it/s]
#
# >>> Subproblem 14/17 completed <<<
# SubPOMC 13: 100% 20672/20672 [14:26<00:00, 23.87it/s]
#
# >>> Subproblem 15/17 completed <<<
# SubPOMC 142: 100% 20672/20672 [13:46<00:00, 25.02it/s]
#
# >>> Subproblem 16/17 completed <<<
# SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 20672/20672 [14:07<00:00, 24.40it/s]
#
# >>> Subproblem 17/17 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 13036.0025 seconds

# %% [markdown]
# **----------Run 2 ------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 400.0 EPOAdapt 4
# 34
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:28<00:00, 917.91it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=1.05, c=1.00, ratio=1.050
#   Node 129: estimated_f=1.00, c=2.01, ratio=0.499
#   Node 142: estimated_f=36.87, c=89.39, ratio=0.412
#   Node 4: estimated_f=33.79, c=83.43, ratio=0.405
#   Node 128: estimated_f=1.17, c=3.04, ratio=0.386
#   Node 0: estimated_f=43.57, c=117.26, ratio=0.372
#   Node 15: estimated_f=35.28, c=101.64, ratio=0.347
#   Node 14: estimated_f=25.94, c=74.92, ratio=0.346
#   Node 1: estimated_f=37.07, c=110.55, ratio=0.335
#   Node 6: estimated_f=23.68, c=70.88, ratio=0.334
#   Node 8: estimated_f=33.79, c=102.68, ratio=0.329
#   Node 22: estimated_f=20.06, c=61.64, ratio=0.325
#   Node 20: estimated_f=32.56, c=102.05, ratio=0.319
#   Node 66: estimated_f=33.20, c=106.37, ratio=0.312
#   Node 143: estimated_f=22.88, c=73.35, ratio=0.312
#   Node 21: estimated_f=28.82, c=92.75, ratio=0.311
#   Node 3: estimated_f=43.62, c=143.03, ratio=0.305
#   Node 13: estimated_f=31.13, c=104.62, ratio=0.298
#   Node 26: estimated_f=22.15, c=75.58, ratio=0.293
#   Node 12: estimated_f=35.33, c=121.36, ratio=0.291
# Selected 20 candidates via RR sets
# → adaptive K_B = 17 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 5168, n = 152
# → K_B = 17; launching 17 diverse subRuns
#
# SubPOMC 3: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 3:  36% 7501/20672 [05:02<08:56, 24.54it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128:   7% 1479/20672 [00:55<11:15, 28.41it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:  24% 5033/20672 [02:38<07:46, 33.52it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 3: 100% 20672/20672 [13:56<00:00, 24.70it/s]
#
# >>> Subproblem 1/17 completed <<<
# SubPOMC 129: 100% 20672/20672 [10:35<00:00, 32.55it/s]
#
# >>> Subproblem 4/17 completed <<<
# SubPOMC 128: 100% 20672/20672 [12:03<00:00, 28.57it/s]
#
# >>> Subproblem 3/17 completed <<<
# SubPOMC 87: 100% 20672/20672 [10:18<00:00, 33.45it/s]
#
# >>> Subproblem 2/17 completed <<<
# SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  16% 3331/20672 [02:05<08:54, 32.43it/s]SubPOMC 143: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 143:   3% 566/20672 [00:23<14:39, 22.85it/s]SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  61% 12637/20672 [07:52<05:29, 24.40it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 20672/20672 [13:11<00:00, 26.10it/s]
#
# >>> Subproblem 5/17 completed <<<
# SubPOMC 22: 100% 20672/20672 [12:58<00:00, 26.55it/s]
#
# >>> Subproblem 6/17 completed <<<
# SubPOMC 143: 100% 20672/20672 [13:45<00:00, 25.05it/s]
#
# >>> Subproblem 7/17 completed <<<
# SubPOMC 1: 100% 20672/20672 [14:10<00:00, 24.31it/s]
#
# >>> Subproblem 8/17 completed <<<
# SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8:  35% 7305/20672 [05:11<07:34, 29.43it/s]SubPOMC 66: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8:  40% 8357/20672 [05:57<10:57, 18.72it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8:  41% 8444/20672 [06:01<09:14, 22.04it/s]SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 20672/20672 [15:09<00:00, 22.73it/s]
# SubPOMC 14:  66% 13685/20672 [09:08<04:35, 25.36it/s]
# >>> Subproblem 9/17 completed <<<
# SubPOMC 66: 100% 20672/20672 [14:19<00:00, 24.05it/s]
#
# >>> Subproblem 12/17 completed <<<
# SubPOMC 14: 100% 20672/20672 [13:48<00:00, 24.95it/s]
#
# >>> Subproblem 10/17 completed <<<
# SubPOMC 4: 100% 20672/20672 [14:17<00:00, 24.10it/s]
#
# >>> Subproblem 11/17 completed <<<
# SubPOMC 26: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 26:  16% 3232/20672 [01:54<10:30, 27.64it/s]SubPOMC 13: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 26:  34% 7078/20672 [04:11<09:32, 23.76it/s]SubPOMC 21: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 26:  89% 18445/20672 [10:52<01:11, 31.16it/s]SubPOMC 142: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 26: 100% 20672/20672 [12:10<00:00, 28.29it/s]
#
# >>> Subproblem 13/17 completed <<<
# SubPOMC 13: 100% 20672/20672 [14:40<00:00, 23.47it/s]
#
# >>> Subproblem 15/17 completed <<<
# SubPOMC 21: 100% 20672/20672 [13:59<00:00, 24.63it/s]
#
# >>> Subproblem 14/17 completed <<<
# SubPOMC 142: 100% 20672/20672 [15:10<00:00, 22.70it/s]
#
# >>> Subproblem 16/17 completed <<<
# SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 20672/20672 [14:22<00:00, 23.98it/s]
#
# >>> Subproblem 17/17 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 12802.8393 seconds

# %% [markdown]
# **-------------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 400.0 EPOAdapt 4
# 34
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:34<00:00, 893.82it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=1.02, c=1.00, ratio=1.024
#   Node 129: estimated_f=1.09, c=2.01, ratio=0.541
#   Node 142: estimated_f=37.01, c=89.39, ratio=0.414
#   Node 4: estimated_f=33.89, c=83.43, ratio=0.406
#   Node 0: estimated_f=43.75, c=117.26, ratio=0.373
#   Node 128: estimated_f=1.09, c=3.04, ratio=0.360
#   Node 15: estimated_f=35.77, c=101.64, ratio=0.352
#   Node 14: estimated_f=26.15, c=74.92, ratio=0.349
#   Node 1: estimated_f=37.36, c=110.55, ratio=0.338
#   Node 6: estimated_f=23.77, c=70.88, ratio=0.335
#   Node 8: estimated_f=34.00, c=102.68, ratio=0.331
#   Node 22: estimated_f=20.29, c=61.64, ratio=0.329
#   Node 20: estimated_f=32.47, c=102.05, ratio=0.318
#   Node 21: estimated_f=29.13, c=92.75, ratio=0.314
#   Node 66: estimated_f=33.04, c=106.37, ratio=0.311
#   Node 143: estimated_f=22.76, c=73.35, ratio=0.310
#   Node 3: estimated_f=43.58, c=143.03, ratio=0.305
#   Node 13: estimated_f=31.27, c=104.62, ratio=0.299
#   Node 12: estimated_f=35.74, c=121.36, ratio=0.295
#   Node 2: estimated_f=44.13, c=151.02, ratio=0.292
# Selected 20 candidates via RR sets
# → adaptive K_B = 17 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 5168, n = 152
# → K_B = 17; launching 17 diverse subRuns
#
# SubPOMC 2: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 2:  32% 6671/20672 [04:41<07:34, 30.83it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 2:  41% 8435/20672 [05:54<08:40, 23.50it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 87:  11% 2316/20672 [01:25<09:52, 31.00it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 2: 100% 20672/20672 [14:42<00:00, 23.43it/s]
#
# >>> Subproblem 1/17 completed <<<
# SubPOMC 87: 100% 20672/20672 [11:49<00:00, 29.14it/s]
#
# >>> Subproblem 2/17 completed <<<
# SubPOMC 128: 100% 20672/20672 [10:37<00:00, 32.42it/s]
#
# >>> Subproblem 3/17 completed <<<
# SubPOMC 129: 100% 20672/20672 [12:09<00:00, 28.32it/s]
#
# >>> Subproblem 4/17 completed <<<
# SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  12% 2469/20672 [01:41<11:24, 26.60it/s]SubPOMC 143: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  15% 3164/20672 [02:10<12:36, 23.14it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:  19% 3945/20672 [02:42<12:50, 21.70it/s]SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6: 100% 20672/20672 [14:29<00:00, 23.76it/s]
#
# >>> Subproblem 7/17 completed <<<
# SubPOMC 143: 100% 20672/20672 [14:28<00:00, 23.80it/s]
#
# >>> Subproblem 5/17 completed <<<
# SubPOMC 1: 100% 20672/20672 [14:54<00:00, 23.12it/s]
#
# >>> Subproblem 8/17 completed <<<
# SubPOMC 22: 100% 20672/20672 [12:26<00:00, 27.68it/s]
#
# >>> Subproblem 6/17 completed <<<
# SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8:  14% 2869/20672 [02:04<11:38, 25.51it/s]SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  17% 3531/20672 [02:32<11:26, 24.98it/s]SubPOMC 66: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  20% 4167/20672 [02:58<11:51, 23.19it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 20672/20672 [14:57<00:00, 23.03it/s]
#
# >>> Subproblem 9/17 completed <<<
# SubPOMC 14: 100% 20672/20672 [14:29<00:00, 23.78it/s]
#
# >>> Subproblem 10/17 completed <<<
# SubPOMC 66: 100% 20672/20672 [14:32<00:00, 23.69it/s]
#
# >>> Subproblem 12/17 completed <<<
# SubPOMC 4: 100% 20672/20672 [15:07<00:00, 22.79it/s]
#
# >>> Subproblem 11/17 completed <<<
# SubPOMC 13: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 13:   8% 1593/20672 [01:07<12:49, 24.79it/s]SubPOMC 21: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21:  53% 10940/20672 [08:01<07:17, 22.23it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21:  66% 13705/20672 [10:07<05:04, 22.87it/s]SubPOMC 142: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 13: 100% 20672/20672 [13:52<00:00, 24.83it/s]
#
# >>> Subproblem 14/17 completed <<<
# SubPOMC 21: 100% 20672/20672 [15:15<00:00, 22.58it/s]
#
# >>> Subproblem 13/17 completed <<<
# SubPOMC 15: 100% 20672/20672 [14:20<00:00, 24.02it/s]
#
# >>> Subproblem 16/17 completed <<<
# SubPOMC 142: 100% 20672/20672 [14:34<00:00, 23.63it/s]
#
# >>> Subproblem 15/17 completed <<<
# SubPOMC 12: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 12: 100% 20672/20672 [14:35<00:00, 23.61it/s]
#
# >>> Subproblem 17/17 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 13232.7666 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 400 Results-----------**

# %%
# The result strings
results = [
    'value = 85.22',
    'value = 85.64',
    'value = 85.94'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Total Time", total_accumulated_values)
# Out:
# Total Time - Mean: 85.6000 sec, Std Dev: 0.3617 sec, CV: 0.42%

# %% [markdown]
# **--------Time Analysis 400------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 13036.0025',
    'Elapsed time: 12802.8393',
    'Elapsed time: 13232.7666'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 13023.8695 sec, Std Dev: 215.2203 sec, CV: 1.65%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 500
# ---

# %% [markdown]
# **------------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 500.0 EPOAdapt 4
# 38
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:38<00:00, 878.67it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=0.98, c=1.00, ratio=0.982
#   Node 129: estimated_f=1.05, c=2.01, ratio=0.524
#   Node 142: estimated_f=36.79, c=89.39, ratio=0.412
#   Node 4: estimated_f=33.67, c=83.43, ratio=0.404
#   Node 0: estimated_f=43.83, c=117.26, ratio=0.374
#   Node 128: estimated_f=1.13, c=3.04, ratio=0.371
#   Node 14: estimated_f=26.11, c=74.92, ratio=0.349
#   Node 15: estimated_f=35.27, c=101.64, ratio=0.347
#   Node 1: estimated_f=37.22, c=110.55, ratio=0.337
#   Node 6: estimated_f=23.70, c=70.88, ratio=0.334
#   Node 8: estimated_f=33.80, c=102.68, ratio=0.329
#   Node 22: estimated_f=20.14, c=61.64, ratio=0.327
#   Node 20: estimated_f=32.26, c=102.05, ratio=0.316
#   Node 143: estimated_f=22.86, c=73.35, ratio=0.312
#   Node 21: estimated_f=28.85, c=92.75, ratio=0.311
#   Node 66: estimated_f=33.08, c=106.37, ratio=0.311
#   Node 3: estimated_f=43.45, c=143.03, ratio=0.304
#   Node 13: estimated_f=31.18, c=104.62, ratio=0.298
#   Node 112: estimated_f=1.12, c=3.79, ratio=0.294
#   Node 12: estimated_f=35.54, c=121.36, ratio=0.293
# Selected 20 candidates via RR sets
# → adaptive K_B = 19 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 5776, n = 152
# → K_B = 19; launching 19 diverse subRuns
#
# SubPOMC 112: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 112:   1% 303/23104 [00:14<16:48, 22.61it/s]SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 112:   2% 396/23104 [00:18<21:22, 17.71it/s]SubPOMC 0: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:   5% 1125/23104 [00:51<16:32, 22.15it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129: 100% 23104/23104 [15:07<00:00, 25.46it/s]
#
# >>> Subproblem 4/19 completed <<<
# SubPOMC 112: 100% 23104/23104 [15:49<00:00, 24.34it/s]
#
# >>> Subproblem 2/19 completed <<<
# SubPOMC 87: 100% 23104/23104 [15:37<00:00, 24.64it/s]
#
# >>> Subproblem 3/19 completed <<<
# SubPOMC 0: 100% 23104/23104 [20:47<00:00, 18.53it/s]
#
# >>> Subproblem 1/19 completed <<<
# SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 1:   6% 1373/23104 [01:18<16:41, 21.70it/s]SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:   5% 1263/23104 [01:05<19:04, 19.09it/s]SubPOMC 143: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  13% 2986/23104 [02:33<16:08, 20.77it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128: 100% 23104/23104 [15:51<00:00, 24.29it/s]
#
# >>> Subproblem 5/19 completed <<<
# SubPOMC 6: 100% 23104/23104 [19:53<00:00, 19.36it/s]
#
# >>> Subproblem 6/19 completed <<<
# SubPOMC 1: 100% 23104/23104 [21:43<00:00, 17.73it/s]
#
# >>> Subproblem 7/19 completed <<<
# SubPOMC 143: 100% 23104/23104 [19:58<00:00, 19.27it/s]
#
# >>> Subproblem 8/19 completed <<<
# SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 22:   3% 682/23104 [00:36<22:30, 16.60it/s]SubPOMC 66: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 22:  13% 2967/23104 [02:41<17:44, 18.91it/s]SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66:  14% 3122/23104 [02:48<16:13, 20.52it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 22: 100% 23104/23104 [18:17<00:00, 21.04it/s]
#
# >>> Subproblem 9/19 completed <<<
# SubPOMC 66: 100% 23104/23104 [19:16<00:00, 19.97it/s]
#
# >>> Subproblem 12/19 completed <<<
# SubPOMC 14: 100% 23104/23104 [19:08<00:00, 20.12it/s]
#
# >>> Subproblem 10/19 completed <<<
# SubPOMC 4: 100% 23104/23104 [19:40<00:00, 19.57it/s]
#
# >>> Subproblem 11/19 completed <<<
# SubPOMC 21: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21:   3% 706/23104 [00:38<20:40, 18.06it/s]SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21:  25% 5835/23104 [05:13<14:37, 19.68it/s]SubPOMC 13: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 13:  27% 6193/23104 [05:34<15:00, 18.78it/s]SubPOMC 142: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 21: 100% 23104/23104 [21:11<00:00, 18.17it/s]
#
# >>> Subproblem 13/19 completed <<<
# SubPOMC 8: 100% 23104/23104 [21:24<00:00, 17.99it/s]
#
# >>> Subproblem 14/19 completed <<<
# SubPOMC 13: 100% 23104/23104 [20:56<00:00, 18.38it/s]
#
# >>> Subproblem 15/19 completed <<<
# SubPOMC 142: 100% 23104/23104 [21:36<00:00, 17.83it/s]
#
# >>> Subproblem 16/19 completed <<<
# SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:   9% 2103/23104 [01:45<15:44, 22.23it/s]SubPOMC 20: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:  15% 3553/23104 [02:56<18:45, 17.38it/s]SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 23104/23104 [20:01<00:00, 19.24it/s]
#
# >>> Subproblem 17/19 completed <<<
# SubPOMC 20: 100% 23104/23104 [20:17<00:00, 18.98it/s]
#
# >>> Subproblem 19/19 completed <<<
# SubPOMC 12: 100% 23104/23104 [19:37<00:00, 19.62it/s]
#
# >>> Subproblem 18/19 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 20332.2451 seconds

# %% [markdown]
# **------------Run 2 --------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 500.0 EPOAdapt 4
# 38
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:38<00:00, 879.31it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=0.95, c=1.00, ratio=0.954
#   Node 129: estimated_f=0.99, c=2.01, ratio=0.494
#   Node 142: estimated_f=36.88, c=89.39, ratio=0.413
#   Node 4: estimated_f=33.78, c=83.43, ratio=0.405
#   Node 128: estimated_f=1.13, c=3.04, ratio=0.374
#   Node 0: estimated_f=43.54, c=117.26, ratio=0.371
#   Node 15: estimated_f=35.16, c=101.64, ratio=0.346
#   Node 14: estimated_f=25.67, c=74.92, ratio=0.343
#   Node 1: estimated_f=37.01, c=110.55, ratio=0.335
#   Node 6: estimated_f=23.66, c=70.88, ratio=0.334
#   Node 8: estimated_f=33.51, c=102.68, ratio=0.326
#   Node 22: estimated_f=19.92, c=61.64, ratio=0.323
#   Node 20: estimated_f=32.05, c=102.05, ratio=0.314
#   Node 21: estimated_f=28.96, c=92.75, ratio=0.312
#   Node 143: estimated_f=22.83, c=73.35, ratio=0.311
#   Node 66: estimated_f=32.89, c=106.37, ratio=0.309
#   Node 112: estimated_f=1.17, c=3.79, ratio=0.307
#   Node 3: estimated_f=43.13, c=143.03, ratio=0.302
#   Node 13: estimated_f=31.03, c=104.62, ratio=0.297
#   Node 12: estimated_f=35.47, c=121.36, ratio=0.292
# Selected 20 candidates via RR sets
# → adaptive K_B = 19 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 5776, n = 152
# → K_B = 19; launching 19 diverse subRuns
#
# SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:   9% 2122/23104 [01:32<11:37, 30.07it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:  33% 7691/23104 [05:03<10:24, 24.67it/s]SubPOMC 112: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 87:  32% 7348/23104 [04:53<09:21, 28.06it/s]SubPOMC 0: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129: 100% 23104/23104 [14:39<00:00, 26.28it/s]
#
# >>> Subproblem 4/19 completed <<<
# SubPOMC 87: 100% 23104/23104 [15:16<00:00, 25.20it/s]
#
# >>> Subproblem 3/19 completed <<<
# SubPOMC 112: 100% 23104/23104 [14:54<00:00, 25.82it/s]
#
# >>> Subproblem 2/19 completed <<<
# SubPOMC 0: 100% 23104/23104 [21:27<00:00, 17.94it/s]
#
# >>> Subproblem 1/19 completed <<<
# SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128:  17% 3939/23104 [02:53<12:33, 25.43it/s]SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128:  50% 11511/23104 [08:01<07:55, 24.39it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:  63% 14608/23104 [12:12<07:31, 18.83it/s]SubPOMC 143: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128: 100% 23104/23104 [15:37<00:00, 24.64it/s]
#
# >>> Subproblem 5/19 completed <<<
# SubPOMC 6: 100% 23104/23104 [19:28<00:00, 19.78it/s]
#
# >>> Subproblem 6/19 completed <<<
# SubPOMC 1: 100% 23104/23104 [20:29<00:00, 18.80it/s]
#
# >>> Subproblem 7/19 completed <<<
# SubPOMC 143: 100% 23104/23104 [18:21<00:00, 20.98it/s]
#
# >>> Subproblem 8/19 completed <<<
# SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 22:  36% 8206/23104 [06:48<12:50, 19.32it/s]SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 22: 100% 23104/23104 [18:52<00:00, 20.41it/s]
#
# >>> Subproblem 9/19 completed <<<
# SubPOMC 14:  65% 14995/23104 [12:04<06:21, 21.28it/s]SubPOMC 21: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:  75% 17223/23104 [13:49<04:33, 21.52it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14: 100% 23104/23104 [18:35<00:00, 20.72it/s]
#
# >>> Subproblem 10/19 completed <<<
# SubPOMC 21: 100% 23104/23104 [19:00<00:00, 20.26it/s]
#
# >>> Subproblem 12/19 completed <<<
# SubPOMC 4: 100% 23104/23104 [20:42<00:00, 18.59it/s]
#
# >>> Subproblem 11/19 completed <<<
# SubPOMC 66: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66:  40% 9157/23104 [07:57<14:16, 16.29it/s]SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66:  97% 22302/23104 [19:29<00:42, 18.97it/s]SubPOMC 13: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66: 100% 23104/23104 [20:11<00:00, 19.07it/s]
#
# >>> Subproblem 13/19 completed <<<
# SubPOMC 13:  37% 8634/23104 [07:24<13:24, 17.99it/s]SubPOMC 142: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 23104/23104 [20:18<00:00, 18.96it/s]
#
# >>> Subproblem 14/19 completed <<<
# SubPOMC 13: 100% 23104/23104 [19:47<00:00, 19.46it/s]
# SubPOMC 142:  58% 13410/23104 [12:22<09:01, 17.89it/s]
# >>> Subproblem 15/19 completed <<<
# SubPOMC 142: 100% 23104/23104 [21:01<00:00, 18.31it/s]
#
# >>> Subproblem 16/19 completed <<<
# SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:  49% 11247/23104 [09:34<10:34, 18.68it/s]SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 23104/23104 [19:37<00:00, 19.62it/s]
#
# >>> Subproblem 17/19 completed <<<
# SubPOMC 12:  56% 12985/23104 [10:52<09:11, 18.36it/s]SubPOMC 20: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 12: 100% 23104/23104 [19:12<00:00, 20.05it/s]
#
# >>> Subproblem 18/19 completed <<<
# SubPOMC 20: 100% 23104/23104 [19:00<00:00, 20.25it/s]
#
# >>> Subproblem 19/19 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 20589.3915 seconds

# %% [markdown]
# **-------------Run 3--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 500.0 EPOAdapt 4
# 38
# Building fast coverage sets...
# Coverage sets built: avg size = 45.2
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [03:35<00:00, 891.48it/s]
# Built 191784 RR sets
#   Node 87: estimated_f=0.97, c=1.00, ratio=0.969
#   Node 129: estimated_f=1.04, c=2.01, ratio=0.516
#   Node 142: estimated_f=36.76, c=89.39, ratio=0.411
#   Node 4: estimated_f=33.95, c=83.43, ratio=0.407
#   Node 0: estimated_f=43.60, c=117.26, ratio=0.372
#   Node 128: estimated_f=1.07, c=3.04, ratio=0.353
#   Node 14: estimated_f=26.07, c=74.92, ratio=0.348
#   Node 15: estimated_f=35.34, c=101.64, ratio=0.348
#   Node 1: estimated_f=36.83, c=110.55, ratio=0.333
#   Node 6: estimated_f=23.57, c=70.88, ratio=0.333
#   Node 8: estimated_f=33.74, c=102.68, ratio=0.329
#   Node 22: estimated_f=20.08, c=61.64, ratio=0.326
#   Node 20: estimated_f=32.02, c=102.05, ratio=0.314
#   Node 66: estimated_f=33.35, c=106.37, ratio=0.314
#   Node 143: estimated_f=22.72, c=73.35, ratio=0.310
#   Node 21: estimated_f=28.61, c=92.75, ratio=0.308
#   Node 3: estimated_f=43.69, c=143.03, ratio=0.305
#   Node 112: estimated_f=1.13, c=3.79, ratio=0.298
#   Node 13: estimated_f=31.00, c=104.62, ratio=0.296
#   Node 12: estimated_f=35.56, c=121.36, ratio=0.293
# Selected 20 candidates via RR sets
# → adaptive K_B = 19 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 5776, n = 152
# → K_B = 19; launching 19 diverse subRuns
#
# SubPOMC 3: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 3:   4% 936/23104 [00:49<20:35, 17.95it/s]SubPOMC 128: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 3:   8% 1957/23104 [01:43<18:12, 19.36it/s]SubPOMC 112: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128:  16% 3774/23104 [02:35<12:00, 26.82it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 128: 100% 23104/23104 [15:28<00:00, 24.87it/s]
#
# >>> Subproblem 4/19 completed <<<
# SubPOMC 112: 100% 23104/23104 [15:05<00:00, 25.51it/s]
#
# >>> Subproblem 3/19 completed <<<
# SubPOMC 87: 100% 23104/23104 [14:19<00:00, 26.88it/s]
#
# >>> Subproblem 2/19 completed <<<
# SubPOMC 3: 100% 23104/23104 [20:23<00:00, 18.88it/s]
#
# >>> Subproblem 1/19 completed <<<
# SubPOMC 129: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:   2% 525/23104 [00:22<17:55, 20.99it/s]SubPOMC 6: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 6:   4% 990/23104 [00:47<17:40, 20.85it/s]SubPOMC 22: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129:  10% 2322/23104 [01:35<13:38, 25.40it/s]SubPOMC 143: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 129: 100% 23104/23104 [14:14<00:00, 27.04it/s]
#
# >>> Subproblem 5/19 completed <<<
# SubPOMC 6: 100% 23104/23104 [17:58<00:00, 21.42it/s]
#
# >>> Subproblem 6/19 completed <<<
# SubPOMC 22: 100% 23104/23104 [18:15<00:00, 21.09it/s]
#
# >>> Subproblem 7/19 completed <<<
# SubPOMC 143: 100% 23104/23104 [18:35<00:00, 20.71it/s]
#
# >>> Subproblem 8/19 completed <<<
# SubPOMC 66: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66:  12% 2774/23104 [02:22<17:29, 19.37it/s]SubPOMC 1: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66:  17% 3986/23104 [03:24<15:45, 20.21it/s]SubPOMC 14: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 14:   9% 2074/23104 [01:37<14:58, 23.40it/s]SubPOMC 8: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 66: 100% 23104/23104 [19:33<00:00, 19.69it/s]
#
# >>> Subproblem 12/19 completed <<<
# SubPOMC 14: 100% 23104/23104 [17:46<00:00, 21.67it/s]
# SubPOMC 8:  85% 19675/23104 [16:08<02:55, 19.53it/s]
# >>> Subproblem 11/19 completed <<<
# SubPOMC 1: 100% 23104/23104 [19:52<00:00, 19.38it/s]
#
# >>> Subproblem 9/19 completed <<<
# SubPOMC 8: 100% 23104/23104 [18:53<00:00, 20.38it/s]
#
# >>> Subproblem 10/19 completed <<<
# SubPOMC 13: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 13:  16% 3690/23104 [03:01<16:23, 19.73it/s]SubPOMC 21: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 13:  24% 5615/23104 [04:35<14:51, 19.62it/s]SubPOMC 4: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 4:  32% 7458/23104 [06:26<11:24, 22.86it/s]SubPOMC 142: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 13: 100% 23104/23104 [18:34<00:00, 20.73it/s]
#
# >>> Subproblem 15/19 completed <<<
# SubPOMC 21: 100% 23104/23104 [18:28<00:00, 20.84it/s]
#
# >>> Subproblem 14/19 completed <<<
# SubPOMC 4: 100% 23104/23104 [19:52<00:00, 19.38it/s]
#
# >>> Subproblem 13/19 completed <<<
# SubPOMC 142: 100% 23104/23104 [20:21<00:00, 18.92it/s]
#
# >>> Subproblem 16/19 completed <<<
# SubPOMC 12: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 12:  10% 2195/23104 [01:47<16:32, 21.07it/s]SubPOMC 15: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:   9% 2088/23104 [01:46<18:36, 18.82it/s]SubPOMC 20: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 12: 100% 23104/23104 [17:53<00:00, 21.53it/s]
#
# >>> Subproblem 18/19 completed <<<
# SubPOMC 15: 100% 23104/23104 [18:43<00:00, 20.57it/s]
#
# >>> Subproblem 17/19 completed <<<
# SubPOMC 20: 100% 23104/23104 [18:10<00:00, 21.18it/s]
#
# >>> Subproblem 19/19 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 19400.0148 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 500 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 91.28',
    'value = 91.16',
    'value = 91.3',
    'value = 92.52'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 91.5650 sec, Std Dev: 0.6397 sec, CV: 0.70%

# %% [markdown]
# **-------Time Analysis 500--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 20332.2451',
    'Elapsed time: 20589.3915',
    'Elapsed time: 19400.0148'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 20107.2171 sec, Std Dev: 625.8054 sec, CV: 3.11%

# %% [markdown]
# ---
