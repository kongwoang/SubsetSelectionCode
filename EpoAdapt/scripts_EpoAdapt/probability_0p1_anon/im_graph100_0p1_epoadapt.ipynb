# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
# ...

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOAdapt/
# Out:
# /content/drive/MyDrive/ML_Project/EPOAdapt

# %% [markdown]
# ### Probability 0.1
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1 \
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 100.0 EPOAdapt 4
# 14
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:31<00:00, 920.23it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.95, c=1.00, ratio=0.953
#   Node 15: estimated_f=38.82, c=48.60, ratio=0.799
#   Node 7: estimated_f=47.59, c=60.51, ratio=0.786
#   Node 12: estimated_f=40.69, c=58.67, ratio=0.693
#   Node 4: estimated_f=48.54, c=70.48, ratio=0.689
#   Node 19: estimated_f=33.79, c=50.06, ratio=0.675
#   Node 6: estimated_f=55.76, c=82.83, ratio=0.673
#   Node 1: estimated_f=57.99, c=89.25, ratio=0.650
#   Node 33: estimated_f=23.86, c=36.83, ratio=0.648
#   Node 17: estimated_f=37.77, c=58.90, ratio=0.641
#   Node 11: estimated_f=50.61, c=79.69, ratio=0.635
#   Node 9: estimated_f=51.39, c=82.73, ratio=0.621
#   Node 10: estimated_f=45.63, c=76.40, ratio=0.597
# ...

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1 \
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 100.0 EPOAdapt 4
# 14
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:30<00:00, 927.31it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.02, c=1.00, ratio=1.016
#   Node 15: estimated_f=38.87, c=48.60, ratio=0.800
#   Node 7: estimated_f=47.53, c=60.51, ratio=0.785
#   Node 12: estimated_f=40.89, c=58.67, ratio=0.697
#   Node 4: estimated_f=48.53, c=70.48, ratio=0.689
#   Node 19: estimated_f=34.05, c=50.06, ratio=0.680
#   Node 6: estimated_f=56.05, c=82.83, ratio=0.677
#   Node 33: estimated_f=24.08, c=36.83, ratio=0.654
#   Node 1: estimated_f=58.15, c=89.25, ratio=0.652
#   Node 17: estimated_f=38.17, c=58.90, ratio=0.648
#   Node 11: estimated_f=50.51, c=79.69, ratio=0.634
#   Node 9: estimated_f=51.20, c=82.73, ratio=0.619
#   Node 10: estimated_f=46.12, c=76.40, ratio=0.604
# ...

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1 \
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 100.0 EPOAdapt 4
# 14
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:31<00:00, 917.69it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.02, c=1.00, ratio=1.022
#   Node 15: estimated_f=38.66, c=48.60, ratio=0.795
#   Node 7: estimated_f=47.52, c=60.51, ratio=0.785
#   Node 12: estimated_f=40.70, c=58.67, ratio=0.694
#   Node 4: estimated_f=48.43, c=70.48, ratio=0.687
#   Node 6: estimated_f=55.80, c=82.83, ratio=0.674
#   Node 19: estimated_f=33.50, c=50.06, ratio=0.669
#   Node 33: estimated_f=23.97, c=36.83, ratio=0.651
#   Node 1: estimated_f=57.91, c=89.25, ratio=0.649
#   Node 17: estimated_f=37.86, c=58.90, ratio=0.643
#   Node 11: estimated_f=50.46, c=79.69, ratio=0.633
#   Node 9: estimated_f=51.17, c=82.73, ratio=0.618
#   Node 10: estimated_f=45.71, c=76.40, ratio=0.598
# ...

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 65.3',
    'value = 65.46',
    'value = 64.8'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 65.1867 sec, Std Dev: 0.3443 sec, CV: 0.53%

# %% [markdown]
# ---

# %% [markdown]
# **--------Time Analysis 100----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 388.9967',
    'Elapsed time: 378.4416',
    'Elapsed time: 389.1950'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 385.5444 sec, Std Dev: 6.1520 sec, CV: 1.60%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 200
# ---

# %% [markdown]
# **--------Run 1----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1 \
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 200.0 EPOAdapt 4
# 20
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:30<00:00, 932.19it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.05, c=1.00, ratio=1.054
#   Node 15: estimated_f=38.87, c=48.60, ratio=0.800
#   Node 7: estimated_f=47.34, c=60.51, ratio=0.782
#   Node 12: estimated_f=40.76, c=58.67, ratio=0.695
#   Node 4: estimated_f=48.67, c=70.48, ratio=0.691
#   Node 6: estimated_f=55.92, c=82.83, ratio=0.675
#   Node 19: estimated_f=33.68, c=50.06, ratio=0.673
#   Node 1: estimated_f=58.14, c=89.25, ratio=0.651
#   Node 33: estimated_f=23.79, c=36.83, ratio=0.646
#   Node 17: estimated_f=38.00, c=58.90, ratio=0.645
#   Node 11: estimated_f=50.69, c=79.69, ratio=0.636
#   Node 9: estimated_f=51.14, c=82.73, ratio=0.618
#   Node 10: estimated_f=45.71, c=76.40, ratio=0.598
# ...

# %% [markdown]
# **---------Run 2 Version--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1 \
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 200.0 EPOAdapt 4
# 20
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:30<00:00, 933.18it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.07, c=1.00, ratio=1.073
#   Node 15: estimated_f=38.83, c=48.60, ratio=0.799
#   Node 7: estimated_f=47.35, c=60.51, ratio=0.782
#   Node 12: estimated_f=40.83, c=58.67, ratio=0.696
#   Node 4: estimated_f=48.82, c=70.48, ratio=0.693
#   Node 6: estimated_f=55.95, c=82.83, ratio=0.675
#   Node 19: estimated_f=33.64, c=50.06, ratio=0.672
#   Node 1: estimated_f=58.16, c=89.25, ratio=0.652
#   Node 33: estimated_f=23.78, c=36.83, ratio=0.646
#   Node 17: estimated_f=37.96, c=58.90, ratio=0.644
#   Node 11: estimated_f=50.62, c=79.69, ratio=0.635
#   Node 9: estimated_f=51.42, c=82.73, ratio=0.622
#   Node 10: estimated_f=45.74, c=76.40, ratio=0.599
# ...

# %% [markdown]
# **----------Run 3-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1 \
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 200.0 EPOAdapt 4
# 20
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:31<00:00, 918.52it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.01, c=1.00, ratio=1.011
#   Node 15: estimated_f=38.92, c=48.60, ratio=0.801
#   Node 7: estimated_f=47.28, c=60.51, ratio=0.781
#   Node 12: estimated_f=40.88, c=58.67, ratio=0.697
#   Node 4: estimated_f=48.53, c=70.48, ratio=0.689
#   Node 6: estimated_f=55.70, c=82.83, ratio=0.672
#   Node 19: estimated_f=33.53, c=50.06, ratio=0.670
#   Node 33: estimated_f=24.01, c=36.83, ratio=0.652
#   Node 1: estimated_f=57.90, c=89.25, ratio=0.649
#   Node 17: estimated_f=38.08, c=58.90, ratio=0.646
#   Node 11: estimated_f=50.67, c=79.69, ratio=0.636
#   Node 9: estimated_f=51.30, c=82.73, ratio=0.620
#   Node 10: estimated_f=45.77, c=76.40, ratio=0.599
# ...

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 200 Results--------------**

# %%
# The result strings
results = [
    'value = 75.34',
    'value = 74.22',
    'value = 74.92'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 74.8267 sec, Std Dev: 0.5658 sec, CV: 0.76%

# %% [markdown]
# ---

# %% [markdown]
# **--------Time Analysis 200----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 1863.8476',
    'Elapsed time: 1837.4283',
    'Elapsed time: 1790.5527'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 1830.6095 sec, Std Dev: 37.1202 sec, CV: 2.03%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 300
# ---

# %% [markdown]
# **--------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1 \
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 300.0 EPOAdapt 4
# 25
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:28<00:00, 946.77it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.00, c=1.00, ratio=0.997
#   Node 15: estimated_f=39.06, c=48.60, ratio=0.804
#   Node 7: estimated_f=47.28, c=60.51, ratio=0.781
#   Node 12: estimated_f=40.76, c=58.67, ratio=0.695
#   Node 4: estimated_f=48.95, c=70.48, ratio=0.695
#   Node 6: estimated_f=55.89, c=82.83, ratio=0.675
#   Node 19: estimated_f=33.72, c=50.06, ratio=0.674
#   Node 33: estimated_f=24.19, c=36.83, ratio=0.657
#   Node 1: estimated_f=58.29, c=89.25, ratio=0.653
#   Node 17: estimated_f=38.11, c=58.90, ratio=0.647
#   Node 11: estimated_f=50.59, c=79.69, ratio=0.635
#   Node 9: estimated_f=51.37, c=82.73, ratio=0.621
#   Node 10: estimated_f=46.00, c=76.40, ratio=0.602
# ...

# %% [markdown]
# **----------Run 2 -----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1 \
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 300.0 EPOAdapt 4
# 25
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:29<00:00, 941.26it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.00, c=1.00, ratio=1.002
#   Node 15: estimated_f=38.91, c=48.60, ratio=0.800
#   Node 7: estimated_f=47.36, c=60.51, ratio=0.783
#   Node 12: estimated_f=40.63, c=58.67, ratio=0.693
#   Node 4: estimated_f=48.62, c=70.48, ratio=0.690
#   Node 6: estimated_f=55.73, c=82.83, ratio=0.673
#   Node 19: estimated_f=33.57, c=50.06, ratio=0.671
#   Node 1: estimated_f=57.97, c=89.25, ratio=0.649
#   Node 33: estimated_f=23.91, c=36.83, ratio=0.649
#   Node 17: estimated_f=37.84, c=58.90, ratio=0.642
#   Node 11: estimated_f=50.38, c=79.69, ratio=0.632
#   Node 9: estimated_f=51.14, c=82.73, ratio=0.618
#   Node 10: estimated_f=45.67, c=76.40, ratio=0.598
# ...

# %% [markdown]
# **----------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1 \
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 300.0 EPOAdapt 4
# 25
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:32<00:00, 908.65it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.96, c=1.00, ratio=0.964
#   Node 15: estimated_f=38.92, c=48.60, ratio=0.801
#   Node 7: estimated_f=47.39, c=60.51, ratio=0.783
#   Node 12: estimated_f=40.81, c=58.67, ratio=0.696
#   Node 4: estimated_f=48.77, c=70.48, ratio=0.692
#   Node 6: estimated_f=56.15, c=82.83, ratio=0.678
#   Node 19: estimated_f=33.71, c=50.06, ratio=0.673
#   Node 1: estimated_f=58.07, c=89.25, ratio=0.651
#   Node 33: estimated_f=23.95, c=36.83, ratio=0.650
#   Node 17: estimated_f=37.82, c=58.90, ratio=0.642
#   Node 11: estimated_f=50.60, c=79.69, ratio=0.635
#   Node 9: estimated_f=51.22, c=82.73, ratio=0.619
#   Node 10: estimated_f=46.02, c=76.40, ratio=0.602
# ...

# %% [markdown]
# ---

# %% [markdown]
# **----------Budget 300 Results-----------**

# %%
# The result strings
results = [
    'value = 78.98',
    'value = 79.0',
    'value = 79.44'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 79.1400 sec, Std Dev: 0.2600 sec, CV: 0.33%

# %% [markdown]
# ---

# %% [markdown]
# **-------Time Analysis 300------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 4134.2442',
    'Elapsed time: 3748.9179',
    'Elapsed time: 3858.1704'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 3913.7775 sec, Std Dev: 198.5905 sec, CV: 5.07%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 400
# ---

# %% [markdown]
# **-----------Run 1-----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1 \
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 400.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:29<00:00, 940.91it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.97, c=1.00, ratio=0.969
#   Node 15: estimated_f=38.87, c=48.60, ratio=0.800
#   Node 7: estimated_f=47.51, c=60.51, ratio=0.785
#   Node 12: estimated_f=40.93, c=58.67, ratio=0.698
#   Node 4: estimated_f=48.48, c=70.48, ratio=0.688
#   Node 6: estimated_f=55.92, c=82.83, ratio=0.675
#   Node 19: estimated_f=33.73, c=50.06, ratio=0.674
#   Node 1: estimated_f=58.08, c=89.25, ratio=0.651
#   Node 33: estimated_f=23.81, c=36.83, ratio=0.647
#   Node 17: estimated_f=37.87, c=58.90, ratio=0.643
#   Node 11: estimated_f=50.66, c=79.69, ratio=0.636
#   Node 9: estimated_f=51.45, c=82.73, ratio=0.622
#   Node 10: estimated_f=45.68, c=76.40, ratio=0.598
# ...

# %% [markdown]
# **----------Run 2 ------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1 \
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 400.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:30<00:00, 934.56it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.98, c=1.00, ratio=0.978
#   Node 15: estimated_f=39.02, c=48.60, ratio=0.803
#   Node 7: estimated_f=47.56, c=60.51, ratio=0.786
#   Node 12: estimated_f=40.87, c=58.67, ratio=0.697
#   Node 4: estimated_f=48.57, c=70.48, ratio=0.689
#   Node 6: estimated_f=56.05, c=82.83, ratio=0.677
#   Node 19: estimated_f=33.83, c=50.06, ratio=0.676
#   Node 1: estimated_f=58.06, c=89.25, ratio=0.651
#   Node 33: estimated_f=23.90, c=36.83, ratio=0.649
#   Node 17: estimated_f=38.08, c=58.90, ratio=0.647
#   Node 11: estimated_f=50.70, c=79.69, ratio=0.636
#   Node 9: estimated_f=51.30, c=82.73, ratio=0.620
#   Node 10: estimated_f=45.81, c=76.40, ratio=0.600
# ...

# %% [markdown]
# **-------------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1 \
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 400.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:29<00:00, 938.04it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.01, c=1.00, ratio=1.010
#   Node 15: estimated_f=38.57, c=48.60, ratio=0.793
#   Node 7: estimated_f=47.33, c=60.51, ratio=0.782
#   Node 12: estimated_f=40.56, c=58.67, ratio=0.691
#   Node 4: estimated_f=48.54, c=70.48, ratio=0.689
#   Node 6: estimated_f=55.60, c=82.83, ratio=0.671
#   Node 19: estimated_f=33.25, c=50.06, ratio=0.664
#   Node 1: estimated_f=58.04, c=89.25, ratio=0.650
#   Node 33: estimated_f=23.72, c=36.83, ratio=0.644
#   Node 17: estimated_f=37.93, c=58.90, ratio=0.644
#   Node 11: estimated_f=50.44, c=79.69, ratio=0.633
#   Node 9: estimated_f=50.89, c=82.73, ratio=0.615
#   Node 10: estimated_f=45.70, c=76.40, ratio=0.598
# ...

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 400 Results-----------**

# %%
# The result strings
results = [
    'value = 82.34',
    'value = 81.86',
    'value = 82.52'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 82.2400 sec, Std Dev: 0.3412 sec, CV: 0.41%

# %% [markdown]
# ---

# %% [markdown]
# **------Time Analysis 400----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 7220.0264',
    'Elapsed time: 7350.0520',
    'Elapsed time: 7295.3445'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 7288.4743 sec, Std Dev: 65.2845 sec, CV: 0.90%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 500
# ---

# %% [markdown]
# **------------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1 \
  -T 4 \
  -times 0
# Out:
# outdegree/graph100-01.txt 500.0 EPOAdapt 4
# 32
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:29<00:00, 938.97it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.03, c=1.00, ratio=1.033
#   Node 15: estimated_f=38.66, c=48.60, ratio=0.796
#   Node 7: estimated_f=47.35, c=60.51, ratio=0.782
#   Node 12: estimated_f=40.56, c=58.67, ratio=0.691
#   Node 4: estimated_f=48.64, c=70.48, ratio=0.690
#   Node 6: estimated_f=56.15, c=82.83, ratio=0.678
#   Node 19: estimated_f=33.56, c=50.06, ratio=0.670
#   Node 1: estimated_f=58.33, c=89.25, ratio=0.654
#   Node 33: estimated_f=23.69, c=36.83, ratio=0.643
#   Node 17: estimated_f=37.76, c=58.90, ratio=0.641
#   Node 11: estimated_f=50.39, c=79.69, ratio=0.632
#   Node 9: estimated_f=51.22, c=82.73, ratio=0.619
#   Node 10: estimated_f=45.75, c=76.40, ratio=0.599
# ...

# %% [markdown]
# **------------Run 2 --------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1 \
  -T 4 \
  -times 1
# Out:
# outdegree/graph100-01.txt 500.0 EPOAdapt 4
# 32
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:30<00:00, 932.70it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=0.96, c=1.00, ratio=0.957
#   Node 15: estimated_f=38.83, c=48.60, ratio=0.799
#   Node 7: estimated_f=47.41, c=60.51, ratio=0.783
#   Node 12: estimated_f=40.71, c=58.67, ratio=0.694
#   Node 4: estimated_f=48.38, c=70.48, ratio=0.687
#   Node 6: estimated_f=56.08, c=82.83, ratio=0.677
#   Node 19: estimated_f=33.43, c=50.06, ratio=0.668
#   Node 1: estimated_f=58.07, c=89.25, ratio=0.651
#   Node 33: estimated_f=23.86, c=36.83, ratio=0.648
#   Node 17: estimated_f=38.04, c=58.90, ratio=0.646
#   Node 11: estimated_f=50.50, c=79.69, ratio=0.634
#   Node 9: estimated_f=51.24, c=82.73, ratio=0.619
#   Node 10: estimated_f=45.60, c=76.40, ratio=0.597
# ...

# %% [markdown]
# **-------------Run 3--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph100-01.txt \
  -outdegree_file graph100_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1 \
  -T 4 \
  -times 2
# Out:
# outdegree/graph100-01.txt 500.0 EPOAdapt 4
# 32
# Building fast coverage sets...
# Coverage sets built: avg size = 50.3
# Computing f_scores via RR sets method...
# Building 84239 RR sets for influence estimation...
# RR sets: 100% 84239/84239 [01:29<00:00, 942.49it/s]
# Built 84239 RR sets
#   Node 99: estimated_f=1.03, c=1.00, ratio=1.034
#   Node 15: estimated_f=38.92, c=48.60, ratio=0.801
#   Node 7: estimated_f=47.62, c=60.51, ratio=0.787
#   Node 12: estimated_f=40.94, c=58.67, ratio=0.698
#   Node 4: estimated_f=48.71, c=70.48, ratio=0.691
#   Node 6: estimated_f=55.98, c=82.83, ratio=0.676
#   Node 19: estimated_f=33.62, c=50.06, ratio=0.672
#   Node 1: estimated_f=58.38, c=89.25, ratio=0.654
#   Node 33: estimated_f=24.01, c=36.83, ratio=0.652
#   Node 17: estimated_f=38.10, c=58.90, ratio=0.647
#   Node 11: estimated_f=50.73, c=79.69, ratio=0.637
#   Node 9: estimated_f=51.31, c=82.73, ratio=0.620
#   Node 10: estimated_f=45.68, c=76.40, ratio=0.598
# ...

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 500 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 84.9',
    'value = 84.88',
    'value = 85.24'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 85.0067 sec, Std Dev: 0.2023 sec, CV: 0.24%

# %% [markdown]
# ---

# %% [markdown]
# **--------Time Analysis 500----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 9987.2365',
    'Elapsed time: 9908.1896',
    'Elapsed time: 9664.4215'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 9853.2825 sec, Std Dev: 168.2661 sec, CV: 1.71%
