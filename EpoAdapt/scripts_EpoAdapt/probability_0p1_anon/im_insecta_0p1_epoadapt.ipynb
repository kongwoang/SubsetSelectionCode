# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOAdapt/
# Out:
# /content/drive/MyDrive/ML_Project/EPOAdapt

# %% [markdown]
# ### Probability 0.1
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [07:49<00:00, 382.55it/s]
# Built 179468 RR sets
#   Node 4: estimated_f=92.46, c=83.43, ratio=1.108
#   Node 6: estimated_f=77.46, c=70.88, ratio=1.093
#   Node 142: estimated_f=95.73, c=89.39, ratio=1.071
#   Node 22: estimated_f=65.15, c=61.64, ratio=1.057
#   Node 131: estimated_f=34.45, c=32.79, ratio=1.051
#   Node 14: estimated_f=78.08, c=74.92, ratio=1.042
#   Node 95: estimated_f=45.13, c=43.66, ratio=1.034
#   Node 143: estimated_f=75.12, c=73.35, ratio=1.024
#   Node 87: estimated_f=1.01, c=1.00, ratio=1.005
#   Node 26: estimated_f=67.55, c=75.58, ratio=0.894
#   Node 148: estimated_f=38.20, c=43.14, ratio=0.886
#   Node 144: estimated_f=46.47, c=53.06, ratio=0.876
#   Node 65: estimated_f=65.43, c=75.02, ratio=0.872
#   Node 21: estimated_f=80.18, c=92.75, ratio=0.864
#   Node 30: estimated_f=60.58, c=72.56, ratio=0.835
#   Node 25: estimated_f=72.25, c=88.37, ratio=0.818
#   Node 28: estimated_f=71.05, c=90.84, ratio=0.782
#   Node 52: estimated_f=31.14, c=40.23, ratio=0.774
#   Node 134: estimated_f=34.92, c=46.12, ratio=0.757
#   Node 32: estimated_f=64.58, c=85.70, ratio=0.754
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 28: Initialized with 10 seeds (20 singletons + greedy)
# SubPOMC 28:   1% 137/10336 [00:06<08:02, 21.15it/s]SubPOMC 142: Initialized with 14 seeds (20 singletons + greedy)
# SubPOMC 142:   5% 519/10336 [00:27<10:32, 15.52it/s]SubPOMC 52: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 52:  14% 1437/10336 [00:39<04:24, 33.65it/s]SubPOMC 87: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 10336/10336 [03:20<00:00, 51.58it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 52: 100% 10336/10336 [04:34<00:00, 37.59it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 28: 100% 10336/10336 [05:32<00:00, 31.05it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 142:  72% 7466/10336 [05:27<01:47, 26.82it/s]SubPOMC 95: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 95:   5% 484/10336 [00:12<04:10, 39.26it/s]SubPOMC 134: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 134:  16% 1655/10336 [00:47<03:45, 38.55it/s]SubPOMC 148: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 142: 100% 10336/10336 [07:41<00:00, 22.41it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 134:  45% 4617/10336 [02:13<02:44, 34.71it/s]SubPOMC 32: Initialized with 12 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 10336/10336 [04:31<00:00, 38.10it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 134: 100% 10336/10336 [04:58<00:00, 34.66it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 148: 100% 10336/10336 [04:38<00:00, 37.14it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 32: 100% 10336/10336 [03:56<00:00, 43.72it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 1191.7876 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [07:57<00:00, 375.46it/s]
# Built 179468 RR sets
#   Node 4: estimated_f=92.22, c=83.43, ratio=1.105
#   Node 6: estimated_f=77.35, c=70.88, ratio=1.091
#   Node 142: estimated_f=95.92, c=89.39, ratio=1.073
#   Node 22: estimated_f=65.19, c=61.64, ratio=1.058
#   Node 131: estimated_f=34.31, c=32.79, ratio=1.047
#   Node 14: estimated_f=78.11, c=74.92, ratio=1.043
#   Node 95: estimated_f=45.17, c=43.66, ratio=1.035
#   Node 143: estimated_f=75.14, c=73.35, ratio=1.024
#   Node 87: estimated_f=1.02, c=1.00, ratio=1.022
#   Node 26: estimated_f=67.69, c=75.58, ratio=0.896
#   Node 148: estimated_f=38.37, c=43.14, ratio=0.890
#   Node 144: estimated_f=46.43, c=53.06, ratio=0.875
#   Node 65: estimated_f=64.90, c=75.02, ratio=0.865
#   Node 21: estimated_f=80.08, c=92.75, ratio=0.863
#   Node 30: estimated_f=60.79, c=72.56, ratio=0.838
#   Node 25: estimated_f=72.18, c=88.37, ratio=0.817
#   Node 28: estimated_f=70.99, c=90.84, ratio=0.782
#   Node 52: estimated_f=31.03, c=40.23, ratio=0.771
#   Node 32: estimated_f=64.60, c=85.70, ratio=0.754
#   Node 116: estimated_f=30.86, c=41.21, ratio=0.749
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# → Using max_procs = 8 (tasks=8, effective_cpus=8)
# SubPOMC 28: Initialized with 14 seeds (20 singletons + greedy)
# SubPOMC 28:   1% 129/10336 [00:10<14:12, 11.97it/s]SubPOMC 142: Initialized with 16 seeds (20 singletons + greedy)
# SubPOMC 142:   0% 23/10336 [00:02<15:17, 11.24it/s]SubPOMC 32: Initialized with 15 seeds (20 singletons + greedy)
# SubPOMC 142:   6% 584/10336 [00:52<15:01, 10.82it/s]SubPOMC 116: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 32:   7% 743/10336 [00:51<09:31, 16.78it/s]SubPOMC 52: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 116:   4% 393/10336 [00:20<08:18, 19.97it/s]SubPOMC 148: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 28:  17% 1756/10336 [02:00<08:11, 17.45it/s]SubPOMC 95: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 95:   4% 413/10336 [00:24<09:28, 17.47it/s]SubPOMC 87: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 10336/10336 [06:11<00:00, 27.82it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 116: 100% 10336/10336 [08:38<00:00, 19.93it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 32: 100% 10336/10336 [09:30<00:00, 18.13it/s]
#
# >>> Subproblem 8/8 completed <<<
# SubPOMC 52: 100% 10336/10336 [08:45<00:00, 19.66it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 28: 100% 10336/10336 [09:59<00:00, 17.24it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 148: 100% 10336/10336 [08:52<00:00, 19.43it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 95: 100% 10336/10336 [08:55<00:00, 19.29it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 142: 100% 10336/10336 [12:16<00:00, 14.04it/s]
#
# >>> Subproblem 1/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 1242.1683 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [07:43<00:00, 387.29it/s]
# Built 179468 RR sets
#   Node 4: estimated_f=92.31, c=83.43, ratio=1.107
#   Node 6: estimated_f=77.48, c=70.88, ratio=1.093
#   Node 142: estimated_f=95.68, c=89.39, ratio=1.070
#   Node 22: estimated_f=65.12, c=61.64, ratio=1.057
#   Node 14: estimated_f=78.02, c=74.92, ratio=1.041
#   Node 131: estimated_f=34.11, c=32.79, ratio=1.040
#   Node 95: estimated_f=45.27, c=43.66, ratio=1.037
#   Node 143: estimated_f=75.09, c=73.35, ratio=1.024
#   Node 87: estimated_f=0.99, c=1.00, ratio=0.988
#   Node 26: estimated_f=67.87, c=75.58, ratio=0.898
#   Node 148: estimated_f=38.32, c=43.14, ratio=0.888
#   Node 144: estimated_f=46.30, c=53.06, ratio=0.873
#   Node 65: estimated_f=65.18, c=75.02, ratio=0.869
#   Node 21: estimated_f=79.88, c=92.75, ratio=0.861
#   Node 30: estimated_f=60.61, c=72.56, ratio=0.835
#   Node 25: estimated_f=72.24, c=88.37, ratio=0.817
#   Node 28: estimated_f=70.98, c=90.84, ratio=0.781
#   Node 52: estimated_f=30.91, c=40.23, ratio=0.769
#   Node 134: estimated_f=34.81, c=46.12, ratio=0.755
#   Node 32: estimated_f=64.50, c=85.70, ratio=0.753
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 28: Initialized with 10 seeds (20 singletons + greedy)
# SubPOMC 28:   1% 141/10336 [00:05<05:52, 28.95it/s]SubPOMC 142: Initialized with 17 seeds (20 singletons + greedy)
# SubPOMC 28:  10% 1019/10336 [00:36<05:27, 28.41it/s]SubPOMC 52: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 52:  15% 1596/10336 [00:41<03:22, 43.22it/s]SubPOMC 87: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 52: 100% 10336/10336 [04:17<00:00, 40.15it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 87: 100% 10336/10336 [03:40<00:00, 46.82it/s]
# SubPOMC 142:  63% 6520/10336 [04:53<02:47, 22.74it/s]
# >>> Subproblem 2/8 completed <<<
# SubPOMC 28:  90% 9329/10336 [05:42<00:41, 24.47it/s]SubPOMC 134: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 134:   2% 195/10336 [00:05<04:54, 34.42it/s]SubPOMC 95: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 28: 100% 10336/10336 [06:21<00:00, 27.06it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 134:  29% 3048/10336 [01:22<03:15, 37.35it/s]SubPOMC 148: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 142: 100% 10336/10336 [08:06<00:00, 21.24it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 148:  27% 2810/10336 [01:21<03:04, 40.85it/s]SubPOMC 32: Initialized with 18 seeds (20 singletons + greedy)
# SubPOMC 134: 100% 10336/10336 [04:39<00:00, 36.92it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 95: 100% 10336/10336 [05:14<00:00, 32.84it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 148: 100% 10336/10336 [04:58<00:00, 34.65it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 32: 100% 10336/10336 [04:18<00:00, 40.03it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 1235.3115 seconds

# %% [markdown]
# **-----------------Run 4----------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [07:54<00:00, 377.89it/s]
# Built 179468 RR sets
#   Node 4: estimated_f=92.75, c=83.43, ratio=1.112
#   Node 6: estimated_f=77.80, c=70.88, ratio=1.098
#   Node 142: estimated_f=96.02, c=89.39, ratio=1.074
#   Node 22: estimated_f=65.27, c=61.64, ratio=1.059
#   Node 131: estimated_f=34.50, c=32.79, ratio=1.052
#   Node 14: estimated_f=78.45, c=74.92, ratio=1.047
#   Node 95: estimated_f=45.25, c=43.66, ratio=1.036
#   Node 143: estimated_f=75.52, c=73.35, ratio=1.030
#   Node 87: estimated_f=0.97, c=1.00, ratio=0.966
#   Node 26: estimated_f=68.19, c=75.58, ratio=0.902
#   Node 148: estimated_f=38.44, c=43.14, ratio=0.891
#   Node 144: estimated_f=46.28, c=53.06, ratio=0.872
#   Node 65: estimated_f=65.24, c=75.02, ratio=0.870
#   Node 21: estimated_f=80.37, c=92.75, ratio=0.866
#   Node 30: estimated_f=60.82, c=72.56, ratio=0.838
#   Node 25: estimated_f=72.54, c=88.37, ratio=0.821
#   Node 28: estimated_f=71.27, c=90.84, ratio=0.785
#   Node 52: estimated_f=31.07, c=40.23, ratio=0.772
#   Node 134: estimated_f=35.03, c=46.12, ratio=0.760
#   Node 32: estimated_f=64.76, c=85.70, ratio=0.756
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# → Using max_procs = 8 (tasks=8, effective_cpus=8)
# SubPOMC 28: Initialized with 10 seeds (20 singletons + greedy)
# SubPOMC 28:   3% 264/10336 [00:18<11:41, 14.36it/s]SubPOMC 142: Initialized with 16 seeds (20 singletons + greedy)
# SubPOMC 142:   0% 36/10336 [00:04<23:31,  7.30it/s]SubPOMC 32: Initialized with 19 seeds (20 singletons + greedy)
# SubPOMC 28:   9% 918/10336 [01:02<10:00, 15.69it/s]SubPOMC 52: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 52:   5% 567/10336 [00:28<08:36, 18.92it/s]SubPOMC 134: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 32:  22% 2264/10336 [01:43<05:32, 24.28it/s]SubPOMC 148: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 52:  14% 1448/10336 [01:07<05:50, 25.33it/s]SubPOMC 95: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 52:  20% 2108/10336 [01:35<05:33, 24.69it/s]SubPOMC 87: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 32: 100% 10336/10336 [07:33<00:00, 22.78it/s]
#
# >>> Subproblem 8/8 completed <<<
# SubPOMC 52: 100% 10336/10336 [07:39<00:00, 22.47it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 87: 100% 10336/10336 [06:51<00:00, 25.15it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 28: 100% 10336/10336 [09:53<00:00, 17.43it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 134: 100% 10336/10336 [08:35<00:00, 20.05it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 148: 100% 10336/10336 [08:16<00:00, 20.80it/s]
# SubPOMC 142:  90% 9325/10336 [10:04<00:30, 33.26it/s]
# >>> Subproblem 7/8 completed <<<
# SubPOMC 95: 100% 10336/10336 [08:33<00:00, 20.12it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 142: 100% 10336/10336 [10:38<00:00, 16.20it/s]
#
# >>> Subproblem 1/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 1143.4660 seconds

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 3
# Out:
# outdegree/insecta.txt 100.0 EPOAdapt 4
# 17
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 179468 RR sets for influence estimation...
# RR sets: 100% 179468/179468 [07:48<00:00, 382.73it/s]
# Built 179468 RR sets
#   Node 4: estimated_f=92.12, c=83.43, ratio=1.104
#   Node 6: estimated_f=77.44, c=70.88, ratio=1.093
#   Node 142: estimated_f=95.68, c=89.39, ratio=1.070
#   Node 22: estimated_f=65.08, c=61.64, ratio=1.056
#   Node 131: estimated_f=34.31, c=32.79, ratio=1.047
#   Node 14: estimated_f=77.89, c=74.92, ratio=1.040
#   Node 95: estimated_f=45.03, c=43.66, ratio=1.031
#   Node 143: estimated_f=75.03, c=73.35, ratio=1.023
#   Node 87: estimated_f=1.00, c=1.00, ratio=0.998
#   Node 26: estimated_f=67.67, c=75.58, ratio=0.895
#   Node 148: estimated_f=38.41, c=43.14, ratio=0.890
#   Node 144: estimated_f=46.27, c=53.06, ratio=0.872
#   Node 65: estimated_f=65.11, c=75.02, ratio=0.868
#   Node 21: estimated_f=80.03, c=92.75, ratio=0.863
#   Node 30: estimated_f=60.76, c=72.56, ratio=0.837
#   Node 25: estimated_f=72.21, c=88.37, ratio=0.817
#   Node 28: estimated_f=70.90, c=90.84, ratio=0.781
#   Node 52: estimated_f=31.10, c=40.23, ratio=0.773
#   Node 134: estimated_f=34.74, c=46.12, ratio=0.753
#   Node 116: estimated_f=31.03, c=41.21, ratio=0.753
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.12
# → GreedyEvaluate = 2584, n = 152
# → K_B = 8; launching 8 diverse subRuns
#
# → Using max_procs = 8 (tasks=8, effective_cpus=8)
# SubPOMC 28: Initialized with 11 seeds (20 singletons + greedy)
# SubPOMC 28:   0% 33/10336 [00:03<18:32,  9.26it/s]SubPOMC 142: Initialized with 13 seeds (20 singletons + greedy)
# SubPOMC 28:   9% 959/10336 [01:12<07:19, 21.32it/s]SubPOMC 134: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 28:  10% 1018/10336 [01:15<07:53, 19.66it/s]SubPOMC 116: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 142:   8% 872/10336 [01:13<10:09, 15.52it/s]SubPOMC 52: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 52:   2% 219/10336 [00:12<09:51, 17.11it/s]SubPOMC 148: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 134:   9% 891/10336 [00:48<11:40, 13.48it/s]SubPOMC 95: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 134:  17% 1785/10336 [01:34<07:34, 18.80it/s]SubPOMC 87: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 10336/10336 [06:19<00:00, 27.24it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 116: 100% 10336/10336 [08:01<00:00, 21.49it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 28: 100% 10336/10336 [09:36<00:00, 17.93it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 134: 100% 10336/10336 [08:36<00:00, 20.02it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 52: 100% 10336/10336 [08:43<00:00, 19.75it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 148: 100% 10336/10336 [08:36<00:00, 20.00it/s]
#
# >>> Subproblem 8/8 completed <<<
# SubPOMC 95: 100% 10336/10336 [09:08<00:00, 18.86it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 142: 100% 10336/10336 [13:23<00:00, 12.86it/s]
#
# >>> Subproblem 1/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 1290.1605 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 109.34',
    'value = 106.24',
    'value = 105.36',
    'value = 106.62',
    'value = 105.06'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 106.5240 sec, Std Dev: 1.6969 sec, CV: 1.59%

# %% [markdown]
# **----------Time Analysis 100--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 1191.7876',
    'Elapsed time: 1273.9853',
    'Elapsed time: 1235.3115',
    'Elapsed time: 1143.4660'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 1211.1376 sec, Std Dev: 56.2378 sec, CV: 4.64%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 200
# ---

# %% [markdown]
# **--------Run 1----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [08:17<00:00, 385.84it/s]
# Built 191784 RR sets
#   Node 4: estimated_f=92.09, c=83.43, ratio=1.104
#   Node 6: estimated_f=77.36, c=70.88, ratio=1.092
#   Node 142: estimated_f=95.78, c=89.39, ratio=1.071
#   Node 22: estimated_f=64.92, c=61.64, ratio=1.053
#   Node 14: estimated_f=77.96, c=74.92, ratio=1.041
#   Node 131: estimated_f=34.10, c=32.79, ratio=1.040
#   Node 95: estimated_f=45.00, c=43.66, ratio=1.031
#   Node 143: estimated_f=75.21, c=73.35, ratio=1.025
#   Node 87: estimated_f=0.96, c=1.00, ratio=0.957
#   Node 26: estimated_f=67.76, c=75.58, ratio=0.897
#   Node 148: estimated_f=38.09, c=43.14, ratio=0.883
#   Node 15: estimated_f=89.22, c=101.64, ratio=0.878
#   Node 1: estimated_f=96.82, c=110.55, ratio=0.876
#   Node 0: estimated_f=102.61, c=117.26, ratio=0.875
#   Node 144: estimated_f=46.43, c=53.06, ratio=0.875
#   Node 8: estimated_f=89.49, c=102.68, ratio=0.872
#   Node 65: estimated_f=64.86, c=75.02, ratio=0.865
#   Node 21: estimated_f=79.77, c=92.75, ratio=0.860
#   Node 66: estimated_f=88.89, c=106.37, ratio=0.836
#   Node 30: estimated_f=60.26, c=72.56, ratio=0.830
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3648, n = 152
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 0: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 0:   0% 44/14592 [00:03<18:59, 12.76it/s]SubPOMC 15: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 15:  31% 4557/14592 [04:51<13:02, 12.82it/s]SubPOMC 95: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 15:  77% 11171/14592 [11:37<04:06, 13.86it/s]SubPOMC 87: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 14592/14592 [15:04<00:00, 16.14it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 15: 100% 14592/14592 [15:12<00:00, 16.00it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 95: 100% 14592/14592 [15:16<00:00, 15.92it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 87:  73% 10582/14592 [09:26<04:07, 16.18it/s]SubPOMC 65: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 14592/14592 [12:37<00:00, 19.26it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 65:  25% 3596/14592 [03:50<11:08, 16.44it/s]SubPOMC 148: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 148:  21% 3116/14592 [03:01<13:03, 14.65it/s]SubPOMC 144: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 65:  58% 8429/14592 [08:28<05:12, 19.71it/s]SubPOMC 30: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 65: 100% 14592/14592 [14:30<00:00, 16.76it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 148: 100% 14592/14592 [13:53<00:00, 17.50it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 144: 100% 14592/14592 [15:33<00:00, 15.63it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 30:  90% 13087/14592 [14:25<02:07, 11.82it/s]SubPOMC 26: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 30: 100% 14592/14592 [16:04<00:00, 15.12it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 26:  22% 3228/14592 [03:27<10:54, 17.37it/s]SubPOMC 131: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 26:  36% 5220/14592 [05:36<10:27, 14.94it/s]SubPOMC 21: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 26:  46% 6750/14592 [07:13<08:25, 15.50it/s]SubPOMC 22: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 26: 100% 14592/14592 [15:35<00:00, 15.59it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 131: 100% 14592/14592 [13:37<00:00, 17.85it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 21: 100% 14592/14592 [15:15<00:00, 15.94it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 22: 100% 14592/14592 [14:48<00:00, 16.42it/s]
#
# >>> Subproblem 11/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 4814.2297 seconds

# %% [markdown]
# **---------Run 2--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [08:14<00:00, 388.10it/s]
# Built 191784 RR sets
#   Node 4: estimated_f=92.42, c=83.43, ratio=1.108
#   Node 6: estimated_f=77.56, c=70.88, ratio=1.094
#   Node 142: estimated_f=95.97, c=89.39, ratio=1.074
#   Node 22: estimated_f=65.05, c=61.64, ratio=1.055
#   Node 14: estimated_f=78.14, c=74.92, ratio=1.043
#   Node 131: estimated_f=34.18, c=32.79, ratio=1.043
#   Node 95: estimated_f=44.92, c=43.66, ratio=1.029
#   Node 143: estimated_f=75.37, c=73.35, ratio=1.028
#   Node 87: estimated_f=1.02, c=1.00, ratio=1.018
#   Node 26: estimated_f=67.69, c=75.58, ratio=0.896
#   Node 148: estimated_f=38.20, c=43.14, ratio=0.885
#   Node 1: estimated_f=97.10, c=110.55, ratio=0.878
#   Node 15: estimated_f=89.23, c=101.64, ratio=0.878
#   Node 0: estimated_f=102.88, c=117.26, ratio=0.877
#   Node 8: estimated_f=89.50, c=102.68, ratio=0.872
#   Node 144: estimated_f=46.16, c=53.06, ratio=0.870
#   Node 65: estimated_f=65.18, c=75.02, ratio=0.869
#   Node 21: estimated_f=80.28, c=92.75, ratio=0.866
#   Node 66: estimated_f=89.30, c=106.37, ratio=0.840
#   Node 30: estimated_f=60.89, c=72.56, ratio=0.839
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3648, n = 152
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 15: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 15:  11% 1561/14592 [01:45<11:52, 18.29it/s]SubPOMC 0: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 15:  20% 2975/14592 [03:20<11:32, 16.77it/s]SubPOMC 95: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 95:  64% 9327/14592 [07:47<03:34, 24.58it/s]SubPOMC 87: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 95: 100% 14592/14592 [12:14<00:00, 19.88it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 15: 100% 14592/14592 [16:25<00:00, 14.81it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 0: 100% 14592/14592 [16:34<00:00, 14.68it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 87:  80% 11743/14592 [09:21<02:29, 19.10it/s]SubPOMC 65: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 14592/14592 [11:10<00:00, 21.76it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 65:  24% 3473/14592 [03:41<12:28, 14.85it/s]SubPOMC 30: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 30:  11% 1552/14592 [01:37<13:31, 16.06it/s]SubPOMC 148: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 65:  61% 8974/14592 [09:35<06:51, 13.66it/s]SubPOMC 144: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 65: 100% 14592/14592 [15:28<00:00, 15.72it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 30: 100% 14592/14592 [15:13<00:00, 15.97it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 148: 100% 14592/14592 [14:24<00:00, 16.88it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 144: 100% 14592/14592 [13:44<00:00, 17.70it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 26: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 26:  15% 2216/14592 [02:24<13:35, 15.18it/s]SubPOMC 131: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 26:  21% 3017/14592 [03:13<10:37, 18.17it/s]SubPOMC 21: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 21:   1% 101/14592 [00:06<15:42, 15.38it/s]SubPOMC 22: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 26: 100% 14592/14592 [15:24<00:00, 15.78it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 131: 100% 14592/14592 [13:14<00:00, 18.37it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 21: 100% 14592/14592 [14:15<00:00, 17.05it/s]
#
# >>> Subproblem 12/12 completed <<<
# SubPOMC 22: 100% 14592/14592 [14:32<00:00, 16.72it/s]
#
# >>> Subproblem 11/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 4594.6038 seconds

# %% [markdown]
# **----------Run 3-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [08:13<00:00, 389.01it/s]
# Built 191784 RR sets
#   Node 4: estimated_f=92.45, c=83.43, ratio=1.108
#   Node 6: estimated_f=77.45, c=70.88, ratio=1.093
#   Node 142: estimated_f=96.01, c=89.39, ratio=1.074
#   Node 22: estimated_f=65.14, c=61.64, ratio=1.057
#   Node 131: estimated_f=34.56, c=32.79, ratio=1.054
#   Node 14: estimated_f=78.30, c=74.92, ratio=1.045
#   Node 95: estimated_f=45.12, c=43.66, ratio=1.034
#   Node 143: estimated_f=75.63, c=73.35, ratio=1.031
#   Node 87: estimated_f=1.01, c=1.00, ratio=1.008
#   Node 26: estimated_f=67.99, c=75.58, ratio=0.900
#   Node 148: estimated_f=38.23, c=43.14, ratio=0.886
#   Node 1: estimated_f=97.44, c=110.55, ratio=0.881
#   Node 15: estimated_f=89.57, c=101.64, ratio=0.881
#   Node 0: estimated_f=103.09, c=117.26, ratio=0.879
#   Node 144: estimated_f=46.39, c=53.06, ratio=0.874
#   Node 8: estimated_f=89.52, c=102.68, ratio=0.872
#   Node 65: estimated_f=65.36, c=75.02, ratio=0.871
#   Node 21: estimated_f=80.32, c=92.75, ratio=0.866
#   Node 66: estimated_f=89.25, c=106.37, ratio=0.839
#   Node 30: estimated_f=60.82, c=72.56, ratio=0.838
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3648, n = 152
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 15: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 15:  22% 3168/14592 [03:16<10:57, 17.38it/s]SubPOMC 0: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 0:   2% 334/14592 [00:22<14:41, 16.17it/s]SubPOMC 95: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 15:  75% 10964/14592 [11:18<04:24, 13.72it/s]SubPOMC 87: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 14592/14592 [15:18<00:00, 15.88it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 95: 100% 14592/14592 [15:07<00:00, 16.07it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 0: 100% 14592/14592 [16:03<00:00, 15.14it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 87:  83% 12109/14592 [13:09<03:28, 11.93it/s]SubPOMC 65: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 65:   0% 50/14592 [00:03<20:13, 11.98it/s]SubPOMC 30: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 87:  93% 13533/14592 [14:36<00:57, 18.46it/s]SubPOMC 148: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 87: 100% 14592/14592 [15:40<00:00, 15.52it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 148:  68% 9883/14592 [08:04<04:21, 18.00it/s]SubPOMC 144: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 148: 100% 14592/14592 [11:47<00:00, 20.62it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 65: 100% 14592/14592 [14:29<00:00, 16.78it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 30: 100% 14592/14592 [16:46<00:00, 14.50it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 144:  66% 9571/14592 [09:34<04:16, 19.60it/s]SubPOMC 26: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 144: 100% 14592/14592 [14:32<00:00, 16.72it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 26:  34% 5030/14592 [05:34<08:45, 18.19it/s]SubPOMC 22: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 22:   5% 690/14592 [00:41<12:57, 17.87it/s]SubPOMC 131: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 131:  23% 3389/14592 [03:34<13:19, 14.01it/s]SubPOMC 21: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 26: 100% 14592/14592 [16:14<00:00, 14.98it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 22: 100% 14592/14592 [14:25<00:00, 16.86it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 131: 100% 14592/14592 [15:14<00:00, 15.95it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 21: 100% 14592/14592 [15:17<00:00, 15.90it/s]
#
# >>> Subproblem 12/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 4927.3776 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 200 Results--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 116.46',
    'value = 116.56',
    'value = 117.54'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 116.8533 sec, Std Dev: 0.5968 sec, CV: 0.51%

# %% [markdown]
# **-----------Time Analysis 200-----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 4814.2297',
    'Elapsed time: 4594.6038',
    'Elapsed time: 4927.3776'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 4778.7370 sec, Std Dev: 169.2022 sec, CV: 3.54%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 300
# ---

# %% [markdown]
# **--------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [08:20<00:00, 383.51it/s]
# Built 191784 RR sets
#   Node 4: estimated_f=92.22, c=83.43, ratio=1.105
#   Node 6: estimated_f=77.64, c=70.88, ratio=1.095
#   Node 142: estimated_f=95.91, c=89.39, ratio=1.073
#   Node 22: estimated_f=65.27, c=61.64, ratio=1.059
#   Node 131: estimated_f=34.44, c=32.79, ratio=1.050
#   Node 87: estimated_f=1.05, c=1.00, ratio=1.049
#   Node 14: estimated_f=78.03, c=74.92, ratio=1.042
#   Node 95: estimated_f=44.96, c=43.66, ratio=1.030
#   Node 143: estimated_f=75.47, c=73.35, ratio=1.029
#   Node 26: estimated_f=67.68, c=75.58, ratio=0.895
#   Node 148: estimated_f=38.47, c=43.14, ratio=0.892
#   Node 15: estimated_f=89.49, c=101.64, ratio=0.880
#   Node 0: estimated_f=102.92, c=117.26, ratio=0.878
#   Node 1: estimated_f=96.88, c=110.55, ratio=0.876
#   Node 144: estimated_f=46.30, c=53.06, ratio=0.873
#   Node 8: estimated_f=89.35, c=102.68, ratio=0.870
#   Node 65: estimated_f=65.25, c=75.02, ratio=0.870
#   Node 21: estimated_f=79.95, c=92.75, ratio=0.862
#   Node 30: estimated_f=60.97, c=72.56, ratio=0.840
#   Node 66: estimated_f=88.96, c=106.37, ratio=0.836
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 4408, n = 152
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 15: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 15:   4% 715/17632 [00:55<27:47, 10.15it/s]SubPOMC 0: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 15:  56% 9874/17632 [12:27<09:59, 12.94it/s]SubPOMC 95: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 95:  25% 4436/17632 [04:55<13:32, 16.25it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 17632/17632 [22:19<00:00, 13.16it/s]
# SubPOMC 95:  51% 9066/17632 [09:52<09:21, 15.27it/s]
# >>> Subproblem 3/14 completed <<<
# SubPOMC 0: 100% 17632/17632 [23:55<00:00, 12.29it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 95: 100% 17632/17632 [18:58<00:00, 15.49it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 87: 100% 17632/17632 [20:30<00:00, 14.33it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 65: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 65:   3% 575/17632 [00:44<22:17, 12.75it/s]SubPOMC 148: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 148:  19% 3322/17632 [04:11<14:33, 16.39it/s]SubPOMC 30: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 148:  74% 13132/17632 [15:52<05:05, 14.72it/s]SubPOMC 144: Initialized with 39 seeds (20 singletons + greedy)
# SubPOMC 65: 100% 17632/17632 [21:23<00:00, 13.73it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 148: 100% 17632/17632 [21:13<00:00, 13.84it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 30: 100% 17632/17632 [21:39<00:00, 13.57it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 144: 100% 17632/17632 [22:05<00:00, 13.30it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 26: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 26:  43% 7655/17632 [09:22<10:24, 15.99it/s]SubPOMC 22: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 22:  25% 4495/17632 [05:47<19:26, 11.26it/s]SubPOMC 131: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 131:   2% 294/17632 [00:22<20:46, 13.91it/s]SubPOMC 21: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 26: 100% 17632/17632 [21:32<00:00, 13.65it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 22: 100% 17632/17632 [21:57<00:00, 13.38it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 131: 100% 17632/17632 [21:49<00:00, 13.47it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 21: 100% 17632/17632 [23:13<00:00, 12.65it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 8: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 8:  58% 10173/17632 [12:43<10:06, 12.30it/s]SubPOMC 14: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 17632/17632 [21:46<00:00, 13.49it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 14: 100% 17632/17632 [20:38<00:00, 14.24it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 12728.4272 seconds

# %% [markdown]
# **----------Run 2 -----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1\
  -T 4 \
  -times 1

# %% [markdown]
# **----------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 74.4
# Computing f_scores via RR sets method...
# Building 191784 RR sets for influence estimation...
# RR sets: 100% 191784/191784 [08:20<00:00, 382.89it/s]
# Built 191784 RR sets
#   Node 4: estimated_f=92.29, c=83.43, ratio=1.106
#   Node 6: estimated_f=77.40, c=70.88, ratio=1.092
#   Node 142: estimated_f=96.06, c=89.39, ratio=1.075
#   Node 22: estimated_f=65.27, c=61.64, ratio=1.059
#   Node 131: estimated_f=34.61, c=32.79, ratio=1.056
#   Node 14: estimated_f=78.10, c=74.92, ratio=1.042
#   Node 95: estimated_f=44.96, c=43.66, ratio=1.030
#   Node 143: estimated_f=75.48, c=73.35, ratio=1.029
#   Node 87: estimated_f=0.99, c=1.00, ratio=0.988
#   Node 26: estimated_f=67.64, c=75.58, ratio=0.895
#   Node 148: estimated_f=38.33, c=43.14, ratio=0.889
#   Node 1: estimated_f=97.34, c=110.55, ratio=0.881
#   Node 15: estimated_f=89.43, c=101.64, ratio=0.880
#   Node 0: estimated_f=102.76, c=117.26, ratio=0.876
#   Node 8: estimated_f=89.73, c=102.68, ratio=0.874
#   Node 144: estimated_f=46.35, c=53.06, ratio=0.874
#   Node 65: estimated_f=65.52, c=75.02, ratio=0.873
#   Node 21: estimated_f=80.03, c=92.75, ratio=0.863
#   Node 30: estimated_f=60.85, c=72.56, ratio=0.839
#   Node 66: estimated_f=89.06, c=106.37, ratio=0.837
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 4408, n = 152
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 0: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 0:  17% 3032/17632 [04:03<26:25,  9.21it/s]SubPOMC 15: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 15:  29% 5127/17632 [05:52<11:03, 18.85it/s]SubPOMC 95: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15:  70% 12407/17632 [13:44<05:50, 14.91it/s]SubPOMC 87: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 17632/17632 [19:19<00:00, 15.20it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 0: 100% 17632/17632 [23:33<00:00, 12.47it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 95: 100% 17632/17632 [20:23<00:00, 14.41it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 87: 100% 17632/17632 [19:16<00:00, 15.25it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 65: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 65:   2% 382/17632 [00:29<20:45, 13.85it/s]SubPOMC 148: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 148:   3% 470/17632 [00:35<22:20, 12.80it/s]SubPOMC 30: Initialized with 41 seeds (20 singletons + greedy)
# SubPOMC 65:  73% 12844/17632 [15:54<05:55, 13.47it/s]SubPOMC 144: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 148: 100% 17632/17632 [20:13<00:00, 14.53it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 65: 100% 17632/17632 [21:35<00:00, 13.61it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 30: 100% 17632/17632 [21:51<00:00, 13.45it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 144: 100% 17632/17632 [21:20<00:00, 13.77it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 26: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 26:  21% 3635/17632 [04:44<19:51, 11.74it/s]SubPOMC 131: Initialized with 42 seeds (20 singletons + greedy)
# SubPOMC 131:  22% 3945/17632 [04:32<14:07, 16.15it/s]SubPOMC 22: Initialized with 40 seeds (20 singletons + greedy)
# SubPOMC 26:  72% 12633/17632 [16:08<04:09, 20.04it/s]SubPOMC 21: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 26: 100% 17632/17632 [22:15<00:00, 13.20it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 131: 100% 17632/17632 [18:00<00:00, 16.32it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 22: 100% 17632/17632 [22:27<00:00, 13.08it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 21: 100% 17632/17632 [21:59<00:00, 13.36it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 8: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 8:  43% 7644/17632 [09:51<14:05, 11.82it/s]SubPOMC 14: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 8: 100% 17632/17632 [22:41<00:00, 12.95it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 14: 100% 17632/17632 [21:16<00:00, 13.81it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 12229.4123 seconds

# %% [markdown]
# ---

# %% [markdown]
# **----------Budget 300 Results-----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 123.96',
    'value = 124.54',
    'value = 124.64'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 124.3800 sec, Std Dev: 0.3672 sec, CV: 0.30%

# %% [markdown]
# #### Budget 400
# ---

# %% [markdown]
# **-----------Run 1-----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1\
  -T 4 \
  -times 0

# %% [markdown]
# **----------Run 2 ------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1\
  -T 4 \
  -times 1

# %% [markdown]
# **-------------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1\
  -T 4 \
  -times 2

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 400 Results-----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 128.34',
    'value = 128.4',
    'value = 127.86'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 128.2000 sec, Std Dev: 0.2960 sec, CV: 0.23%

# %% [markdown]
# #### Budget 500
# ---

# %% [markdown]
# **------------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1\
  -T 4 \
  -times 0

# %% [markdown]
# **------------Run 2 --------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1\
  -T 4 \
  -times 1

# %% [markdown]
# **-----------Run 3-----------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1 \
  -T 4 \
  -times 2

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 500 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 130.96',
    'value = 130.86',
    'value = 131.02'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 130.9467 sec, Std Dev: 0.0808 sec, CV: 0.06%

# %% [markdown]
# ---
