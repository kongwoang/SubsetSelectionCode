# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOAdapt/
# Out:
# /content/drive/MyDrive/ML_Project/EPOAdapt

# %% [markdown]
# ### Probability 0.1
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 100.0 EPOAdapt 4
# 16
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 280490 RR sets for influence estimation...
# RR sets: 100% 280490/280490 [22:57<00:00, 203.58it/s]
# Built 280490 RR sets
#   Node 49: estimated_f=80.68, c=62.67, ratio=1.287
#   Node 45: estimated_f=73.68, c=58.15, ratio=1.267
#   Node 15: estimated_f=116.16, c=92.01, ratio=1.262
#   Node 41: estimated_f=84.74, c=71.80, ratio=1.180
#   Node 43: estimated_f=93.66, c=82.64, ratio=1.133
#   Node 31: estimated_f=95.17, c=84.10, ratio=1.132
#   Node 56: estimated_f=74.79, c=67.56, ratio=1.107
#   Node 32: estimated_f=108.78, c=98.87, ratio=1.100
#   Node 61: estimated_f=80.51, c=75.81, ratio=1.062
#   Node 199: estimated_f=1.04, c=1.00, ratio=1.043
#   Node 44: estimated_f=95.86, c=92.49, ratio=1.036
#   Node 59: estimated_f=73.36, c=71.54, ratio=1.025
#   Node 37: estimated_f=98.48, c=97.20, ratio=1.013
#   Node 48: estimated_f=82.77, c=82.91, ratio=0.998
#   Node 38: estimated_f=93.86, c=94.64, ratio=0.992
#   Node 89: estimated_f=46.89, c=48.20, ratio=0.973
#   Node 96: estimated_f=32.53, c=33.88, ratio=0.960
#   Node 53: estimated_f=90.47, c=94.82, ratio=0.954
#   Node 66: estimated_f=71.44, c=75.00, ratio=0.952
#   Node 52: estimated_f=85.90, c=91.07, ratio=0.943
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 200
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 53: Initialized with 8 seeds (20 singletons + greedy)
# SubPOMC 53:   1% 78/12800 [00:04<10:48, 19.61it/s]SubPOMC 15: Initialized with 9 seeds (20 singletons + greedy)
# SubPOMC 53:  16% 1990/12800 [01:12<04:26, 40.63it/s]SubPOMC 89: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 89:   8% 1037/12800 [00:32<06:23, 30.69it/s]SubPOMC 199: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 12800/12800 [04:55<00:00, 43.31it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 53: 100% 12800/12800 [07:31<00:00, 28.32it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 89:  96% 12232/12800 [06:22<00:14, 38.12it/s]SubPOMC 96: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 89: 100% 12800/12800 [06:39<00:00, 32.05it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 96:  14% 1838/12800 [01:04<05:27, 33.47it/s]SubPOMC 66: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 15:  85% 10848/12800 [09:04<02:08, 15.22it/s]SubPOMC 61: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 12800/12800 [11:06<00:00, 19.21it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 61:  42% 5411/12800 [03:33<03:44, 32.84it/s]SubPOMC 59: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 96: 100% 12800/12800 [07:17<00:00, 29.25it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 61: 100% 12800/12800 [07:34<00:00, 28.17it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 66: 100% 12800/12800 [08:43<00:00, 24.45it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 59: 100% 12800/12800 [06:08<00:00, 34.73it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2515.5684 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 100.0 EPOAdapt 4
# 16
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 280490 RR sets for influence estimation...
# RR sets: 100% 280490/280490 [22:56<00:00, 203.78it/s]
# Built 280490 RR sets
#   Node 49: estimated_f=80.98, c=62.67, ratio=1.292
#   Node 45: estimated_f=73.73, c=58.15, ratio=1.268
#   Node 15: estimated_f=116.20, c=92.01, ratio=1.263
#   Node 41: estimated_f=84.85, c=71.80, ratio=1.182
#   Node 43: estimated_f=93.74, c=82.64, ratio=1.134
#   Node 31: estimated_f=95.15, c=84.10, ratio=1.131
#   Node 56: estimated_f=74.67, c=67.56, ratio=1.105
#   Node 32: estimated_f=109.06, c=98.87, ratio=1.103
#   Node 61: estimated_f=80.52, c=75.81, ratio=1.062
#   Node 44: estimated_f=96.00, c=92.49, ratio=1.038
#   Node 199: estimated_f=1.04, c=1.00, ratio=1.035
#   Node 59: estimated_f=73.63, c=71.54, ratio=1.029
#   Node 37: estimated_f=98.54, c=97.20, ratio=1.014
#   Node 48: estimated_f=82.68, c=82.91, ratio=0.997
#   Node 38: estimated_f=94.34, c=94.64, ratio=0.997
#   Node 96: estimated_f=32.81, c=33.88, ratio=0.969
#   Node 89: estimated_f=46.67, c=48.20, ratio=0.968
#   Node 53: estimated_f=90.81, c=94.82, ratio=0.958
#   Node 66: estimated_f=71.41, c=75.00, ratio=0.952
#   Node 52: estimated_f=85.85, c=91.07, ratio=0.943
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 200
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 53: Initialized with 6 seeds (20 singletons + greedy)
# SubPOMC 53:   1% 143/12800 [00:05<08:08, 25.89it/s]SubPOMC 15: Initialized with 10 seeds (20 singletons + greedy)
# SubPOMC 15:   9% 1118/12800 [00:52<07:40, 25.39it/s]SubPOMC 96: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 53:  17% 2229/12800 [01:22<10:22, 16.98it/s]SubPOMC 199: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 12800/12800 [04:44<00:00, 45.02it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 15:  64% 8156/12800 [06:57<04:56, 15.69it/s]SubPOMC 89: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 53: 100% 12800/12800 [07:46<00:00, 27.43it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 96: 100% 12800/12800 [07:34<00:00, 28.19it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 89:  30% 3832/12800 [01:44<04:17, 34.77it/s]SubPOMC 66: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 66:  13% 1651/12800 [00:41<08:00, 23.22it/s]SubPOMC 61: Initialized with 22 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 12800/12800 [11:16<00:00, 18.93it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 89: 100% 12800/12800 [05:33<00:00, 38.43it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 61:  49% 6314/12800 [03:07<01:52, 57.65it/s]SubPOMC 59: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 66: 100% 12800/12800 [05:21<00:00, 39.77it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 61: 100% 12800/12800 [06:11<00:00, 34.48it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 59: 100% 12800/12800 [07:11<00:00, 29.66it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2571.6769 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 100.0 EPOAdapt 4
# 16
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 280490 RR sets for influence estimation...
# RR sets: 100% 280490/280490 [22:49<00:00, 204.84it/s]
# Built 280490 RR sets
#   Node 49: estimated_f=80.36, c=62.67, ratio=1.282
#   Node 45: estimated_f=73.55, c=58.15, ratio=1.265
#   Node 15: estimated_f=116.00, c=92.01, ratio=1.261
#   Node 41: estimated_f=84.67, c=71.80, ratio=1.179
#   Node 43: estimated_f=93.43, c=82.64, ratio=1.131
#   Node 31: estimated_f=94.75, c=84.10, ratio=1.127
#   Node 56: estimated_f=74.58, c=67.56, ratio=1.104
#   Node 32: estimated_f=108.59, c=98.87, ratio=1.098
#   Node 61: estimated_f=80.17, c=75.81, ratio=1.057
#   Node 44: estimated_f=95.66, c=92.49, ratio=1.034
#   Node 59: estimated_f=73.31, c=71.54, ratio=1.025
#   Node 37: estimated_f=98.25, c=97.20, ratio=1.011
#   Node 48: estimated_f=82.37, c=82.91, ratio=0.993
#   Node 38: estimated_f=93.98, c=94.64, ratio=0.993
#   Node 89: estimated_f=46.25, c=48.20, ratio=0.960
#   Node 53: estimated_f=90.55, c=94.82, ratio=0.955
#   Node 96: estimated_f=32.32, c=33.88, ratio=0.954
#   Node 66: estimated_f=71.01, c=75.00, ratio=0.947
#   Node 52: estimated_f=85.72, c=91.07, ratio=0.941
#   Node 199: estimated_f=0.93, c=1.00, ratio=0.933
# Selected 20 candidates via RR sets
# → adaptive K_B = 8 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 3200, n = 200
# → K_B = 8; launching 8 diverse subRuns
#
# SubPOMC 53: Initialized with 5 seeds (20 singletons + greedy)
# SubPOMC 53:   1% 106/12800 [00:05<11:54, 17.76it/s]SubPOMC 15: Initialized with 8 seeds (20 singletons + greedy)
# SubPOMC 15:   9% 1125/12800 [00:53<08:48, 22.08it/s]SubPOMC 96: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 96:   7% 941/12800 [00:33<06:33, 30.12it/s]SubPOMC 199: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 199: 100% 12800/12800 [05:02<00:00, 42.26it/s]
#
# >>> Subproblem 2/8 completed <<<
# SubPOMC 96:  90% 11523/12800 [06:27<00:53, 23.90it/s]SubPOMC 89: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 53: 100% 12800/12800 [07:44<00:00, 27.58it/s]
#
# >>> Subproblem 3/8 completed <<<
# SubPOMC 96: 100% 12800/12800 [07:09<00:00, 29.81it/s]
#
# >>> Subproblem 4/8 completed <<<
# SubPOMC 15:  89% 11453/12800 [08:47<01:10, 19.18it/s]SubPOMC 66: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 66:   4% 496/12800 [00:18<07:16, 28.16it/s]SubPOMC 61: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 15: 100% 12800/12800 [09:47<00:00, 21.78it/s]
#
# >>> Subproblem 1/8 completed <<<
# SubPOMC 66:  37% 4728/12800 [02:16<04:12, 32.02it/s]SubPOMC 59: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 89: 100% 12800/12800 [05:50<00:00, 36.56it/s]
#
# >>> Subproblem 5/8 completed <<<
# SubPOMC 66: 100% 12800/12800 [05:45<00:00, 37.01it/s]
#
# >>> Subproblem 6/8 completed <<<
# SubPOMC 61: 100% 12800/12800 [06:04<00:00, 35.10it/s]
#
# >>> Subproblem 7/8 completed <<<
# SubPOMC 59: 100% 12800/12800 [08:36<00:00, 24.77it/s]
#
# >>> Subproblem 8/8 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 2560.4043 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 128.64',
    'value = 128.0',
    'value = 126.7'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 127.7800 sec, Std Dev: 0.9885 sec, CV: 0.77%

# %% [markdown]
# **----------Time Analysis 100----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 2515.5684',
    'Elapsed time: 2571.6769',
    'Elapsed time: 2560.4043'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 2549.2165 sec, Std Dev: 29.6802 sec, CV: 1.16%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 200
# ---

# %% [markdown]
# **--------Run 1----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [26:56<00:00, 203.87it/s]
# Built 329587 RR sets
#   Node 0: estimated_f=145.16, c=103.13, ratio=1.408
#   Node 49: estimated_f=80.68, c=62.67, ratio=1.287
#   Node 6: estimated_f=131.66, c=102.60, ratio=1.283
#   Node 45: estimated_f=73.56, c=58.15, ratio=1.265
#   Node 15: estimated_f=116.10, c=92.01, ratio=1.262
#   Node 10: estimated_f=132.27, c=106.33, ratio=1.244
#   Node 4: estimated_f=138.12, c=113.62, ratio=1.216
#   Node 8: estimated_f=127.71, c=105.24, ratio=1.214
#   Node 18: estimated_f=128.47, c=107.45, ratio=1.196
#   Node 41: estimated_f=84.86, c=71.80, ratio=1.182
#   Node 27: estimated_f=115.74, c=100.81, ratio=1.148
#   Node 43: estimated_f=93.95, c=82.64, ratio=1.137
#   Node 31: estimated_f=95.08, c=84.10, ratio=1.131
#   Node 17: estimated_f=118.51, c=104.85, ratio=1.130
#   Node 56: estimated_f=74.86, c=67.56, ratio=1.108
#   Node 32: estimated_f=109.03, c=98.87, ratio=1.103
#   Node 22: estimated_f=122.38, c=115.01, ratio=1.064
#   Node 61: estimated_f=80.43, c=75.81, ratio=1.061
#   Node 11: estimated_f=130.77, c=123.55, ratio=1.058
#   Node 1: estimated_f=144.51, c=137.54, ratio=1.051
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 4800, n = 200
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 61: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 61:   4% 769/19200 [01:10<25:25, 12.08it/s]SubPOMC 56: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 56:  33% 6419/19200 [08:45<21:08, 10.08it/s]SubPOMC 18: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 56:  50% 9668/19200 [13:05<17:19,  9.17it/s]SubPOMC 0: Initialized with 23 seeds (20 singletons + greedy)
# SubPOMC 61: 100% 19200/19200 [26:55<00:00, 11.89it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 56: 100% 19200/19200 [25:59<00:00, 12.31it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 18:  91% 17473/19200 [22:59<01:53, 15.21it/s]SubPOMC 49: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 18:  94% 17952/19200 [23:35<01:31, 13.62it/s]SubPOMC 45: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 18: 100% 19200/19200 [25:09<00:00, 12.72it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 49:  20% 3785/19200 [05:12<20:14, 12.69it/s]SubPOMC 43: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 19200/19200 [26:44<00:00, 11.97it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 45:  49% 9427/19200 [12:47<19:16,  8.45it/s]SubPOMC 32: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 45: 100% 19200/19200 [26:08<00:00, 12.24it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 49: 100% 19200/19200 [26:44<00:00, 11.97it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 43: 100% 19200/19200 [26:21<00:00, 12.14it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 32:  77% 14693/19200 [18:14<04:44, 15.85it/s]SubPOMC 41: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 41:   6% 1179/19200 [01:37<22:01, 13.63it/s]SubPOMC 27: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 32: 100% 19200/19200 [23:49<00:00, 13.43it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 27:  27% 5136/19200 [06:50<21:43, 10.79it/s]SubPOMC 22: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 41:  35% 6667/19200 [09:19<17:39, 11.83it/s]SubPOMC 31: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 41: 100% 19200/19200 [26:41<00:00, 11.99it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 27: 100% 19200/19200 [25:26<00:00, 12.58it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 22: 100% 19200/19200 [21:46<00:00, 14.70it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 31: 100% 19200/19200 [26:29<00:00, 12.08it/s]
#
# >>> Subproblem 12/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 7853.3238 seconds

# %% [markdown]
# **---------Run 2 Version--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [26:38<00:00, 206.12it/s]
# Built 329587 RR sets
#   Node 0: estimated_f=145.05, c=103.13, ratio=1.406
#   Node 49: estimated_f=80.64, c=62.67, ratio=1.287
#   Node 6: estimated_f=131.47, c=102.60, ratio=1.281
#   Node 45: estimated_f=73.63, c=58.15, ratio=1.266
#   Node 15: estimated_f=116.25, c=92.01, ratio=1.263
#   Node 10: estimated_f=132.17, c=106.33, ratio=1.243
#   Node 4: estimated_f=138.08, c=113.62, ratio=1.215
#   Node 8: estimated_f=127.73, c=105.24, ratio=1.214
#   Node 18: estimated_f=128.42, c=107.45, ratio=1.195
#   Node 41: estimated_f=84.73, c=71.80, ratio=1.180
#   Node 27: estimated_f=115.72, c=100.81, ratio=1.148
#   Node 43: estimated_f=93.82, c=82.64, ratio=1.135
#   Node 31: estimated_f=95.15, c=84.10, ratio=1.131
#   Node 17: estimated_f=118.59, c=104.85, ratio=1.131
#   Node 56: estimated_f=74.78, c=67.56, ratio=1.107
#   Node 32: estimated_f=109.03, c=98.87, ratio=1.103
#   Node 22: estimated_f=122.45, c=115.01, ratio=1.065
#   Node 11: estimated_f=130.71, c=123.55, ratio=1.058
#   Node 61: estimated_f=80.20, c=75.81, ratio=1.058
#   Node 1: estimated_f=144.27, c=137.54, ratio=1.049
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 4800, n = 200
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 61: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 61:   3% 592/19200 [00:52<30:40, 10.11it/s]SubPOMC 56: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 61:  24% 4643/19200 [06:24<18:45, 12.93it/s]SubPOMC 18: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 18:  32% 6234/19200 [08:36<21:07, 10.23it/s]SubPOMC 0: Initialized with 24 seeds (20 singletons + greedy)
# SubPOMC 61: 100% 19200/19200 [26:22<00:00, 12.14it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 56: 100% 19200/19200 [25:32<00:00, 12.53it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 18:  99% 19064/19200 [26:26<00:14,  9.71it/s]SubPOMC 49: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 18: 100% 19200/19200 [26:36<00:00, 12.02it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 49:   2% 462/19200 [00:43<25:10, 12.40it/s]SubPOMC 45: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 45:   6% 1121/19200 [01:33<23:19, 12.92it/s]SubPOMC 43: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 19200/19200 [28:51<00:00, 11.09it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 45:  67% 12784/19200 [17:44<08:52, 12.05it/s]SubPOMC 32: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 49: 100% 19200/19200 [26:26<00:00, 12.10it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 45: 100% 19200/19200 [26:44<00:00, 11.96it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 43: 100% 19200/19200 [26:50<00:00, 11.92it/s]
# SubPOMC 32:  45% 8648/19200 [10:40<15:27, 11.38it/s]
# >>> Subproblem 7/12 completed <<<
# SubPOMC 32:  50% 9547/19200 [11:46<12:50, 12.53it/s]SubPOMC 41: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 32:  65% 12487/19200 [15:22<08:37, 12.96it/s]SubPOMC 27: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 27:  18% 3444/19200 [04:27<24:17, 10.81it/s]SubPOMC 22: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 32: 100% 19200/19200 [23:39<00:00, 13.53it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 41:  55% 10603/19200 [14:44<13:38, 10.50it/s]SubPOMC 31: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 41: 100% 19200/19200 [26:34<00:00, 12.04it/s]
# SubPOMC 27:  91% 17565/19200 [22:58<01:49, 14.92it/s]
# >>> Subproblem 9/12 completed <<<
# SubPOMC 27: 100% 19200/19200 [25:01<00:00, 12.78it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 22: 100% 19200/19200 [23:34<00:00, 13.58it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 31: 100% 19200/19200 [27:58<00:00, 11.44it/s]
#
# >>> Subproblem 12/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 8166.6084 seconds

# %% [markdown]
# **----------Run 3-------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 200 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 200.0 EPOAdapt 4
# 24
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [26:34<00:00, 206.65it/s]
# Built 329587 RR sets
#   Node 0: estimated_f=144.99, c=103.13, ratio=1.406
#   Node 49: estimated_f=80.80, c=62.67, ratio=1.289
#   Node 6: estimated_f=131.68, c=102.60, ratio=1.283
#   Node 45: estimated_f=73.76, c=58.15, ratio=1.268
#   Node 15: estimated_f=116.14, c=92.01, ratio=1.262
#   Node 10: estimated_f=132.17, c=106.33, ratio=1.243
#   Node 4: estimated_f=138.20, c=113.62, ratio=1.216
#   Node 8: estimated_f=127.67, c=105.24, ratio=1.213
#   Node 18: estimated_f=128.56, c=107.45, ratio=1.196
#   Node 41: estimated_f=84.59, c=71.80, ratio=1.178
#   Node 27: estimated_f=115.41, c=100.81, ratio=1.145
#   Node 43: estimated_f=93.69, c=82.64, ratio=1.134
#   Node 17: estimated_f=118.51, c=104.85, ratio=1.130
#   Node 31: estimated_f=94.99, c=84.10, ratio=1.129
#   Node 56: estimated_f=74.83, c=67.56, ratio=1.108
#   Node 32: estimated_f=108.78, c=98.87, ratio=1.100
#   Node 22: estimated_f=122.56, c=115.01, ratio=1.066
#   Node 61: estimated_f=80.60, c=75.81, ratio=1.063
#   Node 11: estimated_f=130.98, c=123.55, ratio=1.060
#   Node 1: estimated_f=144.37, c=137.54, ratio=1.050
# Selected 20 candidates via RR sets
# → adaptive K_B = 12 based on avg marginal ≈ 2.00
# → GreedyEvaluate = 4800, n = 200
# → K_B = 12; launching 12 diverse subRuns
#
# SubPOMC 61: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 61:   5% 867/19200 [01:16<17:43, 17.24it/s]SubPOMC 56: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 56:  23% 4435/19200 [06:00<21:46, 11.30it/s]SubPOMC 18: Initialized with 22 seeds (20 singletons + greedy)
# SubPOMC 56:  41% 7866/19200 [10:45<13:51, 13.64it/s]SubPOMC 0: Initialized with 23 seeds (20 singletons + greedy)
# SubPOMC 61: 100% 19200/19200 [26:27<00:00, 12.10it/s]
#
# >>> Subproblem 3/12 completed <<<
# SubPOMC 56: 100% 19200/19200 [26:01<00:00, 12.30it/s]
#
# >>> Subproblem 4/12 completed <<<
# SubPOMC 18: 100% 19158/19200 [25:28<00:03, 12.70it/s]SubPOMC 49: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 18: 100% 19200/19200 [25:31<00:00, 12.54it/s]
#
# >>> Subproblem 2/12 completed <<<
# SubPOMC 0:  78% 14924/19200 [21:31<08:14,  8.64it/s]SubPOMC 45: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 0:  88% 16967/19200 [24:21<02:34, 14.46it/s]SubPOMC 43: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 0: 100% 19200/19200 [27:30<00:00, 11.63it/s]
#
# >>> Subproblem 1/12 completed <<<
# SubPOMC 45:  39% 7424/19200 [09:48<18:24, 10.67it/s]SubPOMC 32: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 45: 100% 19200/19200 [24:53<00:00, 12.86it/s]
#
# >>> Subproblem 6/12 completed <<<
# SubPOMC 49: 100% 19200/19200 [26:01<00:00, 12.30it/s]
#
# >>> Subproblem 5/12 completed <<<
# SubPOMC 32:  75% 14468/19200 [18:40<05:42, 13.80it/s]SubPOMC 41: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 43: 100% 19200/19200 [27:12<00:00, 11.76it/s]
#
# >>> Subproblem 7/12 completed <<<
# SubPOMC 41:  19% 3623/19200 [04:59<24:59, 10.39it/s]SubPOMC 27: Initialized with 25 seeds (20 singletons + greedy)
# SubPOMC 32: 100% 19200/19200 [24:40<00:00, 12.97it/s]
#
# >>> Subproblem 8/12 completed <<<
# SubPOMC 41:  34% 6528/19200 [08:59<14:44, 14.32it/s]SubPOMC 31: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 41:  39% 7482/19200 [10:17<14:23, 13.58it/s]SubPOMC 22: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 41: 100% 19200/19200 [26:41<00:00, 11.99it/s]
#
# >>> Subproblem 9/12 completed <<<
# SubPOMC 27: 100% 19200/19200 [24:59<00:00, 12.80it/s]
#
# >>> Subproblem 10/12 completed <<<
# SubPOMC 22: 100% 19200/19200 [24:04<00:00, 13.29it/s]
#
# >>> Subproblem 11/12 completed <<<
# SubPOMC 31: 100% 19200/19200 [26:29<00:00, 12.08it/s]
#
# >>> Subproblem 12/12 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 7645.5760 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 200 Results--------------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 160.76',
    'value = 160.84',
    'value = 159.78'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 160.4600 sec, Std Dev: 0.5903 sec, CV: 0.37%

# %% [markdown]
# **---------Time Analysis 200-----**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 7853.3238',
    'Elapsed time: 8166.6084',
    'Elapsed time: 7645.5760'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 7888.5027 sec, Std Dev: 262.2916 sec, CV: 3.32%

# %% [markdown]
# ---

# %% [markdown]
# #### Budget 300
# ---

# %% [markdown]
# **--------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [26:59<00:00, 203.47it/s]
# Built 329587 RR sets
#   Node 0: estimated_f=145.25, c=103.13, ratio=1.408
#   Node 6: estimated_f=131.64, c=102.60, ratio=1.283
#   Node 49: estimated_f=80.42, c=62.67, ratio=1.283
#   Node 45: estimated_f=73.77, c=58.15, ratio=1.269
#   Node 15: estimated_f=115.98, c=92.01, ratio=1.260
#   Node 10: estimated_f=132.17, c=106.33, ratio=1.243
#   Node 4: estimated_f=138.18, c=113.62, ratio=1.216
#   Node 8: estimated_f=127.84, c=105.24, ratio=1.215
#   Node 18: estimated_f=128.55, c=107.45, ratio=1.196
#   Node 41: estimated_f=84.77, c=71.80, ratio=1.181
#   Node 27: estimated_f=115.58, c=100.81, ratio=1.147
#   Node 43: estimated_f=93.93, c=82.64, ratio=1.137
#   Node 17: estimated_f=118.48, c=104.85, ratio=1.130
#   Node 31: estimated_f=94.86, c=84.10, ratio=1.128
#   Node 56: estimated_f=74.78, c=67.56, ratio=1.107
#   Node 32: estimated_f=108.89, c=98.87, ratio=1.101
#   Node 22: estimated_f=122.31, c=115.01, ratio=1.063
#   Node 61: estimated_f=80.33, c=75.81, ratio=1.060
#   Node 11: estimated_f=130.88, c=123.55, ratio=1.059
#   Node 1: estimated_f=144.42, c=137.54, ratio=1.050
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 5800, n = 200
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 18: Initialized with 27 seeds (20 singletons + greedy)
# SubPOMC 18:  21% 4873/23200 [06:42<23:10, 13.18it/s]SubPOMC 0: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 0:   5% 1122/23200 [01:59<34:54, 10.54it/s]SubPOMC 61: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 18:  49% 11444/23200 [15:44<16:26, 11.92it/s]SubPOMC 56: Initialized with 37 seeds (20 singletons + greedy)
# SubPOMC 18: 100% 23200/23200 [32:20<00:00, 11.95it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 61: 100% 23200/23200 [35:55<00:00, 10.76it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 0: 100% 23200/23200 [40:29<00:00,  9.55it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 56: 100% 23200/23200 [35:23<00:00, 10.93it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 49: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 49:   6% 1411/23200 [02:24<26:24, 13.75it/s]SubPOMC 43: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 49:  10% 2341/23200 [03:56<31:33, 11.01it/s]SubPOMC 32: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 49:  47% 10832/23200 [18:20<23:06,  8.92it/s]SubPOMC 45: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 43: 100% 23200/23200 [35:22<00:00, 10.93it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 49: 100% 23200/23200 [37:59<00:00, 10.18it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 32: 100% 23200/23200 [38:24<00:00, 10.07it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 45: 100% 23200/23200 [35:27<00:00, 10.90it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 22: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 22:   3% 654/23200 [01:02<24:23, 15.40it/s]SubPOMC 27: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 27:  24% 5502/23200 [07:33<20:56, 14.08it/s]SubPOMC 41: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 27:  63% 14613/23200 [20:01<10:07, 14.15it/s]SubPOMC 31: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 27: 100% 23200/23200 [31:39<00:00, 12.21it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 22: 100% 23200/23200 [34:20<00:00, 11.26it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 41: 100% 23200/23200 [35:31<00:00, 10.88it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 31:  95% 22060/23200 [34:10<01:24, 13.52it/s]SubPOMC 1: Initialized with 26 seeds (20 singletons + greedy)
# SubPOMC 31: 100% 23200/23200 [35:55<00:00, 10.76it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 1:  32% 7345/23200 [12:29<29:54,  8.83it/s]SubPOMC 15: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 23200/23200 [38:48<00:00,  9.96it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 15: 100% 23200/23200 [35:49<00:00, 10.79it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 17923.2771 seconds

# %% [markdown]
# **----------Run 2 -----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [26:58<00:00, 203.60it/s]
# Built 329587 RR sets
#   Node 0: estimated_f=144.83, c=103.13, ratio=1.404
#   Node 49: estimated_f=80.59, c=62.67, ratio=1.286
#   Node 6: estimated_f=131.42, c=102.60, ratio=1.281
#   Node 45: estimated_f=73.57, c=58.15, ratio=1.265
#   Node 15: estimated_f=116.18, c=92.01, ratio=1.263
#   Node 10: estimated_f=131.98, c=106.33, ratio=1.241
#   Node 4: estimated_f=138.06, c=113.62, ratio=1.215
#   Node 8: estimated_f=127.57, c=105.24, ratio=1.212
#   Node 18: estimated_f=128.40, c=107.45, ratio=1.195
#   Node 41: estimated_f=84.64, c=71.80, ratio=1.179
#   Node 27: estimated_f=115.67, c=100.81, ratio=1.147
#   Node 43: estimated_f=93.85, c=82.64, ratio=1.136
#   Node 17: estimated_f=118.28, c=104.85, ratio=1.128
#   Node 31: estimated_f=94.81, c=84.10, ratio=1.127
#   Node 56: estimated_f=74.62, c=67.56, ratio=1.104
#   Node 32: estimated_f=108.70, c=98.87, ratio=1.099
#   Node 22: estimated_f=122.47, c=115.01, ratio=1.065
#   Node 61: estimated_f=80.46, c=75.81, ratio=1.061
#   Node 11: estimated_f=131.11, c=123.55, ratio=1.061
#   Node 1: estimated_f=144.37, c=137.54, ratio=1.050
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 5800, n = 200
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 0: Initialized with 28 seeds (20 singletons + greedy)
# SubPOMC 0:   2% 575/23200 [01:01<40:18,  9.36it/s]SubPOMC 18: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 18:  27% 6363/23200 [10:25<19:07, 14.67it/s]SubPOMC 56: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 18:  34% 7833/23200 [12:50<29:15,  8.76it/s]SubPOMC 61: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 18: 100% 23200/23200 [37:55<00:00, 10.20it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 0: 100% 23200/23200 [39:08<00:00,  9.88it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 56: 100% 23200/23200 [35:50<00:00, 10.79it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 61: 100% 23200/23200 [35:32<00:00, 10.88it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 32: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 32:   6% 1363/23200 [02:01<33:50, 10.75it/s]SubPOMC 43: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 43:   9% 2011/23200 [03:24<39:44,  8.88it/s]SubPOMC 45: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 32:  19% 4335/23200 [06:07<25:59, 12.09it/s]SubPOMC 49: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 32: 100% 23200/23200 [32:46<00:00, 11.80it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 43: 100% 23200/23200 [38:57<00:00,  9.93it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 49: 100% 23200/23200 [36:02<00:00, 10.73it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 45: 100% 23200/23200 [37:00<00:00, 10.45it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 22: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 22:  16% 3677/23200 [05:34<27:18, 11.91it/s]SubPOMC 27: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 27:   3% 762/23200 [01:02<32:51, 11.38it/s]SubPOMC 41: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 27:  10% 2396/23200 [03:08<21:37, 16.04it/s]SubPOMC 31: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 22: 100% 23200/23200 [34:59<00:00, 11.05it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 27: 100% 23200/23200 [31:14<00:00, 12.37it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 41: 100% 23200/23200 [36:22<00:00, 10.63it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 31: 100% 23200/23200 [35:04<00:00, 11.03it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 1: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 1:  61% 14131/23200 [20:11<10:33, 14.31it/s]SubPOMC 15: Initialized with 31 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 23200/23200 [33:08<00:00, 11.67it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 15: 100% 23200/23200 [36:09<00:00, 10.69it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 18471.7128 seconds

# %% [markdown]
# **----------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 300 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 300.0 EPOAdapt 4
# 29
# Building fast coverage sets...
# Coverage sets built: avg size = 99.7
# Computing f_scores via RR sets method...
# Building 329587 RR sets for influence estimation...
# RR sets: 100% 329587/329587 [26:34<00:00, 206.71it/s]
# Built 329587 RR sets
#   Node 0: estimated_f=144.86, c=103.13, ratio=1.405
#   Node 49: estimated_f=80.57, c=62.67, ratio=1.286
#   Node 6: estimated_f=131.40, c=102.60, ratio=1.281
#   Node 45: estimated_f=73.46, c=58.15, ratio=1.263
#   Node 15: estimated_f=115.99, c=92.01, ratio=1.261
#   Node 10: estimated_f=131.91, c=106.33, ratio=1.241
#   Node 4: estimated_f=138.06, c=113.62, ratio=1.215
#   Node 8: estimated_f=127.55, c=105.24, ratio=1.212
#   Node 18: estimated_f=128.31, c=107.45, ratio=1.194
#   Node 41: estimated_f=84.43, c=71.80, ratio=1.176
#   Node 27: estimated_f=115.55, c=100.81, ratio=1.146
#   Node 43: estimated_f=93.61, c=82.64, ratio=1.133
#   Node 17: estimated_f=118.58, c=104.85, ratio=1.131
#   Node 31: estimated_f=94.75, c=84.10, ratio=1.127
#   Node 56: estimated_f=74.50, c=67.56, ratio=1.103
#   Node 32: estimated_f=108.57, c=98.87, ratio=1.098
#   Node 22: estimated_f=122.35, c=115.01, ratio=1.064
#   Node 61: estimated_f=80.45, c=75.81, ratio=1.061
#   Node 11: estimated_f=130.93, c=123.55, ratio=1.060
#   Node 1: estimated_f=144.24, c=137.54, ratio=1.049
# Selected 20 candidates via RR sets
# → adaptive K_B = 14 based on avg marginal ≈ 2.07
# → GreedyEvaluate = 5800, n = 200
# → K_B = 14; launching 14 diverse subRuns
#
# SubPOMC 18: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 18:   6% 1289/23200 [02:03<42:00,  8.69it/s]SubPOMC 0: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 18:  24% 5501/23200 [08:38<31:17,  9.43it/s]SubPOMC 61: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 0:  31% 7292/23200 [13:18<30:37,  8.66it/s]SubPOMC 56: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 18: 100% 23200/23200 [35:52<00:00, 10.78it/s]
#
# >>> Subproblem 2/14 completed <<<
# SubPOMC 0: 100% 23200/23200 [41:26<00:00,  9.33it/s]
#
# >>> Subproblem 1/14 completed <<<
# SubPOMC 61: 100% 23200/23200 [35:48<00:00, 10.80it/s]
#
# >>> Subproblem 3/14 completed <<<
# SubPOMC 56: 100% 23200/23200 [35:19<00:00, 10.94it/s]
#
# >>> Subproblem 4/14 completed <<<
# SubPOMC 49: Initialized with 38 seeds (20 singletons + greedy)
# SubPOMC 49:  16% 3661/23200 [06:02<34:35,  9.41it/s]SubPOMC 43: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 43:  13% 3092/23200 [04:54<34:10,  9.81it/s]SubPOMC 32: Initialized with 32 seeds (20 singletons + greedy)
# SubPOMC 32:   0% 43/23200 [00:04<35:23, 10.90it/s]SubPOMC 45: Initialized with 34 seeds (20 singletons + greedy)
# SubPOMC 49: 100% 23200/23200 [38:23<00:00, 10.07it/s]
#
# >>> Subproblem 5/14 completed <<<
# SubPOMC 43: 100% 23200/23200 [36:05<00:00, 10.71it/s]
#
# >>> Subproblem 7/14 completed <<<
# SubPOMC 32: 100% 23200/23200 [33:20<00:00, 11.60it/s]
#
# >>> Subproblem 8/14 completed <<<
# SubPOMC 45: 100% 23200/23200 [38:27<00:00, 10.05it/s]
#
# >>> Subproblem 6/14 completed <<<
# SubPOMC 22: Initialized with 33 seeds (20 singletons + greedy)
# SubPOMC 22:   6% 1374/23200 [02:04<40:39,  8.95it/s]SubPOMC 27: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 27:  14% 3278/23200 [04:52<35:00,  9.48it/s]SubPOMC 41: Initialized with 35 seeds (20 singletons + greedy)
# SubPOMC 27:  34% 7976/23200 [11:50<22:40, 11.19it/s]SubPOMC 31: Initialized with 36 seeds (20 singletons + greedy)
# SubPOMC 22: 100% 23200/23200 [34:21<00:00, 11.25it/s]
#
# >>> Subproblem 11/14 completed <<<
# SubPOMC 27: 100% 23200/23200 [34:24<00:00, 11.24it/s]
#
# >>> Subproblem 10/14 completed <<<
# SubPOMC 41: 100% 23200/23200 [35:39<00:00, 10.85it/s]
#
# >>> Subproblem 9/14 completed <<<
# SubPOMC 31: 100% 23200/23200 [33:29<00:00, 11.55it/s]
#
# >>> Subproblem 12/14 completed <<<
# SubPOMC 1: Initialized with 29 seeds (20 singletons + greedy)
# SubPOMC 1:  54% 12472/23200 [19:26<15:28, 11.55it/s]SubPOMC 15: Initialized with 30 seeds (20 singletons + greedy)
# SubPOMC 1: 100% 23200/23200 [36:15<00:00, 10.66it/s]
#
# >>> Subproblem 13/14 completed <<<
# SubPOMC 15: 100% 23200/23200 [30:48<00:00, 12.55it/s]
#
# >>> Subproblem 14/14 completed <<<
# → EPOAdapt returned; exiting main()
# --------------------------------------
# Elapsed time: 17878.6300 seconds

# %% [markdown]
# ---

# %% [markdown]
# **----------Budget 300 Results-----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 168.14',
    'value = 168.7',
    'value = 168.98'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 168.6067 sec, Std Dev: 0.4277 sec, CV: 0.25%

# %% [markdown]
# **-------Time Analysis 300----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 17923.2771',
    'Elapsed time: 18471.7128',
    'Elapsed time: 17878.6300'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 18091.2066 sec, Std Dev: 330.2833 sec, CV: 1.83%

# %% [markdown]
# #### Budget 400
# ---

# %% [markdown]
# **-----------Run 1-----------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1\
  -T 4 \
  -times 0

# %% [markdown]
# **----------Run 2 ------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1\
  -T 4 \
  -times 1

# %% [markdown]
# **-------------Run 3---------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 400 \
  -probability 0.1\
  -T 4 \
  -times 2

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 400 Results-----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 174.38',
    'value = 173.64',
    'value = 174.1'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 174.0400 sec, Std Dev: 0.3736 sec, CV: 0.21%

# %% [markdown]
# #### Budget 500
# ---

# %% [markdown]
# **------------Run 1------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1\
  -T 4 \
  -times 0

# %% [markdown]
# **------------Run 2 --------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1\
  -T 4 \
  -times 1

# %% [markdown]
# **-------------Run 3--------------**

# %%
# !python3 outdegree_opt_mut.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOAdapt \
  -budget 500 \
  -probability 0.1\
  -T 4 \
  -times 2

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 500 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 176.98',
    'value = 178.3',
    'value = 177.94'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 177.7400 sec, Std Dev: 0.6823 sec, CV: 0.38%

# %% [markdown]
# ---
