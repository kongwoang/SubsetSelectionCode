# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOL/
# Out:
# /content/drive/MyDrive/ML_Project/EPOL

# %% [markdown]
# ### Probability 0.1
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 0
# Out:
# outdegree/insecta.txt 100.0 EPOMC 4
# 17
# 100% 10336/10336 [1:34:51<00:00,  1.82it/s]
# 100% 10336/10336 [1:36:23<00:00,  1.79it/s]
# 100% 10336/10336 [1:40:49<00:00,  1.71it/s]
# 100% 10336/10336 [1:42:46<00:00,  1.68it/s]
# 100% 10336/10336 [1:42:47<00:00,  1.68it/s]
# 100% 10336/10336 [1:43:20<00:00,  1.67it/s]
# 100% 10336/10336 [1:55:36<00:00,  1.49it/s]
# 100% 10336/10336 [1:58:06<00:00,  1.46it/s]
# 100% 10336/10336 [1:29:51<00:00,  1.92it/s]
# 100% 10336/10336 [1:32:23<00:00,  1.86it/s]
# 100% 10336/10336 [1:25:52<00:00,  2.01it/s]
# 100% 10336/10336 [1:28:40<00:00,  1.94it/s]
# 100% 10336/10336 [1:27:49<00:00,  1.96it/s]
# 100% 10336/10336 [1:29:24<00:00,  1.93it/s]
# 100% 10336/10336 [1:19:52<00:00,  2.16it/s]
# 100% 10336/10336 [1:17:49<00:00,  2.21it/s]
# 100% 10336/10336 [44:48<00:00,  3.84it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 13887.3809 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 1
# Out:
# outdegree/insecta.txt 100.0 EPOMC 4
# 17
# 100% 10336/10336 [1:33:26<00:00,  1.84it/s]
# 100% 10336/10336 [1:35:30<00:00,  1.80it/s]
# 100% 10336/10336 [1:39:19<00:00,  1.73it/s]
# 100% 10336/10336 [1:41:12<00:00,  1.70it/s]
# 100% 10336/10336 [1:41:13<00:00,  1.70it/s]
# 100% 10336/10336 [1:41:42<00:00,  1.69it/s]
# 100% 10336/10336 [1:53:06<00:00,  1.52it/s]
# 100% 10336/10336 [1:56:18<00:00,  1.48it/s]
# 100% 10336/10336 [1:31:40<00:00,  1.88it/s]
# 100% 10336/10336 [1:24:11<00:00,  2.05it/s]
# 100% 10336/10336 [1:30:59<00:00,  1.89it/s]
# 100% 10336/10336 [1:27:51<00:00,  1.96it/s]
# 100% 10336/10336 [1:26:53<00:00,  1.98it/s]
# 100% 10336/10336 [1:28:10<00:00,  1.95it/s]
# 100% 10336/10336 [1:19:50<00:00,  2.16it/s]
# 100% 10336/10336 [1:17:35<00:00,  2.22it/s]
# 100% 10336/10336 [44:00<00:00,  3.91it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 13771.7185 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file insecta.txt \
  -outdegree_file insecta_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.1\
  -T 4 \
  -times 2
# Out:
# outdegree/insecta.txt 100.0 EPOMC 4
# 17
# 100% 10336/10336 [1:33:39<00:00,  1.84it/s]
# 100% 10336/10336 [1:35:32<00:00,  1.80it/s]
# 100% 10336/10336 [1:39:43<00:00,  1.73it/s]
# 100% 10336/10336 [1:41:08<00:00,  1.70it/s]
# 100% 10336/10336 [1:41:21<00:00,  1.70it/s]
# 100% 10336/10336 [1:41:52<00:00,  1.69it/s]
# 100% 10336/10336 [1:53:35<00:00,  1.52it/s]
# 100% 10336/10336 [1:56:41<00:00,  1.48it/s]
# 100% 10336/10336 [1:29:19<00:00,  1.93it/s]
# 100% 10336/10336 [1:24:18<00:00,  2.04it/s]
# 100% 10336/10336 [1:31:39<00:00,  1.88it/s]
# 100% 10336/10336 [1:27:30<00:00,  1.97it/s]
# 100% 10336/10336 [1:27:34<00:00,  1.97it/s]
# 100% 10336/10336 [1:30:12<00:00,  1.91it/s]
# 100% 10336/10336 [1:20:34<00:00,  2.14it/s]
# 100% 10336/10336 [1:17:45<00:00,  2.22it/s]
# 100% 10336/10336 [45:33<00:00,  3.78it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 13737.3070 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 99.316',
    'value = 99.596',
    'value = 99.404'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value", total_accumulated_values)
# Out:
# Value - Mean: 99.4387 sec, Std Dev: 0.1432 sec, CV: 0.14%

# %% [markdown]
# ---

# %% [markdown]
# **----------Time Analysis-----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 13887.3809',
    'Elapsed time: 13771.7185',
    'Elapsed time: 13737.3070'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 13798.8021 sec, Std Dev: 78.6173 sec, CV: 0.57%

# %% [markdown]
# ---
