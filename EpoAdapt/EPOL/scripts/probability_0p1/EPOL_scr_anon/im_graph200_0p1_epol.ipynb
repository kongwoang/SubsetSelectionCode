# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOL/
# Out:
# /content/drive/MyDrive/ML_Project/EPOL

# %% [markdown]
# ### Probability 0.1
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.1 \
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 100.0 EPOMC 4
# 16
# 100% 12800/12800 [2:25:57<00:00,  1.46it/s]
# 100% 12800/12800 [2:30:32<00:00,  1.42it/s]
# 100% 12800/12800 [2:30:51<00:00,  1.41it/s]
# 100% 12800/12800 [2:32:58<00:00,  1.39it/s]
# 100% 12800/12800 [2:33:00<00:00,  1.39it/s]
# 100% 12800/12800 [2:35:52<00:00,  1.37it/s]
# 100% 12800/12800 [2:47:23<00:00,  1.27it/s]
# 100% 12800/12800 [2:56:21<00:00,  1.21it/s]
# 100% 12800/12800 [2:21:54<00:00,  1.50it/s]
# 100% 12800/12800 [2:17:02<00:00,  1.56it/s]
# 100% 12800/12800 [2:15:09<00:00,  1.58it/s]
# 100% 12800/12800 [2:20:11<00:00,  1.52it/s]
# 100% 12800/12800 [2:18:14<00:00,  1.54it/s]
# 100% 12800/12800 [2:21:10<00:00,  1.51it/s]
# 100% 12800/12800 [2:09:58<00:00,  1.64it/s]
# 100% 12800/12800 [2:05:01<00:00,  1.71it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 18127.3599 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.1 \
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 100.0 EPOMC 4
# 16
# 100% 12800/12800 [2:27:49<00:00,  1.44it/s]
# 100% 12800/12800 [2:32:30<00:00,  1.40it/s]
# 100% 12800/12800 [2:32:48<00:00,  1.40it/s]
# 100% 12800/12800 [2:34:09<00:00,  1.38it/s]
# 100% 12800/12800 [2:34:51<00:00,  1.38it/s]
# 100% 12800/12800 [2:38:19<00:00,  1.35it/s]
# 100% 12800/12800 [2:49:07<00:00,  1.26it/s]
# 100% 12800/12800 [2:57:26<00:00,  1.20it/s]
# 100% 12800/12800 [2:14:01<00:00,  1.59it/s]
# 100% 12800/12800 [2:21:48<00:00,  1.50it/s]
# 100% 12800/12800 [2:17:25<00:00,  1.55it/s]
# 100% 12800/12800 [2:19:35<00:00,  1.53it/s]
# 100% 12800/12800 [2:19:53<00:00,  1.53it/s]
# 100% 12800/12800 [2:14:35<00:00,  1.58it/s]
# 100% 12800/12800 [2:09:11<00:00,  1.65it/s]
# 100% 12800/12800 [2:05:35<00:00,  1.70it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 18226.2995 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.1 \
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 100.0 EPOMC 4
# 16
# 100% 12800/12800 [2:24:45<00:00,  1.47it/s]
# 100% 12800/12800 [2:29:46<00:00,  1.42it/s]
# 100% 12800/12800 [2:30:05<00:00,  1.42it/s]
# 100% 12800/12800 [2:31:49<00:00,  1.41it/s]
# 100% 12800/12800 [2:32:44<00:00,  1.40it/s]
# 100% 12800/12800 [2:35:25<00:00,  1.37it/s]
# 100% 12800/12800 [2:46:06<00:00,  1.28it/s]
# 100% 12800/12800 [2:55:11<00:00,  1.22it/s]
# 100% 12800/12800 [2:21:13<00:00,  1.51it/s]
# 100% 12800/12800 [2:17:32<00:00,  1.55it/s]
# 100% 12800/12800 [2:15:02<00:00,  1.58it/s]
# 100% 12800/12800 [2:19:56<00:00,  1.52it/s]
# 100% 12800/12800 [2:14:18<00:00,  1.59it/s]
# 100% 12800/12800 [2:18:11<00:00,  1.54it/s]
# 100% 12800/12800 [2:09:56<00:00,  1.64it/s]
# 100% 12800/12800 [2:03:43<00:00,  1.72it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 17979.8397 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 120.444',
    'value = 120.176',
    'value = 120.238'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Total Value", total_accumulated_values)
# Out:
# Total Value - Mean: 120.2860 sec, Std Dev: 0.1403 sec, CV: 0.12%

# %% [markdown]
# **---------Time Analysis---------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 18127.3599',
    'Elapsed time: 18226.2995',
    'Elapsed time: 17979.8397'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Total Time", total_accumulated_values)
# Out:
# Total Time - Mean: 18111.1664 sec, Std Dev: 124.0253 sec, CV: 0.68%

# %% [markdown]
# ---
