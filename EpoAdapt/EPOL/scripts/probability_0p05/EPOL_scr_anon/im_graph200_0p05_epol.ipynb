# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             48 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      8
#   On-line CPU(s) list:       0-7
# Vendor ID:                   AuthenticAMD
#   Model name:                AMD EPYC 7B12
#     CPU family:              23
#     Model:                   49
#     Thread(s) per core:      2
#     Core(s) per socket:      4
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4499.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ht s
#                              yscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constan
#                              t_tsc rep_good nopl nonstop_tsc cpuid extd_apicid t
#                              sc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 s
#                              se4_2 x2apic movbe popcnt aes xsave avx f16c rdrand
#                               hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a
#                               misalignsse 3dnowprefetch osvw topoext ssbd ibrs i
#                              bpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 sme
#                              p bmi2 rdseed adx smap clflushopt clwb sha_ni xsave
#                              opt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_
#                              save umip rdpid
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       128 KiB (4 instances)
#   L1i:                       128 KiB (4 instances)
#   L2:                        2 MiB (4 instances)
#   L3:                        16 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-7
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Not affected
#   Itlb multihit:             Not affected
#   L1tf:                      Not affected
#   Mds:                       Not affected
#   Meltdown:                  Not affected
#   Mmio stale data:           Not affected
#   Reg file data sampling:    Not affected
#   Retbleed:                  Vulnerable
#   Spec rstack overflow:      Vulnerable
#   Spec store bypass:         Vulnerable
#   Spectre v1:                Vulnerable: __user pointer sanitization and usercop
#                              y barriers only; no swapgs barriers
#   Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-
#                              eIBRS: Not affected; BHI: Not affected
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Not affected

# %% [markdown]
# **--------Mount the drive-----**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# **--------Change directory to run the code-------------**

# %%
# %cd /content/drive/MyDrive/ML_Project/EPOL/
# Out:
# /content/drive/MyDrive/ML_Project/EPOL

# %% [markdown]
# ### Probability 0.05
# ---

# %% [markdown]
# #### Budget 100
# ---

# %% [markdown]
# **---------------Run 1---------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 0
# Out:
# outdegree/graph200-01.txt 100.0 EPOMC 4
# 16
# 100% 12800/12800 [1:11:38<00:00,  2.98it/s]
# 100% 12800/12800 [1:13:18<00:00,  2.91it/s]
# 100% 12800/12800 [1:13:52<00:00,  2.89it/s]
# 100% 12800/12800 [1:14:03<00:00,  2.88it/s]
# 100% 12800/12800 [1:15:07<00:00,  2.84it/s]
# 100% 12800/12800 [1:16:57<00:00,  2.77it/s]
# 100% 12800/12800 [1:27:16<00:00,  2.44it/s]
# 100% 12800/12800 [1:30:29<00:00,  2.36it/s]
# 100% 12800/12800 [1:06:26<00:00,  3.21it/s]
# 100% 12800/12800 [1:06:20<00:00,  3.22it/s]
# 100% 12800/12800 [1:05:57<00:00,  3.23it/s]
# 100% 12800/12800 [1:08:08<00:00,  3.13it/s]
# 100% 12800/12800 [1:09:47<00:00,  3.06it/s]
# 100% 12800/12800 [1:05:15<00:00,  3.27it/s]
# 100% 12800/12800 [59:56<00:00,  3.56it/s]
# 100% 12800/12800 [58:09<00:00,  3.67it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 8940.9536 seconds

# %% [markdown]
# **---------Run 2-------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 1
# Out:
# outdegree/graph200-01.txt 100.0 EPOMC 4
# 16
# 100% 12800/12800 [1:12:37<00:00,  2.94it/s]
# 100% 12800/12800 [1:14:27<00:00,  2.86it/s]
# 100% 12800/12800 [1:14:51<00:00,  2.85it/s]
# 100% 12800/12800 [1:15:30<00:00,  2.83it/s]
# 100% 12800/12800 [1:16:04<00:00,  2.80it/s]
# 100% 12800/12800 [1:17:46<00:00,  2.74it/s]
# 100% 12800/12800 [1:28:25<00:00,  2.41it/s]
# 100% 12800/12800 [1:31:23<00:00,  2.33it/s]
# 100% 12800/12800 [1:05:00<00:00,  3.28it/s]
# 100% 12800/12800 [1:06:20<00:00,  3.22it/s]
# 100% 12800/12800 [1:05:45<00:00,  3.24it/s]
# 100% 12800/12800 [1:09:05<00:00,  3.09it/s]
# 100% 12800/12800 [1:07:20<00:00,  3.17it/s]
# 100% 12800/12800 [1:05:21<00:00,  3.26it/s]
# 100% 12800/12800 [59:54<00:00,  3.56it/s]
# 100% 12800/12800 [58:36<00:00,  3.64it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 9022.2040 seconds

# %% [markdown]
# **---------------Run 3------------------**

# %%
# !python3 IM_outdegree.py \
  -adjacency_file graph200-01.txt \
  -outdegree_file graph200_eps.txt \
  -algo EPOMC \
  -budget 100 \
  -probability 0.05\
  -T 4 \
  -times 2
# Out:
# outdegree/graph200-01.txt 100.0 EPOMC 4
# 16
# 100% 12800/12800 [1:12:33<00:00,  2.94it/s]
# 100% 12800/12800 [1:13:42<00:00,  2.89it/s]
# 100% 12800/12800 [1:14:34<00:00,  2.86it/s]
# 100% 12800/12800 [1:14:51<00:00,  2.85it/s]
# 100% 12800/12800 [1:15:45<00:00,  2.82it/s]
# 100% 12800/12800 [1:17:08<00:00,  2.77it/s]
# 100% 12800/12800 [1:28:21<00:00,  2.41it/s]
# 100% 12800/12800 [1:30:53<00:00,  2.35it/s]
# 100% 12800/12800 [1:06:02<00:00,  3.23it/s]
# 100% 12800/12800 [1:05:52<00:00,  3.24it/s]
# 100% 12800/12800 [1:08:08<00:00,  3.13it/s]
# 100% 12800/12800 [1:06:59<00:00,  3.18it/s]
# 100% 12800/12800 [1:09:21<00:00,  3.08it/s]
# 100% 12800/12800 [1:05:18<00:00,  3.27it/s]
# 100% 12800/12800 [59:39<00:00,  3.58it/s]
# 100% 12800/12800 [57:59<00:00,  3.68it/s]
# → EPOMC returned; exiting main()
# --------------------------------------
# Elapsed time: 8955.5562 seconds

# %% [markdown]
# ---

# %% [markdown]
# **---------Budget 100 Results----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'value = 47.208',
    'value = 46.91',
    'value = 47.228'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'value =\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Value ", total_accumulated_values)
# Out:
# Value  - Mean: 47.1153 sec, Std Dev: 0.1781 sec, CV: 0.38%

# %% [markdown]
# **------Time Analysis----------**

# %%
import re
import numpy as np

# The result strings
results = [
    'Elapsed time: 8940.9536',
    'Elapsed time: 9022.2040',
    'Elapsed time: 8955.5562'
]

# Extract times using regex
total_accumulated_values = []

for line in results:
    match = re.search(r'Elapsed time:\s*([\d.]+)', line)
    if match:
        total_accumulated_values.append(float(match.group(1)))
    else:
        print(f"Warning: No match found in line: {line}")

# Compute mean, std, and CV
def stats(name, values):
    avg = np.mean(values)
    std = np.std(values, ddof=1)  # Sample std dev
    cv = (std / avg) * 100 if avg != 0 else float('nan')  # CV in percentage
    print(f"{name} - Mean: {avg:.4f} sec, Std Dev: {std:.4f} sec, CV: {cv:.2f}%")

stats("Time", total_accumulated_values)
# Out:
# Time - Mean: 8972.9046 sec, Std Dev: 43.3143 sec, CV: 0.48%

# %% [markdown]
# ---
